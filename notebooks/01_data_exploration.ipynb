# %% [markdown]
# # growers.csv Analysis

# %%
import pandas as pd

# %%
df = pd.read_csv("../Dataset/growers.csv")

# %%
df.head()
# Out:
#    grower_id          state      district             tehsil language  \
# 0  GRW_00001      Rajasthan     Bharatpur     Bharatpur_T023    Hindi
# 1  GRW_00002  Uttar Pradesh  Kanpur Nagar  Kanpur_Nagar_T023    Hindi
# 2  GRW_00003         Punjab       Patiala       Patiala_T104  Punjabi
# 3  GRW_00004      Rajasthan        Jaipur        Jaipur_T007    Hindi
# 4  GRW_00005  Uttar Pradesh  Kanpur Nagar  Kanpur_Nagar_T124    Hindi
#
#   device_type  grower_age  gender  \
# 0  smartphone          67    male
# 1  smartphone          71    male
# 2  smartphone          52    male
# 3  smartphone          65    male
# 4  smartphone          26  female
#
#                                 grower_crop_calendar  product_scan  \
# 0  {"season": "Rabi_2025-26", "crop": "wheat", "s...         False
# 1  {"season": "Rabi_2025-26", "crop": "wheat", "s...         False
# 2  {"season": "Rabi_2025-26", "crop": "wheat", "s...         False
# ...

# %% [markdown]
# # Initial Dataset Observations — growers.csv
#
# ## Overview
#
# - The dataset appears to contain grower/farmer profile information used for agricultural analysis and engagement tracking.
# - Each record represents an individual grower identified using a unique `grower_id`.
# - The dataset combines demographic, geographic, agricultural, and behavioral information into a single structure.
#
# ---
#
# ## Geographic Information Analysis
#
# - The dataset contains multiple levels of location hierarchy:
#   - `state`
#   - `district`
#   - `tehsil`
# - States visible in the sample include:
#   - Rajasthan
#   - Uttar Pradesh
#   - Punjab
# - This geographic granularity can support:
#   - territory-based analysis,
#   - regional targeting,
#   - field-force optimization,
#   - and localized agricultural recommendations.
#
# ---
#
# ## Demographic Insights
#
# - The dataset includes grower demographic features such as:
#   - age,
#   - gender,
#   - language preference.
# - Grower ages vary significantly, indicating representation across multiple age groups.
# - Language information such as Hindi and Punjabi may help support multilingual communication and campaign personalization.
# - Gender information may help analyze participation and engagement diversity among growers.
#
# ---
#
# ## Digital Accessibility Analysis
#
# - The `device_type` column indicates that growers are using smartphones.
# - Smartphone accessibility is important because it enables:
#   - digital campaign delivery,
#   - mobile notifications,
#   - product scanning,
#   - and app-based interactions.
# - This suggests that digital engagement strategies may be feasible for a large portion of growers.
#
# ---
#
# ## Agricultural Information Analysis
#
# - The `grower_crop_calendar` column contains crop-season related information.
# - The sample indicates crops associated with the Rabi farming season.
# - Crop calendar data is highly valuable because agricultural demand is seasonal.
# - This information can help:
#   - optimize product recommendation timing,
#   - improve campaign scheduling,
#   - and align retailer priorities with seasonal demand patterns.
#
# ---
#
# ## Behavioral and Engagement Analysis
#
# - The dataset includes behavioral activity indicators such as:
#   - `product_scan`
#   - `offline_campaign_attended`
# - These fields may help estimate grower engagement and product interest levels.
# - Offline campaign participation suggests that the organization is conducting field-level outreach programs.
# - Behavioral indicators can later be useful for:
#   - conversion prediction,
#   - engagement scoring,
#   - and grower prioritization.
#
# ---
#
# ## Product Interaction Analysis
#
# - The columns:
#   - `product_name`
#   - `product_scan_datetime`
#   contain missing values (`NaN`) in several rows.
# - The missing values appear logically consistent because growers who did not scan products would naturally not have associated scan details.
# - This suggests that the missing data likely represents absence of activity rather than corrupted records.
#
# ---
#
# ## Farm Size Analysis
#
# - The `grower_farm_size` column contains numerical farm size values.
# - Farm size can be an important business indicator because:
#   - larger farms may have higher purchasing requirements,
#   - product demand may vary by cultivation scale,
#   - and sales prioritization can depend on farm capacity.
# - Farm size may become an important feature during machine learning model training.
#
# ---
#
# ## Relevance to AgriPulse AI
#
# - This dataset appears highly useful for intelligent agricultural analytics.
# - The combination of:
#   - geographic data,
#   - behavioral signals,
#   - demographic information,
#   - and crop-season data
#   can support AI-driven prioritization and targeting systems.
# - The dataset can contribute to:
#   - grower segmentation,
#   - engagement prediction,
#   - campaign optimization,
#   - and retailer prioritization workflows.

# %%
df.shape
# Out:
# (6000, 15)

# %% [markdown]
# # Dataset Size Analysis
#
# ## Shape of Dataset
#
# - The dataset contains:
#   - 6000 rows
#   - 15 columns
#
# ---
#
# ## Observations
#
# - A dataset size of 6000 records is sufficient for meaningful exploratory data analysis and machine learning experimentation.
# - The number of rows indicates that the dataset likely represents a moderately large grower population across multiple regions.
# - The dataset size is appropriate for:
#   - pattern analysis,
#   - feature engineering,
#   - segmentation,
#   - and predictive modeling tasks.
#
# ---
#
# ## Feature Availability
#
# - The dataset contains 15 columns representing multiple categories of information, including:
#   - demographic data,
#   - geographic attributes,
#   - behavioral engagement,
#   - agricultural activity,
#   - and campaign participation.
#
# - The diversity of features increases the usefulness of the dataset for AI-driven analysis.
#
# ---
#
# ## Machine Learning Relevance
#
# - A dataset with 6000 records provides enough samples for:
#   - training validation splits,
#   - classification experiments,
#   - and feature importance analysis.
#
# - The dataset size is manageable for:
#   - local machine learning experimentation,
#   - Jupyter Notebook analysis,
#   - and hackathon-scale development.
#
# ---
#
# ## Business Relevance
#
# - The dataset scale suggests that the organization is tracking grower engagement at a reasonably broad operational level.
# - Geographic diversity combined with behavioral data may help improve:
#   - retailer prioritization,
#   - campaign targeting,
#   - and field-force efficiency.
#
# ---
#
# ## Overall Interpretation
#
# - The dataset appears sufficiently large and feature-rich for developing AI-assisted agricultural intelligence workflows within the AgriPulse AI project.

# %%
df.columns
# Out:
# Index(['grower_id', 'state', 'district', 'tehsil', 'language', 'device_type',
#        'grower_age', 'gender', 'grower_crop_calendar', 'product_scan',
#        'product_name', 'product_scan_datetime', 'grower_farm_size',
#        'offline_campaign_attended', 'campaign_attendance_date'],
#       dtype='str')

# %% [markdown]
# # Column Structure Analysis
#
# ## Available Columns
#
# The dataset contains the following columns:
#
# - `grower_id`
# - `state`
# - `district`
# - `tehsil`
# - `language`
# - `device_type`
# - `grower_age`
# - `gender`
# - `grower_crop_calendar`
# - `product_scan`
# - `product_name`
# - `product_scan_datetime`
# - `grower_farm_size`
# - `offline_campaign_attended`
# - `campaign_attendance_date`
#
# ---
#
# # Feature Category Analysis
#
# ## 1. Identification Features
#
# ### `grower_id`
#
# - Acts as a unique identifier for each grower.
# - Useful for:
#   - record tracking,
#   - dataset joins,
#   - and personalization workflows.
# - Essential for connecting grower activity across multiple datasets.
#
# ---
#
# ## 2. Geographic Features
#
# ### Geographic Columns
# - `state`
# - `district`
# - `tehsil`
#
# ### Importance
#
# - These columns provide hierarchical geographic segmentation.
# - Geographic information is extremely important in agriculture because:
#   - climate differs by region,
#   - crop patterns vary,
#   - demand behavior changes geographically,
#   - and field-force operations are location dependent.
#
# ### Business Applications
#
# These columns can support:
# - territory management,
# - retailer prioritization,
# - route optimization,
# - localized recommendations,
# - and regional demand forecasting.
#
# ---
#
# ## 3. Demographic Features
#
# ### Demographic Columns
# - `grower_age`
# - `gender`
# - `language`
#
# ### Importance
#
# - Demographic attributes can help identify behavioral patterns among growers.
# - Language preference can improve communication personalization.
# - Age distribution may influence:
#   - technology adoption,
#   - campaign responsiveness,
#   - and purchasing behavior.
#
# ### AI/ML Relevance
#
# These features may become useful during:
# - grower segmentation,
# - engagement prediction,
# - and recommendation modeling.
#
# ---
#
# ## 4. Technology Accessibility Features
#
# ### `device_type`
#
# - Indicates the type of digital device used by growers.
# - Helps estimate digital accessibility and online engagement capability.
#
# ### Importance
#
# This feature may help determine:
# - whether growers can receive app-based communication,
# - digital campaign effectiveness,
# - and mobile engagement potential.
#
# ---
#
# ## 5. Agricultural Features
#
# ### `grower_crop_calendar`
#
# - Stores crop-season information.
# - Likely contains:
#   - crop names,
#   - seasons,
#   - sowing schedules,
#   - or harvest timelines.
#
# ### Importance
#
# Agricultural data is highly seasonal, making this feature extremely valuable.
#
# This information can help:
# - align product recommendations with crop cycles,
# - optimize campaign timing,
# - and improve seasonal demand forecasting.
#
# ---
#
# ## 6. Behavioral Features
#
# ### Behavioral Columns
# - `product_scan`
# - `product_name`
# - `product_scan_datetime`
# - `offline_campaign_attended`
# - `campaign_attendance_date`
#
# ### Importance
#
# These columns track grower engagement and interaction behavior.
#
# Behavioral data is especially important because it may indicate:
# - interest levels,
# - purchase intent,
# - campaign responsiveness,
# - and digital activity.
#
# ### AI Relevance
#
# Behavioral features often become strong predictors in machine learning systems because they represent actual user activity patterns.
#
# ---
#
# ## 7. Farm Size Feature
#
# ### `grower_farm_size`
#
# - Represents the size of the grower’s farm.
# - Farm size may correlate with:
#   - purchasing power,
#   - product demand,
#   - and business potential.
#
# ### Importance
#
# This feature may help:
# - prioritize high-value growers,
# - improve targeting strategies,
# - and strengthen predictive models.
#
# ---
#
# # Overall Dataset Interpretation
#
# - The dataset contains a strong combination of:
#   - geographic,
#   - demographic,
#   - agricultural,
#   - behavioral,
#   - and operational features.
#
# - The feature diversity makes the dataset highly suitable for:
#   - AI-driven agricultural analytics,
#   - grower segmentation,
#   - engagement analysis,
#   - and intelligent prioritization systems.
#
# - The dataset structure appears well-aligned with the goals of the AgriPulse AI project.

# %%
df.isnull().sum()
# Out:
# grower_id                       0
# state                           0
# district                        0
# tehsil                          0
# language                        0
# device_type                     0
# grower_age                      0
# gender                          0
# grower_crop_calendar          450
# product_scan                    0
# product_name                 4904
# product_scan_datetime        4843
# grower_farm_size              745
# offline_campaign_attended       0
# campaign_attendance_date     2078
# dtype: int64

# %% [markdown]
# # Missing Value Analysis
#
# ## Overview
#
# The dataset contains several columns with missing values, while many core identification and geographic fields are completely populated.
#
# Missing-value analysis is important because incomplete data can:
# - affect model accuracy,
# - reduce analytical reliability,
# - introduce bias,
# - and impact downstream AI/ML systems.
#
# Understanding which columns contain missing data helps determine:
# - data quality,
# - preprocessing requirements,
# - and feature usability.
#
# ---
#
# # Column-wise Missing Value Evaluation
#
# ## 1. Fully Complete Columns
#
# ### Columns with No Missing Values
#
# - `grower_id`
# - `state`
# - `district`
# - `tehsil`
# - `language`
# - `device_type`
# - `grower_age`
# - `gender`
# - `product_scan`
# - `offline_campaign_attended`
#
# ### Importance
#
# These columns are highly reliable because they contain complete information for all records.
#
# ### Business & AI Significance
#
# Complete columns are extremely valuable because they:
# - improve model consistency,
# - reduce preprocessing complexity,
# - enable reliable segmentation,
# - and support accurate analytics.
#
# ### Observations
#
# The dataset is especially strong in:
# - geographic coverage,
# - demographic consistency,
# - and operational tracking.
#
# This indicates good foundational data collection practices.
#
# ---
#
# ## 2. Agricultural Feature Missing Values
#
# ### `grower_crop_calendar` → 450 Missing Values
#
# ### Interpretation
#
# Some growers do not have crop calendar information recorded.
#
# ### Possible Reasons
#
# This may happen because:
# - crop details were not collected,
# - growers skipped seasonal information,
# - or agricultural records are incomplete.
#
# ### Impact
#
# Missing crop-cycle data may affect:
# - seasonal recommendation systems,
# - crop-based targeting,
# - and demand forecasting models.
#
# ### AI/ML Relevance
#
# Since agricultural seasonality is important in agri-intelligence systems, this feature should ideally be completed or carefully imputed.
#
# ### Suggested Handling
#
# Possible preprocessing approaches:
# - fill using regional crop patterns,
# - use “Unknown” category,
# - or apply predictive imputation techniques.
#
# ---
#
# ## 3. Product Interaction Missing Values
#
# ### `product_name` → 4904 Missing Values
#
# ### Interpretation
#
# A large number of records do not contain scanned product names.
#
# ### Possible Reasons
#
# This could indicate:
# - no product scan occurred,
# - scan failures,
# - incomplete tracking,
# - or inactive grower engagement.
#
# ### Impact
#
# This is one of the most significant missing-value areas in the dataset.
#
# Missing product information may reduce the effectiveness of:
# - recommendation systems,
# - behavioral analysis,
# - product affinity modeling,
# - and engagement scoring.
#
# ### Business Insight
#
# The high missing count may itself carry useful behavioral meaning:
# - growers without scans may represent low-engagement users,
# - inactive customers,
# - or digitally disconnected growers.
#
# ### AI Relevance
#
# This feature may still become highly valuable after:
# - feature engineering,
# - missing-category labeling,
# - or behavioral segmentation.
#
# ---
#
# ## 4. Product Scan Timestamp Missing Values
#
# ### `product_scan_datetime` → 4843 Missing Values
#
# ### Interpretation
#
# Many records lack timestamps for product scans.
#
# ### Relationship with `product_name`
#
# This missing pattern is likely connected to the missing `product_name` field because:
# - if no scan occurred,
# - scan timestamps would also remain empty.
#
# ### Impact
#
# Missing timestamps reduce the ability to:
# - analyze engagement timing,
# - study seasonal scan trends,
# - monitor usage frequency,
# - and build time-series behavioral models.
#
# ### AI/ML Importance
#
# Temporal behavior is often extremely useful in predictive analytics. Missing timestamps may weaken:
# - activity prediction,
# - engagement forecasting,
# - and campaign timing optimization.
#
# ### Suggested Handling
#
# Potential approaches:
# - retain as null if representing “no activity,”
# - derive binary engagement indicators,
# - or separate active vs inactive growers.
#
# ---
#
# ## 5. Farm Size Missing Values
#
# ### `grower_farm_size` → 745 Missing Values
#
# ### Interpretation
#
# Some growers do not have farm-size information recorded.
#
# ### Importance
#
# Farm size is an economically meaningful feature because it may correlate with:
# - purchasing power,
# - yield potential,
# - input requirements,
# - and commercial value.
#
# ### Impact
#
# Missing farm-size values may affect:
# - grower prioritization,
# - market segmentation,
# - and revenue prediction systems.
#
# ### Suggested Handling
#
# Possible preprocessing strategies:
# - median imputation,
# - regional average estimation,
# - or farm-size category prediction.
#
# ---
#
# ## 6. Campaign Attendance Date Missing Values
#
# ### `campaign_attendance_date` → 2078 Missing Values
#
# ### Interpretation
#
# Many growers do not have campaign attendance dates recorded.
#
# ### Likely Reason
#
# This is likely associated with growers who:
# - never attended campaigns,
# - or whose attendance was not logged.
#
# ### Relationship with `offline_campaign_attended`
#
# This feature should be analyzed together with:
# - `offline_campaign_attended`
#
# because:
# - growers marked as “No” attendance may naturally have null dates.
#
# ### Business Importance
#
# Campaign participation data is important for:
# - engagement analysis,
# - outreach optimization,
# - and campaign effectiveness measurement.
#
# ### AI/ML Relevance
#
# Attendance history may become a strong feature for:
# - engagement scoring,
# - response prediction,
# - and grower retention modeling.
#
# ---
#
# # Overall Missing Data Interpretation
#
# ## Key Observations
#
# The dataset demonstrates:
# - strong geographic completeness,
# - reliable demographic coverage,
# - and solid operational consistency.
#
# Most missing values occur in:
# - behavioral,
# - agricultural,
# - and engagement-related columns.
#
# This pattern is common in real-world agricultural datasets because behavioral interactions are often optional or event-driven.
#
# ---
#
# # Strategic Interpretation
#
# The missing values themselves may contain useful business signals.
#
# For example:
# - missing product scans may indicate low digital engagement,
# - missing attendance dates may indicate inactive growers,
# - and missing crop information may reflect incomplete agricultural onboarding.
#
# Thus, missingness should not always be treated purely as a data-quality problem.
#
# ---
#
# # AI/ML Readiness Assessment
#
# ## Strengths
#
# The dataset is strong because it includes:
# - rich geographic structure,
# - behavioral interaction data,
# - demographic information,
# - and agricultural context.
#
# ## Challenges
#
# The main preprocessing challenges involve:
# - behavioral feature sparsity,
# - timestamp incompleteness,
# - and agricultural data gaps.
#
# ## Conclusion
#
# Overall, the dataset remains highly valuable and well-suited for:
# - grower segmentation,
# - engagement analytics,
# - recommendation systems,
# - intelligent field-force prioritization,
# - and AI-driven agricultural decision systems.

# %%
df.dtypes
# Out:
# grower_id                        str
# state                            str
# district                         str
# tehsil                           str
# language                         str
# device_type                      str
# grower_age                     int64
# gender                           str
# grower_crop_calendar             str
# product_scan                    bool
# product_name                     str
# product_scan_datetime            str
# grower_farm_size             float64
# offline_campaign_attended       bool
# campaign_attendance_date         str
# dtype: object

# %% [markdown]
# # Data Type Analysis
#
# ## Overview
#
# The dataset contains a mixture of:
# - string (`str`),
# - integer (`int64`),
# - floating-point (`float64`),
# - and boolean (`bool`) data types.
#
# The presence of multiple data types indicates that the dataset includes:
# - categorical information,
# - numerical measurements,
# - behavioral indicators,
# - and operational records.
#
# A well-structured datatype distribution is important because it:
# - improves preprocessing efficiency,
# - supports machine learning workflows,
# - and enables better feature engineering.
#
# ---
#
# # Column-wise Data Type Evaluation
#
# ## 1. String-Based Features (`str`)
#
# ### Columns
# - `grower_id`
# - `state`
# - `district`
# - `tehsil`
# - `language`
# - `device_type`
# - `gender`
# - `grower_crop_calendar`
# - `product_name`
# - `product_scan_datetime`
# - `campaign_attendance_date`
#
# ---
#
# ## Importance of String Features
#
# String columns mainly represent:
# - identifiers,
# - categories,
# - labels,
# - locations,
# - and textual operational information.
#
# These columns are highly important for:
# - segmentation,
# - grouping,
# - filtering,
# - and categorical analysis.
#
# ---
#
# ## Detailed Interpretation
#
# ### `grower_id`
#
# - Stored as a string because it acts as a unique identifier rather than a numerical quantity.
# - Prevents accidental mathematical operations.
# - Useful for:
#   - user tracking,
#   - joins,
#   - and personalization systems.
#
# ---
#
# ### Geographic Features
#
# #### Columns
# - `state`
# - `district`
# - `tehsil`
#
# ### Importance
#
# These are categorical geographic variables.
#
# They help support:
# - regional analytics,
# - location-based recommendations,
# - and territory intelligence systems.
#
# ### AI/ML Usage
#
# These columns may later require:
# - label encoding,
# - one-hot encoding,
# - or embedding techniques.
#
# ---
#
# ### `language`
#
# - Represents grower communication preference.
# - Useful for multilingual engagement systems.
# - Important for:
#   - localized communication,
#   - campaign personalization,
#   - and accessibility optimization.
#
# ---
#
# ### `device_type`
#
# - Indicates digital accessibility.
# - Helps identify:
#   - smartphone users,
#   - feature-phone users,
#   - or other device categories.
#
# ### Business Value
#
# This feature may influence:
# - digital campaign reach,
# - app adoption,
# - and mobile engagement strategy.
#
# ---
#
# ### `gender`
#
# - A categorical demographic variable.
# - Useful for demographic segmentation and behavioral analysis.
#
# ### AI Consideration
#
# Should be handled carefully to avoid:
# - demographic bias,
# - unfair targeting,
# - or skewed modeling outcomes.
#
# ---
#
# ### `grower_crop_calendar`
#
# - Stored as text because crop schedules and crop names are categorical/seasonal information.
# - May contain:
#   - crop names,
#   - sowing timelines,
#   - or harvest patterns.
#
# ### Importance
#
# This is a high-value agricultural intelligence feature.
#
# ---
#
# ### `product_name`
#
# - Represents scanned product information.
# - Important for:
#   - behavioral analytics,
#   - product affinity analysis,
#   - and recommendation systems.
#
# ---
#
# ### Date Columns Stored as Strings
#
# #### Columns
# - `product_scan_datetime`
# - `campaign_attendance_date`
#
# ### Important Observation
#
# These columns are currently stored as strings instead of datetime format.
#
# ### Impact
#
# This may limit:
# - time-series analysis,
# - seasonal trend analysis,
# - and temporal modeling.
#
# ### Recommended Preprocessing
#
# These columns should ideally be converted using:
#
# ```python
# pd.to_datetime()

# %%
df.describe()
# Out:
#         grower_age  grower_farm_size
# count  6000.000000       5255.000000
# mean     47.877000          1.967973
# std      15.147193          1.269911
# min      22.000000          0.190000
# 25%      35.000000          1.100000
# 50%      48.000000          1.640000
# 75%      61.000000          2.470000
# max      74.000000         10.920000

# %% [markdown]
# # Numerical Feature Statistical Analysis
#
# ## Overview
#
# The dataset contains two primary numerical features:
#
# - `grower_age`
# - `grower_farm_size`
#
# Statistical analysis helps understand:
# - data distribution,
# - variability,
# - central tendency,
# - and potential outliers.
#
# These insights are extremely useful for:
# - preprocessing,
# - feature engineering,
# - segmentation,
# - and predictive modeling.
#
# ---
#
# # 1. Grower Age Analysis
#
# ## Statistical Summary for `grower_age`
#
# | Metric | Value |
# |---|---|
# | Count | 6000 |
# | Mean | 47.877 |
# | Standard Deviation | 15.147 |
# | Minimum | 22 |
# | 25th Percentile | 35 |
# | Median (50%) | 48 |
# | 75th Percentile | 61 |
# | Maximum | 74 |
#
# ---
#
# ## Interpretation
#
# ### Count = 6000
#
# - All growers have age information available.
# - This indicates strong demographic completeness.
# - No missing values exist for this feature.
#
# ---
#
# ## Mean Age ≈ 48 Years
#
# - The average grower age is approximately 48 years.
# - This suggests the dataset mainly represents middle-aged agricultural workers.
#
# ### Business Insight
#
# Middle-aged growers may:
# - possess strong farming experience,
# - have established agricultural practices,
# - and show moderate technology adoption behavior.
#
# ---
#
# ## Median Age = 48
#
# - The median age is almost identical to the mean age.
#
# ### Interpretation
#
# This indicates:
# - the age distribution is relatively balanced,
# - and there is limited skewness.
#
# The dataset does not appear heavily biased toward:
# - extremely young growers,
# - or extremely old growers.
#
# ---
#
# ## Age Range
#
# ### Minimum Age = 22
# ### Maximum Age = 74
#
# ### Interpretation
#
# The dataset covers a wide farming age population.
#
# This range suggests inclusion of:
# - younger digitally adaptable growers,
# - experienced middle-aged farmers,
# - and senior traditional growers.
#
# ### AI/ML Importance
#
# A broad age range improves:
# - segmentation quality,
# - behavioral diversity,
# - and prediction robustness.
#
# ---
#
# ## Standard Deviation ≈ 15.15
#
# ### Interpretation
#
# The age values are moderately spread out.
#
# This means:
# - growers belong to multiple age groups,
# - and demographic diversity exists in the dataset.
#
# ### Business Relevance
#
# Different age groups may exhibit different:
# - purchasing patterns,
# - digital engagement levels,
# - campaign responsiveness,
# - and technology adoption behavior.
#
# ---
#
# ## Quartile Analysis
#
# ### 25% of growers are younger than 35
#
# This indicates a smaller but meaningful younger population.
#
# ---
#
# ### 50% of growers are younger than 48
#
# This confirms the dataset is centered around middle-aged growers.
#
# ---
#
# ### 75% of growers are younger than 61
#
# This suggests the majority of growers fall within:
# - mature,
# - experienced,
# - and economically active farming age groups.
#
# ---
#
# # Overall Interpretation of Age Feature
#
# The `grower_age` feature appears:
# - complete,
# - well distributed,
# - and highly valuable for behavioral and demographic analysis.
#
# This feature may strongly influence:
# - engagement prediction,
# - campaign personalization,
# - and adoption modeling.
#
# ---
#
# # 2. Grower Farm Size Analysis
#
# ## Statistical Summary for `grower_farm_size`
#
# | Metric | Value |
# |---|---|
# | Count | 5255 |
# | Mean | 1.968 |
# | Standard Deviation | 1.270 |
# | Minimum | 0.19 |
# | 25th Percentile | 1.10 |
# | Median (50%) | 1.64 |
# | 75th Percentile | 2.47 |
# | Maximum | 10.92 |
#
# ---
#
# ## Interpretation
#
# ### Count = 5255
#
# - Farm-size information is available for 5255 growers.
# - Approximately 745 values are missing.
#
# ### Data Quality Observation
#
# Although some values are missing, the feature still contains substantial information for analysis.
#
# ---
#
# ## Mean Farm Size ≈ 1.97
#
# ### Interpretation
#
# The average farm size is relatively small.
#
# ### Business Insight
#
# This may indicate:
# - small-scale farming dominance,
# - fragmented agricultural landholding,
# - or regional smallholder farming patterns.
#
# This is common in many agricultural economies.
#
# ---
#
# ## Median Farm Size = 1.64
#
# ### Interpretation
#
# The median is lower than the mean.
#
# This suggests:
# - the distribution may be slightly right-skewed,
# - with some larger farms increasing the average.
#
# ---
#
# ## Farm Size Range
#
# ### Minimum = 0.19
# ### Maximum = 10.92
#
# ### Interpretation
#
# The dataset includes:
# - very small farms,
# - medium-sized farms,
# - and a few significantly larger agricultural operations.
#
# ### Business Relevance
#
# Farm-size diversity is extremely valuable because:
# - larger farms may have higher purchasing capacity,
# - different product requirements,
# - and different engagement patterns.
#
# ---
#
# ## Standard Deviation ≈ 1.27
#
# ### Interpretation
#
# Farm sizes vary considerably across growers.
#
# This indicates:
# - heterogeneous agricultural profiles,
# - diverse economic capacity,
# - and varying commercial potential.
#
# ---
#
# ## Quartile Analysis
#
# ### 25% of growers have farm size below 1.10
#
# Represents small-scale growers.
#
# ---
#
# ### 50% of growers have farm size below 1.64
#
# Indicates most growers own relatively modest land sizes.
#
# ---
#
# ### 75% of growers have farm size below 2.47
#
# Suggests that very large farms are relatively uncommon.
#
# ---
#
# # Outlier Observation
#
# ## Maximum Farm Size = 10.92
#
# This value is significantly larger than:
# - the median,
# - and the upper quartile.
#
# ### Interpretation
#
# Possible explanations:
# - large commercial growers,
# - high-value agricultural operators,
# - or statistical outliers.
#
# ### AI/ML Consideration
#
# Outlier handling may be important because:
# - extreme values can influence model training,
# - skew regression models,
# - and affect normalization.
#
# ---
#
# # Combined Numerical Feature Insights
#
# ## Dataset Characteristics
#
# The numerical data suggests the dataset mainly represents:
# - middle-aged growers,
# - small-to-medium farm owners,
# - and diverse agricultural profiles.
#
# ---
#
# # Business Intelligence Potential
#
# The combination of:
# - age,
# - farm size,
# - geographic data,
# - and behavioral features
#
# creates strong potential for:
# - grower segmentation,
# - engagement prediction,
# - sales prioritization,
# - and intelligent recommendation systems.
#
# ---
#
# # AI/ML Readiness Assessment
#
# ## Strengths
#
# The numerical features are:
# - meaningful,
# - interpretable,
# - and business relevant.
#
# They can significantly improve:
# - clustering,
# - predictive modeling,
# - and grower scoring systems.
#
# ---
#
# ## Recommended Preprocessing
#
# ### 1. Handle Missing Farm Sizes
#
# Possible approaches:
# - median imputation,
# - regional estimation,
# - or predictive filling.
#
# ---
#
# ### 2. Detect Outliers
#
# Farm-size outliers should be examined carefully.
#
# Potential techniques:
# - IQR analysis,
# - Z-score analysis,
# - or winsorization.
#
# ---
#
# ### 3. Feature Scaling
#
# Scaling may be useful for:
# - distance-based algorithms,
# - clustering,
# - and neural networks.
#
# ---
#
# # Final Interpretation
#
# The numerical structure of the dataset appears strong and analytically useful.
#
# The features provide:
# - demographic intelligence,
# - economic indicators,
# - and agricultural diversity signals.
#
# Overall, these numerical attributes can become highly influential in:
# - AI-driven grower profiling,
# - intelligent targeting systems,
# - and agricultural decision-support platforms.

# %%
df['state'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='state'>

# %% [markdown]
# # State Distribution Analysis
#
# ## Overview
#
# The bar chart shows the distribution of growers across different states in the dataset. It helps identify which regions contribute the highest number of records and highlights geographic diversity.
#
# ---
#
# # Key Observations
#
# | State | Approximate Count |
# |---|---|
# | Uttar Pradesh | ~980 |
# | Rajasthan | ~755 |
# | Punjab | ~750 |
# | Madhya Pradesh | ~710 |
# | Haryana | ~705 |
# | Maharashtra | ~515 |
# | Gujarat | ~490 |
# | Bihar | ~400 |
# | Karnataka | ~355 |
# | West Bengal | ~335 |
#
# ---
#
# # Interpretation
#
# ## Uttar Pradesh Has the Highest Representation
#
# - Uttar Pradesh contributes the largest number of growers.
# - This suggests strong agricultural presence or better data collection coverage in the region.
#
# ---
#
# ## Rajasthan, Punjab, Haryana, and Madhya Pradesh Show Strong Participation
#
# - These states also have high grower counts.
# - The dataset appears heavily concentrated in northern and central agricultural regions.
#
# ---
#
# ## Lower Representation States
#
# - Karnataka, West Bengal, and Bihar have comparatively fewer records.
# - This may indicate lower sampling coverage or smaller grower participation.
#
# ---
#
# # Business Insights
#
# The state-wise distribution can help with:
#
# - regional market analysis,
# - targeted campaigns,
# - resource allocation,
# - and grower segmentation.
#
# States with higher representation may offer:
# - stronger engagement opportunities,
# - larger customer bases,
# - and higher business potential.
#
# ---
#
# # AI/ML Relevance
#
# The `state` feature is highly valuable for:
# - geographic segmentation,
# - predictive modeling,
# - and regional recommendation systems.
#
# However, unequal distribution across states may introduce regional bias, so balanced preprocessing may be useful.
#
# ---
#
# # Final Interpretation
#
# The dataset demonstrates good geographic diversity with stronger representation from key agricultural states. The `state` feature provides important regional intelligence and can significantly improve agricultural analytics and AI-driven decision systems.

# %%
df['state'].value_counts()
# Out:
# state
# Uttar Pradesh     982
# Rajasthan         755
# Punjab            749
# Madhya Pradesh    709
# Haryana           706
# Maharashtra       518
# Gujarat           490
# Bihar             399
# Karnataka         357
# West Bengal       335
# Name: count, dtype: int64

# %% [markdown]
# # State-wise Distribution Analysis
#
# ## Overview
#
# The `state` column represents the geographic distribution of growers across different Indian states.
#
# Geographic analysis is extremely important in agricultural datasets because:
# - farming practices vary regionally,
# - climate conditions differ,
# - crop cycles change by state,
# - and operational strategies are location dependent.
#
# Understanding state-wise distribution helps evaluate:
# - regional representation,
# - market concentration,
# - operational coverage,
# - and potential geographic bias in the dataset.
#
# ---
#
# # State-wise Grower Distribution
#
# | State | Grower Count |
# |---|---|
# | Uttar Pradesh | 982 |
# | Rajasthan | 755 |
# | Punjab | 749 |
# | Madhya Pradesh | 709 |
# | Haryana | 706 |
# | Maharashtra | 518 |
# | Gujarat | 490 |
# | Bihar | 399 |
# | Karnataka | 357 |
# | West Bengal | 335 |
#
# ---
#
# # Detailed Interpretation
#
# ## 1. Uttar Pradesh — Highest Representation
#
# ### Grower Count = 982
#
# - Uttar Pradesh has the largest number of growers in the dataset.
# - This indicates strong operational or market presence in the region.
#
# ### Agricultural Importance
#
# Uttar Pradesh is one of India's major agricultural states and contributes heavily to:
# - wheat production,
# - sugarcane cultivation,
# - rice farming,
# - and vegetable production.
#
# ### Business Insight
#
# The high grower concentration suggests:
# - significant business activity,
# - strong field-force engagement,
# - or high adoption of agricultural programs.
#
# ### AI/ML Relevance
#
# This state may heavily influence:
# - predictive trends,
# - recommendation systems,
# - and segmentation models.
#
# Care should be taken to avoid regional bias during model training.
#
# ---
#
# ## 2. Rajasthan
#
# ### Grower Count = 755
#
# - Rajasthan has the second-highest representation.
#
# ### Agricultural Characteristics
#
# Rajasthan agriculture is often influenced by:
# - arid climate conditions,
# - water scarcity,
# - and drought-resistant crop cultivation.
#
# ### Business Importance
#
# This region may require:
# - climate-specific recommendations,
# - water-efficient product strategies,
# - and targeted field-force planning.
#
# ---
#
# ## 3. Punjab
#
# ### Grower Count = 749
#
# - Punjab has nearly equal representation to Rajasthan.
#
# ### Agricultural Importance
#
# Punjab is one of India's most agriculturally advanced states.
#
# Known for:
# - high mechanization,
# - intensive farming,
# - and large-scale wheat/rice production.
#
# ### Business Insight
#
# Growers from Punjab may exhibit:
# - higher technology adoption,
# - greater product awareness,
# - and stronger engagement potential.
#
# ---
#
# ## 4. Madhya Pradesh
#
# ### Grower Count = 709
#
# - Madhya Pradesh contributes a substantial share of growers.
#
# ### Agricultural Characteristics
#
# The state supports:
# - soybean farming,
# - wheat cultivation,
# - pulses,
# - and oilseed production.
#
# ### AI/ML Importance
#
# This region adds agricultural diversity to the dataset.
#
# ---
#
# ## 5. Haryana
#
# ### Grower Count = 706
#
# - Haryana shows strong representation similar to Madhya Pradesh.
#
# ### Agricultural Importance
#
# Haryana is known for:
# - mechanized farming,
# - irrigation-based agriculture,
# - and high agricultural productivity.
#
# ### Business Relevance
#
# This state may represent growers with:
# - relatively higher digital accessibility,
# - stronger purchasing capacity,
# - and higher engagement rates.
#
# ---
#
# ## 6. Maharashtra
#
# ### Grower Count = 518
#
# - Maharashtra has moderate representation.
#
# ### Agricultural Diversity
#
# This state supports:
# - cotton,
# - sugarcane,
# - soybean,
# - horticulture,
# - and fruit cultivation.
#
# ### Business Insight
#
# The region may provide:
# - crop diversity,
# - varied grower profiles,
# - and multi-season agricultural patterns.
#
# ---
#
# ## 7. Gujarat
#
# ### Grower Count = 490
#
# - Gujarat contributes a balanced number of growers.
#
# ### Agricultural Importance
#
# Known for:
# - cotton,
# - groundnut,
# - and cash-crop cultivation.
#
# ### Business Potential
#
# Growers may have:
# - commercial farming orientation,
# - export-linked agriculture,
# - and irrigation-supported farming systems.
#
# ---
#
# ## 8. Bihar
#
# ### Grower Count = 399
#
# - Bihar has comparatively lower representation.
#
# ### Interpretation
#
# This may indicate:
# - limited operational penetration,
# - lower data collection coverage,
# - or smaller digital participation.
#
# ### Business Opportunity
#
# Lower representation may also signal:
# - future market expansion potential,
# - underserved grower communities,
# - and outreach opportunities.
#
# ---
#
# ## 9. Karnataka
#
# ### Grower Count = 357
#
# - Karnataka contributes a smaller portion of the dataset.
#
# ### Agricultural Characteristics
#
# Karnataka supports:
# - coffee,
# - millet,
# - pulses,
# - and horticulture farming.
#
# ### Strategic Importance
#
# The southern geographic representation improves dataset diversity.
#
# ---
#
# ## 10. West Bengal
#
# ### Grower Count = 335
#
# - West Bengal has the lowest representation among listed states.
#
# ### Interpretation
#
# This could indicate:
# - limited operational reach,
# - smaller sample collection,
# - or lower participation levels.
#
# ### Business Insight
#
# The region may still provide valuable:
# - rice cultivation patterns,
# - eastern India agricultural insights,
# - and unique crop-season behavior.
#
# ---
#
# # Distribution Pattern Analysis
#
# ## Geographic Diversity
#
# The dataset covers multiple agricultural zones across India, including:
# - northern regions,
# - western regions,
# - central India,
# - eastern India,
# - and southern states.
#
# This improves:
# - dataset diversity,
# - model generalization,
# - and agricultural variability.
#
# ---
#
# # Representation Imbalance
#
# ## Observation
#
# Some states contribute significantly more growers than others.
#
# ### Potential Impact
#
# This imbalance may:
# - bias machine learning models,
# - overrepresent certain regional behaviors,
# - and reduce fairness in predictive systems.
#
# ### AI/ML Recommendation
#
# Possible solutions:
# - stratified sampling,
# - weighted modeling,
# - or balanced training datasets.
#
# ---
#
# # Business Intelligence Insights
#
# ## Strong Presence States
#
# The dataset appears heavily concentrated in:
# - Uttar Pradesh,
# - Rajasthan,
# - Punjab,
# - Madhya Pradesh,
# - and Haryana.
#
# These states may represent:
# - core operational markets,
# - high-priority agricultural regions,
# - or stronger grower engagement zones.
#
# ---
#
# # Strategic Value of Geographic Features
#
# State-level information can support:
# - localized recommendations,
# - demand forecasting,
# - territory optimization,
# - field-force intelligence,
# - and region-specific campaign planning.
#
# ---
#
# # Final Interpretation
#
# The state distribution demonstrates strong agricultural coverage across major farming regions of India.
#
# The dataset reflects:
# - geographic diversity,
# - operational concentration,
# - and regional agricultural variation.
#
# Overall, the `state` feature appears highly valuable for:
# - AI-driven agricultural analytics,
# - grower segmentation,
# - regional targeting,
# - and intelligent field-force optimization systems.

# %%
df['campaign_attendance_date'].min()
# Out:
# '2025-09-29'

# %%
df['campaign_attendance_date'].max()
# Out:
# '2026-03-29'

# %% [markdown]
# # Campaign Attendance Date Range Analysis
#
# ## Overview
#
# The `campaign_attendance_date` feature represents the dates on which growers attended campaigns or events.
#
# Analyzing the date range helps understand:
# - campaign activity duration,
# - operational timeline,
# - seasonal coverage,
# - and data recency.
#
# ---
#
# # Date Range Summary
#
# | Metric | Value |
# |---|---|
# | Earliest Date | 2025-09-29 |
# | Latest Date | 2026-03-29 |
#
# ---
#
# # Interpretation
#
# ## Campaign Duration
#
# - The dataset spans approximately 6 months of campaign activity.
# - This indicates sustained operational engagement over multiple months.
#
# ---
#
# ## Seasonal Coverage
#
# The timeline covers:
# - late 2025,
# - year-end activity,
# - and early 2026 operations.
#
# ### Business Insight
#
# This period may capture:
# - seasonal agricultural campaigns,
# - sowing or harvesting cycles,
# - and region-specific engagement programs.
#
# ---
#
# # Data Quality Observation
#
# - The dates appear structured and chronologically consistent.
# - No abnormal historical or future timestamps are visible.
#
# This improves:
# - temporal reliability,
# - trend analysis capability,
# - and forecasting readiness.
#
# ---
#
# # AI/ML Relevance
#
# The `campaign_attendance_date` feature can support:
# - time-series analysis,
# - campaign trend monitoring,
# - seasonal prediction,
# - and engagement forecasting.
#
# Additional features can also be engineered, such as:
# - month,
# - quarter,
# - season,
# - and campaign frequency.
#
# ---
#
# # Final Interpretation
#
# The dataset captures campaign attendance activity across a well-defined 6-month operational window. The temporal information provides strong potential for:
# - seasonal analytics,
# - campaign performance evaluation,
# - and AI-driven engagement prediction.

# %% [markdown]
# # retailers.csv Analysis

# %%
df = pd.read_csv("../datasets/retailers.csv")

# %%
df.head()
# Out:
#   retailer_id territory_id  state district      tehsil
# 0   RTL_00001     TER_0001  Bihar    Patna  Patna_T012
# 1   RTL_00002     TER_0001  Bihar    Patna  Patna_T004
# 2   RTL_00003     TER_0001  Bihar    Patna  Patna_T002
# 3   RTL_00004     TER_0001  Bihar    Patna  Patna_T007
# 4   RTL_00005     TER_0001  Bihar    Patna  Patna_T007

# %% [markdown]
# # Retailer Dataset Structure Analysis
#
# ## Overview
#
# The dataset appears to represent retailer-level operational and geographic information.
#
# It contains the following columns:
#
# - `retailer_id`
# - `territory_id`
# - `state`
# - `district`
# - `tehsil`
#
# This dataset is strongly location-oriented and appears designed for:
# - field-force management,
# - retailer tracking,
# - territory planning,
# - and operational intelligence systems.
#
# ---
#
# # Column-wise Feature Analysis
#
# ## 1. Retailer Identification Feature
#
# ### `retailer_id`
#
# ### Description
#
# - Represents a unique identifier assigned to each retailer.
# - Example:
#   - `RTL_00001`
#   - `RTL_00002`
#
# ### Importance
#
# This column is essential for:
# - uniquely identifying retailers,
# - tracking retailer activity,
# - linking operational records,
# - and maintaining retailer-level analytics.
#
# ### Business Applications
#
# Retailer IDs can support:
# - retailer performance monitoring,
# - sales tracking,
# - retailer engagement systems,
# - and supply-chain management.
#
# ### AI/ML Relevance
#
# This feature may later help in:
# - retailer profiling,
# - retailer segmentation,
# - and recommendation systems.
#
# ---
#
# ## 2. Territory Feature
#
# ### `territory_id`
#
# ### Description
#
# - Represents the operational territory assigned to retailers.
# - Example:
#   - `TER_0001`
#
# ### Importance
#
# Territory information is highly important in:
# - sales-force operations,
# - route optimization,
# - and field planning.
#
# ### Business Significance
#
# Territory segmentation helps organizations:
# - distribute field-force workload,
# - assign managers efficiently,
# - optimize regional operations,
# - and monitor territory-level performance.
#
# ### AI/ML Applications
#
# This feature may support:
# - territory prioritization,
# - workload prediction,
# - and intelligent route optimization systems.
#
# ---
#
# # 3. Geographic Features
#
# ## Geographic Columns
#
# - `state`
# - `district`
# - `tehsil`
#
# ---
#
# ## Importance of Geographic Features
#
# Agricultural and retailer operations are highly geography dependent.
#
# These features provide:
# - hierarchical location structure,
# - regional operational intelligence,
# - and market segmentation capability.
#
# ---
#
# ## `state`
#
# ### Description
#
# Represents the state where the retailer operates.
#
# ### Example
#
# - `Bihar`
#
# ### Business Importance
#
# State-level information helps:
# - regional sales planning,
# - state-wise demand forecasting,
# - and operational expansion analysis.
#
# ### AI/ML Relevance
#
# Useful for:
# - regional modeling,
# - geographic clustering,
# - and location-aware recommendation systems.
#
# ---
#
# ## `district`
#
# ### Description
#
# Represents the district within the state.
#
# ### Example
#
# - `Patna`
#
# ### Importance
#
# District-level granularity improves:
# - local market analysis,
# - operational monitoring,
# - and territory intelligence.
#
# ### Business Applications
#
# Supports:
# - district performance analysis,
# - localized inventory planning,
# - and targeted outreach strategies.
#
# ---
#
# ## `tehsil`
#
# ### Description
#
# Represents the tehsil or sub-district area.
#
# ### Example
#
# - `Patna_T012`
# - `Patna_T004`
#
# ### Importance
#
# Tehsil-level data provides fine-grained geographic segmentation.
#
# This is extremely valuable for:
# - micro-level field-force planning,
# - local retailer clustering,
# - and precision agricultural operations.
#
# ### Operational Significance
#
# Tehsil information can help:
# - assign retailers to field agents,
# - optimize retailer visit scheduling,
# - and improve local market penetration.
#
# ---
#
# # Sample Record Interpretation
#
# ## Example Record
#
# | retailer_id | territory_id | state | district | tehsil |
# |---|---|---|---|---|
# | RTL_00001 | TER_0001 | Bihar | Patna | Patna_T012 |
#
# ---
#
# ## Interpretation
#
# This record indicates:
# - retailer `RTL_00001`
# - belongs to territory `TER_0001`
# - operates in Bihar state,
# - within Patna district,
# - specifically inside tehsil `Patna_T012`.
#
# This hierarchical structure enables:
# - detailed geographic tracking,
# - localized operational intelligence,
# - and scalable retailer management.
#
# ---
#
# # Dataset Characteristics
#
# ## Strong Geographic Organization
#
# The dataset follows a clear hierarchical structure:
#
# ```text
# State → District → Tehsil → Retailer

# %%
df.shape
# Out:
# (4000, 5)

# %% [markdown]
# # Dataset Size Analysis
#
# ## Shape of Dataset
#
# - The dataset contains:
#   - 4000 rows
#   - 5 columns
#
# ---
#
# ## Observations
#
# - A dataset size of 4000 records is sufficient for meaningful exploratory data analysis and operational analytics.
# - The number of rows indicates that the dataset likely represents a substantial retailer network distributed across multiple geographic regions.
# - The dataset size is appropriate for:
#   - geographic analysis,
#   - territory mapping,
#   - retailer segmentation,
#   - and operational intelligence tasks.
#
# ---
#
# ## Feature Availability
#
# - The dataset contains 5 columns representing:
#   - retailer identification,
#   - territory allocation,
#   - and hierarchical geographic information.
#
# - The available features provide strong support for:
#   - territory-based analytics,
#   - retailer distribution analysis,
#   - and field-force planning systems.
#
# ---
#
# ## Machine Learning Relevance
#
# - A dataset with 4000 records provides enough samples for:
#   - clustering experiments,
#   - geographic segmentation,
#   - territory optimization models,
#   - and operational prediction systems.
#
# - The dataset size is manageable for:
#   - local machine learning experimentation,
#   - Jupyter Notebook workflows,
#   - and hackathon-scale AI development.
#
# ---
#
# ## Business Relevance
#
# - The dataset scale suggests that the organization maintains a broad retailer network across multiple operational regions.
# - Geographic hierarchy combined with territory mapping may help improve:
#   - field-force allocation,
#   - route optimization,
#   - retailer prioritization,
#   - and operational efficiency.
#
# ---
#
# ## Overall Interpretation
#
# - The dataset appears structured, operationally valuable, and geographically organized.
# - Although compact in terms of feature count, the dataset provides strong foundational support for:
#   - retailer intelligence systems,
#   - territory management,
#   - operational analytics,
#   - and AI-assisted field-force optimization workflows.

# %%
df.columns
# Out:
# Index(['retailer_id', 'territory_id', 'state', 'district', 'tehsil'], dtype='str')

# %% [markdown]
# # Categorical Feature Analysis
#
# ## Overview
#
# The dataset contains multiple geographic and operational categorical features:
#
# - `retailer_id`
# - `territory_id`
# - `state`
# - `district`
# - `tehsil`
#
# These features provide important regional and hierarchical information that can support:
# - geographic analysis,
# - retailer segmentation,
# - territory performance tracking,
# - and regional AI/ML modeling.
#
# ---
#
# # 1. Retailer ID Analysis
#
# ## Feature: `retailer_id`
#
# ### Interpretation
#
# - Represents unique retailer identifiers.
# - Helps distinguish individual retailers in the dataset.
# - Likely acts as a high-cardinality categorical feature.
#
# ### Business Importance
#
# This feature can support:
# - retailer-level tracking,
# - customer relationship analysis,
# - sales attribution,
# - and engagement monitoring.
#
# ### AI/ML Relevance
#
# `retailer_id` may be useful for:
# - retailer behavior modeling,
# - recommendation systems,
# - and retailer segmentation.
#
# However, due to high uniqueness, encoding techniques such as:
# - label encoding,
# - frequency encoding,
# - or embeddings
#
# may be required.
#
# ---
#
# # 2. Territory ID Analysis
#
# ## Feature: `territory_id`
#
# ### Interpretation
#
# - Represents operational or sales territories.
# - Groups growers and retailers into manageable regions.
#
# ### Business Importance
#
# This feature is useful for:
# - territory performance analysis,
# - operational planning,
# - and sales-force management.
#
# ### AI/ML Relevance
#
# Territory-level patterns may improve:
# - regional forecasting,
# - campaign optimization,
# - and demand prediction.
#
# ---
#
# # 3. State Analysis
#
# ## Feature: `state`
#
# ### Interpretation
#
# - Represents state-level geographic information.
# - Provides macro-regional agricultural insights.
#
# ### Business Importance
#
# State-level analysis helps with:
# - regional targeting,
# - market expansion,
# - and policy-level planning.
#
# ### AI/ML Relevance
#
# The `state` feature can significantly improve:
# - geographic segmentation,
# - regional predictions,
# - and behavioral analysis.
#
# ---
#
# # 4. District Analysis
#
# ## Feature: `district`
#
# ### Interpretation
#
# - Provides more granular regional information within states.
# - Captures localized agricultural patterns.
#
# ### Business Importance
#
# District-level insights can help identify:
# - high-performing markets,
# - operational hotspots,
# - and regional demand differences.
#
# ### AI/ML Relevance
#
# District information improves:
# - localization accuracy,
# - micro-segmentation,
# - and predictive precision.
#
# ---
#
# # 5. Tehsil Analysis
#
# ## Feature: `tehsil`
#
# ### Interpretation
#
# - Represents sub-district administrative regions.
# - Offers fine-grained geographic intelligence.
#
# ### Business Importance
#
# Tehsil-level analysis enables:
# - hyperlocal targeting,
# - localized interventions,
# - and detailed market understanding.
#
# ### AI/ML Relevance
#
# This feature may improve:
# - location-sensitive predictions,
# - clustering,
# - and precision recommendation systems.
#
# ---
#
# # Overall Observations
#
# The categorical geographic hierarchy:
#
# `State → District → Tehsil`
#
# creates strong potential for:
# - hierarchical analysis,
# - regional segmentation,
# - and advanced geographic modeling.
#
# The combination of retailer and territory identifiers further strengthens:
# - operational intelligence,
# - sales analysis,
# - and grower-network analytics.
#
# ---
#
# # Final Interpretation
#
# The categorical features in the dataset are highly valuable and business relevant. They provide multiple levels of geographic and operational intelligence that can significantly enhance:
# - exploratory analysis,
# - business decision-making,
# - and AI/ML model performance.

# %%
df.isnull().sum()
# Out:
# retailer_id     0
# territory_id    0
# state           0
# district        0
# tehsil          0
# dtype: int64

# %% [markdown]
# # Missing Value Analysis
#
# ## Overview
#
# Missing value analysis helps evaluate:
# - data completeness,
# - feature reliability,
# - and dataset quality.
#
# A dataset with fewer missing values is generally more suitable for:
# - statistical analysis,
# - machine learning,
# - and business intelligence applications.
#
# ---
#
# # Missing Value Summary
#
# | Feature | Missing Values |
# |---|---|
# | retailer_id | 0 |
# | territory_id | 0 |
# | state | 0 |
# | district | 0 |
# | tehsil | 0 |
#
# ---
#
# # Interpretation
#
# ## No Missing Values Detected
#
# All categorical features contain complete information with:
# - zero null values,
# - full geographic coverage,
# - and strong data consistency.
#
# ---
#
# # Feature-Level Observations
#
# ## `retailer_id`
#
# - Every record is linked to a retailer.
# - Ensures reliable retailer-level analysis.
#
# ---
#
# ## `territory_id`
#
# - Territory information is fully available.
# - Supports accurate regional segmentation and operational analysis.
#
# ---
#
# ## `state`, `district`, and `tehsil`
#
# - Geographic hierarchy is completely populated.
# - Enables multi-level regional analysis without preprocessing concerns.
#
# ---
#
# # Business Importance
#
# Complete geographic and operational data improves:
# - reporting accuracy,
# - regional targeting,
# - territory management,
# - and segmentation quality.
#
# The absence of missing values also reduces:
# - preprocessing complexity,
# - data-cleaning effort,
# - and information loss.
#
# ---
#
# # AI/ML Relevance
#
# Since no null values exist:
# - imputation is unnecessary,
# - encoding becomes simpler,
# - and model training reliability improves.
#
# This strengthens:
# - predictive modeling,
# - clustering,
# - and recommendation systems.
#
# ---
#
# # Final Interpretation
#
# The categorical features demonstrate excellent data quality with complete information across all records. This makes the dataset highly reliable for:
# - exploratory analysis,
# - geographic intelligence,
# - and AI/ML applications.

# %%
df.dtypes
# Out:
# retailer_id     str
# territory_id    str
# state           str
# district        str
# tehsil          str
# dtype: object

# %% [markdown]
# # Data Type Analysis
#
# ## Overview
#
# Data type analysis helps verify whether dataset features are stored in appropriate formats for:
# - analysis,
# - preprocessing,
# - visualization,
# - and machine learning.
#
# Correct data types improve:
# - data consistency,
# - computational efficiency,
# - and analytical reliability.
#
# ---
#
# # Feature Data Types
#
# | Feature | Data Type |
# |---|---|
# | retailer_id | object (string) |
# | territory_id | object (string) |
# | state | object (string) |
# | district | object (string) |
# | tehsil | object (string) |
#
# ---
#
# # Interpretation
#
# ## All Features Are Categorical
#
# All columns are stored as `object` type, which indicates:
# - text-based categorical data,
# - identifiers,
# - or geographic labels.
#
# This is appropriate because:
# - retailer and territory IDs are non-numeric identifiers,
# - while state, district, and tehsil represent categorical geographic regions.
#
# ---
#
# # Feature-Level Observations
#
# ## `retailer_id`
#
# - Stored as string values.
# - Prevents accidental numerical operations on identifiers.
#
# ### Business Importance
#
# Useful for:
# - retailer tracking,
# - grouping,
# - and retailer-level analytics.
#
# ---
#
# ## `territory_id`
#
# - Properly stored as categorical text data.
# - Supports operational segmentation and territory analysis.
#
# ---
#
# ## Geographic Features
#
# ### `state`, `district`, `tehsil`
#
# These features are correctly represented as categorical variables because they describe:
# - locations,
# - administrative regions,
# - and geographic hierarchies.
#
# ---
#
# # AI/ML Relevance
#
# Since all features are categorical, machine learning models will require:
# - label encoding,
# - one-hot encoding,
# - or embedding techniques.
#
# These features can contribute significantly to:
# - regional clustering,
# - segmentation,
# - and predictive modeling.
#
# ---
#
# # Data Quality Observation
#
# The dataset demonstrates strong structural consistency because:
# - all categorical variables are stored correctly,
# - identifiers are not misclassified as numeric values,
# - and geographic information remains interpretable.
#
# ---
#
# # Final Interpretation
#
# The dataset’s data types are well-structured and appropriate for categorical geographic and operational analysis. The current format supports:
# - clean preprocessing,
# - reliable feature engineering,
# - and effective AI/ML integration.

# %%
df.describe()
# Out:
#        retailer_id territory_id          state   district       tehsil
# count         4000         4000           4000       4000         4000
# unique        4000          500             10         33         2849
# top      RTL_00001     TER_0016  Uttar Pradesh  Bharatpur  Ratlam_T055
# freq             1           11            622        140            5

# %% [markdown]
# # Categorical Feature Statistical Analysis
#
# ## Overview
#
# The statistical summary of categorical features provides insights into:
# - uniqueness,
# - frequency distribution,
# - dominant categories,
# - and geographic diversity.
#
# These observations are useful for:
# - segmentation,
# - operational analysis,
# - and AI/ML preprocessing.
#
# ---
#
# # Statistical Summary
#
# | Feature | Count | Unique | Top Value | Frequency |
# |---|---|---|---|---|
# | retailer_id | 4000 | 4000 | RTL_00001 | 1 |
# | territory_id | 4000 | 500 | TER_0016 | 11 |
# | state | 4000 | 10 | Uttar Pradesh | 622 |
# | district | 4000 | 33 | Bharatpur | 140 |
# | tehsil | 4000 | 2849 | Ratlam_T055 | 5 |
#
# ---
#
# # Interpretation
#
# # 1. Retailer ID Analysis
#
# ## Unique Retailers = 4000
#
# - Every retailer ID is unique.
# - No retailer appears more than once in the dataset.
#
# ### Business Insight
#
# This indicates:
# - highly granular retailer-level data,
# - strong entity separation,
# - and clean retailer identification.
#
# ### AI/ML Relevance
#
# `retailer_id` behaves like a unique identifier and may:
# - help with tracking,
# - but provide limited predictive value directly.
#
# ---
#
# # 2. Territory ID Analysis
#
# ## Unique Territories = 500
#
# - The dataset contains 500 operational territories.
# - The most frequent territory appears 11 times.
#
# ### Interpretation
#
# This suggests:
# - balanced territory distribution,
# - moderate operational diversity,
# - and relatively even territorial representation.
#
# ### Business Importance
#
# Territory-level analysis can support:
# - performance comparison,
# - operational planning,
# - and sales optimization.
#
# ---
#
# # 3. State Analysis
#
# ## Unique States = 10
#
# - The dataset spans 10 states.
# - Uttar Pradesh has the highest representation with 622 records.
#
# ### Interpretation
#
# This indicates:
# - strong geographic diversity,
# - but slightly higher concentration in Uttar Pradesh.
#
# ### Business Insight
#
# States with larger representation may:
# - contribute higher business activity,
# - offer stronger engagement opportunities,
# - and influence regional trends.
#
# ---
#
# # 4. District Analysis
#
# ## Unique Districts = 33
#
# - The dataset includes 33 districts.
# - Bharatpur appears most frequently with 140 records.
#
# ### Interpretation
#
# District-level distribution appears moderately concentrated.
#
# ### Business Relevance
#
# District analysis can help identify:
# - high-density agricultural zones,
# - operational hotspots,
# - and region-specific opportunities.
#
# ---
#
# # 5. Tehsil Analysis
#
# ## Unique Tehsils = 2849
#
# - Tehsil data is highly granular.
# - Most tehsils appear very few times.
#
# ### Interpretation
#
# This indicates:
# - extensive geographic spread,
# - detailed regional coverage,
# - and strong localization capability.
#
# ### AI/ML Importance
#
# Fine-grained tehsil information may improve:
# - hyperlocal predictions,
# - recommendation systems,
# - and geographic clustering.
#
# ---
#
# # Overall Dataset Characteristics
#
# The dataset demonstrates:
# - strong geographic diversity,
# - high retailer uniqueness,
# - and detailed regional granularity.
#
# The hierarchical structure:
#
# `State → District → Tehsil`
#
# provides rich opportunities for:
# - regional intelligence,
# - segmentation,
# - and location-based analytics.
#
# ---
#
# # Final Interpretation
#
# The categorical structure of the dataset is highly informative and operationally valuable. The features provide:
# - multi-level geographic intelligence,
# - strong segmentation capability,
# - and excellent support for AI/ML applications.

# %%
df['state'].value_counts()
# Out:
# state
# Uttar Pradesh     622
# Rajasthan         502
# Punjab            498
# Madhya Pradesh    489
# Haryana           475
# Maharashtra       358
# Gujarat           335
# Bihar             255
# Karnataka         237
# West Bengal       229
# Name: count, dtype: int64

# %% [markdown]
# # State-Wise Distribution Analysis
#
# ## Overview
#
# The `state` feature represents the geographic distribution of growers across different states. Analyzing state-wise frequency helps identify:
# - regional concentration,
# - operational coverage,
# - market penetration,
# - and geographic diversity.
#
# ---
#
# # State Frequency Distribution
#
# | State | Count |
# |---|---|
# | Uttar Pradesh | 622 |
# | Rajasthan | 502 |
# | Punjab | 498 |
# | Madhya Pradesh | 489 |
# | Haryana | 475 |
# | Maharashtra | 358 |
# | Gujarat | 335 |
# | Bihar | 255 |
# | Karnataka | 237 |
# | West Bengal | 229 |
#
# ---
#
# # Interpretation
#
# ## Uttar Pradesh Has the Highest Representation
#
# - Uttar Pradesh contains the largest number of records.
# - This suggests strong agricultural activity or better operational coverage in the region.
#
# ### Business Insight
#
# The state may represent:
# - a major target market,
# - high grower engagement,
# - or strong retailer presence.
#
# ---
#
# ## Rajasthan, Punjab, Madhya Pradesh, and Haryana Show Strong Participation
#
# - These states also contribute significantly to the dataset.
# - The distribution indicates strong representation from northern and central agricultural regions.
#
# ### Business Importance
#
# These regions may offer:
# - high commercial potential,
# - stronger market opportunities,
# - and stable grower networks.
#
# ---
#
# ## Moderate Representation States
#
# ### Maharashtra and Gujarat
#
# - These states show moderate participation levels.
# - They may represent expanding or selectively targeted markets.
#
# ---
#
# ## Lower Representation States
#
# ### Bihar, Karnataka, and West Bengal
#
# - These states contain comparatively fewer records.
# - This may indicate:
#   - lower operational penetration,
#   - smaller grower networks,
#   - or limited sampling coverage.
#
# ---
#
# # Geographic Diversity Insights
#
# The dataset includes growers from:
# - northern India,
# - western India,
# - central India,
# - eastern India,
# - and southern India.
#
# This improves:
# - regional diversity,
# - segmentation quality,
# - and geographic intelligence.
#
# ---
#
# # AI/ML Relevance
#
# The `state` feature is highly valuable for:
# - regional clustering,
# - geographic segmentation,
# - demand forecasting,
# - and personalized recommendation systems.
#
# However, unequal distribution across states may introduce:
# - regional bias,
# - class imbalance,
# - or skewed predictions.
#
# Balanced preprocessing techniques may help address these challenges.
#
# ---
#
# # Final Interpretation
#
# The state-wise distribution demonstrates strong representation from major agricultural regions while maintaining meaningful geographic diversity. The `state` feature provides critical regional intelligence and can significantly improve:
# - business analytics,
# - operational planning,
# - and AI/ML model performance.

# %%
df['state'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='state'>

# %% [markdown]
# # State Distribution Visualization Analysis
#
# ## Overview
#
# The bar chart visualizes the frequency distribution of growers across different states in the dataset. It provides a clear comparison of regional representation and highlights dominant agricultural regions.
#
# ---
#
# # Key Observations
#
# | State | Approximate Count |
# |---|---|
# | Uttar Pradesh | ~620 |
# | Rajasthan | ~500 |
# | Punjab | ~500 |
# | Madhya Pradesh | ~490 |
# | Haryana | ~475 |
# | Maharashtra | ~360 |
# | Gujarat | ~335 |
# | Bihar | ~255 |
# | Karnataka | ~240 |
# | West Bengal | ~230 |
#
# ---
#
# # Interpretation
#
# ## Uttar Pradesh Has the Highest Representation
#
# - Uttar Pradesh shows the tallest bar in the chart.
# - This indicates the highest grower concentration in the dataset.
#
# ### Business Insight
#
# This region may represent:
# - a major agricultural market,
# - strong retailer activity,
# - or better operational penetration.
#
# ---
#
# ## Strong Presence from Northern and Central States
#
# ### Rajasthan, Punjab, Madhya Pradesh, and Haryana
#
# - These states also show high participation.
# - The dataset appears heavily concentrated in agriculturally active northern regions.
#
# ### Business Importance
#
# These states may contribute:
# - significant market opportunities,
# - strong grower engagement,
# - and higher commercial potential.
#
# ---
#
# ## Moderate Representation States
#
# ### Maharashtra and Gujarat
#
# - These states have moderate grower counts.
# - They may represent secondary but important agricultural markets.
#
# ---
#
# ## Lower Representation States
#
# ### Bihar, Karnataka, and West Bengal
#
# - These states show comparatively smaller participation.
# - Possible reasons include:
#   - lower sampling coverage,
#   - smaller grower networks,
#   - or regional operational limitations.
#
# ---
#
# # Visualization Insights
#
# The chart effectively highlights:
# - regional imbalance,
# - dominant agricultural states,
# - and geographic diversity.
#
# The decreasing bar pattern clearly shows how grower concentration varies across regions.
#
# ---
#
# # AI/ML Relevance
#
# The `state` feature can significantly improve:
# - geographic segmentation,
# - regional recommendation systems,
# - and predictive analytics.
#
# However, uneven distribution across states may introduce:
# - regional bias,
# - class imbalance,
# - and skewed model learning.
#
# Balancing techniques may help improve model fairness.
#
# ---
#
# # Final Interpretation
#
# The visualization demonstrates strong geographic diversity with higher concentration in key agricultural states. The `state` feature provides valuable regional intelligence and can play an important role in:
# - business analytics,
# - operational planning,
# - and AI-driven agricultural decision systems.

# %% [markdown]
# # digital_funnel_weekly.csv Analysis

# %%
df = pd.read_csv("../datasets/digital_funnel_weekly.csv")

# %%
df.head()
# Out:
#       campaign_id week_start_date  social_post_impression  \
# 0  CMP_RABI25_001      2025-10-06                   29663
# 1  CMP_RABI25_001      2025-10-13                   14618
# 2  CMP_RABI25_001      2025-10-20                   36445
# 3  CMP_RABI25_001      2025-10-27                   32487
# 4  CMP_RABI25_001      2025-11-03                   18904
#
#    landing_page_visits  lead_form_submission campaign_crop campaign_product
# 0                  665                    47         wheat      Topik 15 WP
# 1                  279                    14         wheat      Topik 15 WP
# 2                  753                    36         wheat      Topik 15 WP
# 3                  478                    42         wheat      Topik 15 WP
# 4                  371                    14         wheat      Topik 15 WP

# %% [markdown]
# # Digital Funnel Weekly Dataset Analysis
#
# ## Overview
#
# The `digital_funnel_weekly.csv` dataset contains weekly digital campaign performance metrics related to:
# - social media engagement,
# - website traffic,
# - and lead generation activities.
#
# The dataset combines:
# - marketing funnel metrics,
# - campaign information,
# - crop targeting,
# - and product promotion data.
#
# ---
#
# # Dataset Features
#
# | Feature | Description |
# |---|---|
# | campaign_id | Unique campaign identifier |
# | week_start_date | Weekly campaign tracking date |
# | social_post_impression | Number of social media impressions |
# | landing_page_visits | Number of website visits |
# | lead_form_submission | Number of lead submissions |
# | campaign_crop | Crop targeted by the campaign |
# | campaign_product | Product promoted in the campaign |
#
# ---
#
# # Initial Observations
#
# ## Campaign Tracking Structure
#
# - The dataset is organized at a weekly level.
# - Each row represents campaign performance for a specific week.
#
# ### Business Importance
#
# This structure supports:
# - weekly performance monitoring,
# - trend analysis,
# - and campaign optimization.
#
# ---
#
# # Funnel Performance Insights
#
# ## Social Post Impressions
#
# - Impressions are significantly higher than visits and submissions.
# - This reflects the top stage of the marketing funnel.
#
# ### Interpretation
#
# High impressions indicate:
# - strong campaign visibility,
# - broad audience reach,
# - and active digital engagement.
#
# ---
#
# ## Landing Page Visits
#
# - Website visits are much lower than impressions.
# - This suggests only a portion of viewers engage further.
#
# ### Business Insight
#
# The difference between impressions and visits may reflect:
# - click-through effectiveness,
# - content quality,
# - or audience relevance.
#
# ---
#
# ## Lead Form Submissions
#
# - Lead submissions are the smallest metric in the funnel.
# - This is expected because conversions typically decrease at each stage.
#
# ### AI/ML Importance
#
# Lead conversion analysis can support:
# - funnel optimization,
# - conversion prediction,
# - and campaign effectiveness modeling.
#
# ---
#
# # Crop and Product Targeting
#
# ## Campaign Crop
#
# - Campaigns are crop-specific.
# - Example shown: `wheat`.
#
# ### Business Relevance
#
# Crop-based targeting enables:
# - personalized marketing,
# - seasonal campaigns,
# - and precision engagement strategies.
#
# ---
#
# ## Campaign Product
#
# - Campaigns promote specific agricultural products.
# - Example shown: `Topik 15 WP`.
#
# ### Strategic Importance
#
# This supports:
# - product-level performance analysis,
# - demand forecasting,
# - and recommendation systems.
#
# ---
#
# # Temporal Insights
#
# ## Weekly Tracking
#
# The `week_start_date` feature enables:
# - time-series analysis,
# - trend monitoring,
# - seasonal evaluation,
# - and campaign progression tracking.
#
# ---
#
# # AI/ML Relevance
#
# This dataset is highly valuable for:
# - conversion prediction,
# - campaign optimization,
# - lead forecasting,
# - and digital marketing analytics.
#
# Potential engineered features include:
# - conversion rate,
# - click-through rate,
# - weekly growth trends,
# - and campaign efficiency scores.
#
# ---
#
# # Final Interpretation
#
# The `digital_funnel_weekly.csv` dataset provides a structured view of digital marketing performance across weekly agricultural campaigns. It contains strong business and analytical value for:
# - marketing intelligence,
# - campaign optimization,
# - and AI-driven engagement prediction.

# %%
df.shape
# Out:
# (104, 7)

# %% [markdown]
# # Dataset Shape Analysis
#
# ## Overview
#
# The `shape` of a dataset represents:
# - the number of rows (records),
# - and the number of columns (features).
#
# This helps understand:
# - dataset size,
# - feature availability,
# - and overall analytical scope.
#
# ---
#
# # Dataset Shape
#
# | Metric | Value |
# |---|---|
# | Number of Rows | 104 |
# | Number of Columns | 7 |
#
# ---
#
# # Interpretation
#
# ## Total Records = 104
#
# - The dataset contains 104 weekly campaign records.
# - Each row represents campaign performance for a specific week.
#
# ### Business Insight
#
# This provides sufficient data for:
# - trend analysis,
# - campaign monitoring,
# - and funnel performance evaluation.
#
# ---
#
# ## Total Features = 7
#
# The dataset includes:
# - campaign identifiers,
# - temporal information,
# - marketing funnel metrics,
# - crop targeting,
# - and product details.
#
# ### Analytical Importance
#
# These features collectively support:
# - marketing analytics,
# - conversion tracking,
# - and predictive modeling.
#
# ---
#
# # Data Structure Observation
#
# The dataset appears:
# - compact,
# - well-structured,
# - and suitable for exploratory analysis.
#
# The feature count is manageable and interpretable, making preprocessing simpler.
#
# ---
#
# # AI/ML Relevance
#
# Although the dataset is relatively small, it can still support:
# - basic forecasting,
# - conversion analysis,
# - campaign effectiveness modeling,
# - and dashboard reporting.
#
# Additional data over longer time periods could further improve:
# - model reliability,
# - trend stability,
# - and predictive accuracy.
#
# ---
#
# # Final Interpretation
#
# The dataset contains 104 observations and 7 meaningful features, providing a clean and organized structure for:
# - digital funnel analysis,
# - campaign performance evaluation,
# - and AI-driven marketing insights.

# %%
df.columns
# Out:
# Index(['campaign_id', 'week_start_date', 'social_post_impression',
#        'landing_page_visits', 'lead_form_submission', 'campaign_crop',
#        'campaign_product'],
#       dtype='str')

# %% [markdown]
# # Feature Analysis
#
# ## Overview
#
# The dataset contains 7 features related to:
# - digital marketing campaigns,
# - funnel performance metrics,
# - crop targeting,
# - and agricultural product promotion.
#
# These features provide valuable insights for:
# - campaign analytics,
# - lead generation analysis,
# - and AI/ML-based marketing optimization.
#
# ---
#
# # Dataset Features
#
# | Feature | Description |
# |---|---|
# | campaign_id | Unique identifier for each campaign |
# | week_start_date | Weekly tracking date for campaign performance |
# | social_post_impression | Total number of social media impressions |
# | landing_page_visits | Number of visits to the landing page |
# | lead_form_submission | Number of lead form submissions |
# | campaign_crop | Crop targeted in the campaign |
# | campaign_product | Product promoted in the campaign |
#
# ---
#
# # Feature-Level Interpretation
#
# ## `campaign_id`
#
# - Identifies individual campaigns uniquely.
# - Useful for campaign tracking and performance comparison.
#
# ### Business Importance
#
# Supports:
# - campaign monitoring,
# - performance benchmarking,
# - and historical analysis.
#
# ---
#
# ## `week_start_date`
#
# - Represents weekly campaign activity periods.
# - Enables time-based analysis and trend tracking.
#
# ### AI/ML Relevance
#
# Useful for:
# - time-series analysis,
# - seasonal trend detection,
# - and forecasting.
#
# ---
#
# ## `social_post_impression`
#
# - Measures audience reach on digital platforms.
# - Represents the top stage of the marketing funnel.
#
# ### Business Insight
#
# Higher impressions indicate:
# - broader campaign visibility,
# - stronger awareness generation,
# - and higher digital exposure.
#
# ---
#
# ## `landing_page_visits`
#
# - Tracks user engagement after viewing campaign content.
# - Represents audience interaction quality.
#
# ### Analytical Importance
#
# Useful for evaluating:
# - click-through behavior,
# - engagement effectiveness,
# - and traffic generation.
#
# ---
#
# ## `lead_form_submission`
#
# - Measures successful lead conversions.
# - Represents the final stage of the marketing funnel.
#
# ### Business Relevance
#
# Helps assess:
# - campaign effectiveness,
# - conversion efficiency,
# - and lead generation success.
#
# ---
#
# ## `campaign_crop`
#
# - Indicates the agricultural crop targeted by the campaign.
# - Enables crop-specific marketing analysis.
#
# ### Strategic Importance
#
# Supports:
# - personalized campaign strategies,
# - seasonal targeting,
# - and crop-focused recommendations.
#
# ---
#
# ## `campaign_product`
#
# - Represents the product promoted in the campaign.
# - Useful for product-level performance analysis.
#
# ### Business Insight
#
# Can help evaluate:
# - product popularity,
# - campaign success by product,
# - and demand trends.
#
# ---
#
# # Overall Observations
#
# The dataset combines:
# - campaign metadata,
# - temporal tracking,
# - funnel metrics,
# - and agricultural targeting features.
#
# This creates strong potential for:
# - marketing intelligence,
# - campaign optimization,
# - and predictive analytics.
#
# ---
#
# # Final Interpretation
#
# The dataset features are highly structured and business relevant. Together, they provide a strong foundation for:
# - digital funnel analysis,
# - campaign performance evaluation,
# - lead prediction,
# - and AI-driven agricultural marketing systems.

# %%
df.isnull().sum()
# Out:
# campaign_id               0
# week_start_date           0
# social_post_impression    0
# landing_page_visits       0
# lead_form_submission      0
# campaign_crop             0
# campaign_product          0
# dtype: int64

# %% [markdown]
# # Missing Value Analysis
#
# ## Overview
#
# Missing value analysis helps evaluate:
# - data completeness,
# - dataset reliability,
# - and preprocessing requirements.
#
# Datasets with fewer missing values are generally more suitable for:
# - statistical analysis,
# - visualization,
# - and machine learning applications.
#
# ---
#
# # Missing Value Summary
#
# | Feature | Missing Values |
# |---|---|
# | campaign_id | 0 |
# | week_start_date | 0 |
# | social_post_impression | 0 |
# | landing_page_visits | 0 |
# | lead_form_submission | 0 |
# | campaign_crop | 0 |
# | campaign_product | 0 |
#
# ---
#
# # Interpretation
#
# ## No Missing Values Detected
#
# All features in the dataset are completely populated with:
# - zero null values,
# - strong structural consistency,
# - and complete campaign information.
#
# This indicates excellent data quality.
#
# ---
#
# # Feature-Level Observations
#
# ## Campaign Information
#
# ### `campaign_id`
#
# - Every record contains a valid campaign identifier.
# - Ensures reliable campaign-level tracking.
#
# ---
#
# ## Temporal Information
#
# ### `week_start_date`
#
# - Weekly dates are fully available.
# - Supports uninterrupted time-series and trend analysis.
#
# ---
#
# ## Funnel Metrics
#
# ### `social_post_impression`
# ### `landing_page_visits`
# ### `lead_form_submission`
#
# - All marketing funnel metrics are complete.
# - Improves accuracy in:
#   - conversion analysis,
#   - campaign evaluation,
#   - and performance modeling.
#
# ---
#
# ## Targeting Features
#
# ### `campaign_crop`
# ### `campaign_product`
#
# - Crop and product information are fully populated.
# - Enables accurate segmentation and product-level analysis.
#
# ---
#
# # Business Importance
#
# Complete data improves:
# - reporting reliability,
# - operational decision-making,
# - and campaign performance analysis.
#
# The absence of missing values also reduces:
# - preprocessing complexity,
# - imputation requirements,
# - and potential analytical bias.
#
# ---
#
# # AI/ML Relevance
#
# Since the dataset contains no missing values:
# - preprocessing becomes simpler,
# - model training becomes more reliable,
# - and feature engineering becomes more efficient.
#
# This strengthens:
# - predictive analytics,
# - forecasting,
# - and campaign optimization systems.
#
# ---
#
# # Final Interpretation
#
# The dataset demonstrates excellent data completeness with no missing values across all features. This makes it highly reliable for:
# - exploratory analysis,
# - marketing intelligence,
# - and AI/ML-based campaign analytics.

# %%
df.dtypes
# Out:
# campaign_id                 str
# week_start_date             str
# social_post_impression    int64
# landing_page_visits       int64
# lead_form_submission      int64
# campaign_crop               str
# campaign_product            str
# dtype: object

# %% [markdown]
# # Data Type Analysis
#
# ## Overview
#
# Data type analysis helps verify whether dataset features are stored in appropriate formats for:
# - analysis,
# - preprocessing,
# - visualization,
# - and machine learning.
#
# Correct data types improve:
# - data consistency,
# - analytical accuracy,
# - and computational efficiency.
#
# ---
#
# # Feature Data Types
#
# | Feature | Data Type |
# |---|---|
# | campaign_id | object (string) |
# | week_start_date | object (string) |
# | social_post_impression | int64 |
# | landing_page_visits | int64 |
# | lead_form_submission | int64 |
# | campaign_crop | object (string) |
# | campaign_product | object (string) |
#
# ---
#
# # Interpretation
#
# ## Categorical Features
#
# ### `campaign_id`
#
# - Stored correctly as string data.
# - Acts as a unique campaign identifier.
#
# ### `campaign_crop`
#
# - Represents crop categories targeted in campaigns.
# - Suitable for segmentation and crop-wise analysis.
#
# ### `campaign_product`
#
# - Represents promoted agricultural products.
# - Useful for product performance evaluation.
#
# ---
#
# ## Numerical Features
#
# ### `social_post_impression`
#
# - Represents audience reach and campaign visibility.
# - Useful for engagement analysis.
#
# ### `landing_page_visits`
#
# - Measures user interaction with campaigns.
# - Helps evaluate click-through effectiveness.
#
# ### `lead_form_submission`
#
# - Represents final lead conversions.
# - Important for conversion analysis and ROI estimation.
#
# ---
#
# ## Temporal Feature Observation
#
# ### `week_start_date`
#
# - Currently stored as string (`object`) type.
# - Represents weekly campaign tracking dates.
#
# ### Recommended Improvement
#
# Convert this feature into datetime format for:
# - time-series analysis,
# - trend detection,
# - forecasting,
# - and seasonal analysis.
#
# ### Suggested Conversion
#
# ```python
# df['week_start_date'] = pd.to_datetime(df['week_start_date'])
# ```
#
# ---
#
# # Overall Observations
#
# The dataset contains a strong combination of:
# - categorical campaign features,
# - numerical funnel metrics,
# - and temporal information.
#
# This structure is highly suitable for:
# - campaign analytics,
# - funnel optimization,
# - and AI/ML applications.
#
# ---
#
# # Final Interpretation
#
# The dataset data types are mostly well-structured and analytically appropriate. Numerical features are correctly stored, while categorical features remain interpretable and business relevant.
#
# The primary improvement opportunity is converting `week_start_date` into datetime format to enable advanced temporal analysis and forecasting.

# %%
df.describe()
# Out:
#        social_post_impression  landing_page_visits  lead_form_submission
# count              104.000000           104.000000            104.000000
# mean             37160.105769           711.336538             47.259615
# std              14540.535610           355.354865             27.831321
# min              11386.000000           185.000000             10.000000
# 25%              25455.750000           443.500000             25.000000
# 50%              36379.000000           649.500000             42.000000
# 75%              47863.750000           965.500000             64.750000
# max              76445.000000          1510.000000            130.000000

# %% [markdown]
# # Numerical Feature Statistical Analysis
#
# ## Overview
#
# The dataset contains three major numerical marketing funnel features:
#
# - `social_post_impression`
# - `landing_page_visits`
# - `lead_form_submission`
#
# These features help analyze:
# - campaign reach,
# - audience engagement,
# - and conversion performance.
#
# ---
#
# # 1. Social Post Impression Analysis
#
# ## Statistical Summary
#
# | Metric | Value |
# |---|---|
# | Count | 104 |
# | Mean | 37160.11 |
# | Standard Deviation | 14540.54 |
# | Minimum | 11386 |
# | 25th Percentile | 25455.75 |
# | Median (50%) | 36379 |
# | 75th Percentile | 47863.75 |
# | Maximum | 76445 |
#
# ---
#
# ## Interpretation
#
# - The average campaign generates approximately 37,160 impressions.
# - The distribution shows high variability across campaigns.
# - Some campaigns achieved significantly larger audience reach.
#
# ### Business Insight
#
# High impression variability may indicate:
# - differences in campaign quality,
# - audience targeting,
# - seasonal demand,
# - or advertising budget allocation.
#
# ---
#
# # 2. Landing Page Visits Analysis
#
# ## Statistical Summary
#
# | Metric | Value |
# |---|---|
# | Count | 104 |
# | Mean | 711.34 |
# | Standard Deviation | 355.35 |
# | Minimum | 185 |
# | Median (50%) | 649.5 |
# | Maximum | 1510 |
#
# ---
#
# ## Interpretation
#
# - Campaigns generate an average of 711 landing page visits.
# - Visits are significantly lower than impressions, which is expected in a marketing funnel.
#
# ### Business Insight
#
# The gap between impressions and visits reflects:
# - click-through efficiency,
# - audience engagement quality,
# - and campaign effectiveness.
#
# ---
#
# # 3. Lead Form Submission Analysis
#
# ## Statistical Summary
#
# | Metric | Value |
# |---|---|
# | Count | 104 |
# | Mean | 47.26 |
# | Standard Deviation | 27.83 |
# | Minimum | 10 |
# | Median (50%) | 42 |
# | Maximum | 130 |
#
# ---
#
# ## Interpretation
#
# - Average lead generation is approximately 47 submissions per campaign week.
# - Conversion numbers are naturally lower than visits and impressions.
#
# ### Business Importance
#
# Lead submissions directly represent:
# - campaign success,
# - customer acquisition potential,
# - and conversion effectiveness.
#
# ---
#
# # Funnel Pattern Observation
#
# The numerical statistics clearly show a standard marketing funnel pattern:
#
# `Impressions → Visits → Lead Submissions`
#
# At each stage:
# - audience volume decreases,
# - engagement becomes more targeted,
# - and conversions become more valuable.
#
# ---
#
# # AI/ML Relevance
#
# These numerical features are highly useful for:
# - conversion prediction,
# - campaign performance forecasting,
# - engagement scoring,
# - and funnel optimization.
#
# Potential engineered features include:
# - click-through rate (CTR),
# - conversion rate,
# - engagement ratio,
# - and lead efficiency metrics.
#
# ---
#
# # Final Interpretation
#
# The numerical features demonstrate strong analytical and business value. The dataset captures meaningful variations in:
# - campaign reach,
# - user engagement,
# - and lead conversion performance.
#
# These metrics provide an excellent foundation for:
# - marketing analytics,
# - business intelligence,
# - and AI-driven campaign optimization systems.

# %%
df['campaign_crop'].value_counts()
# Out:
# campaign_crop
# wheat       26
# mustard     26
# chickpea    26
# potato      26
# Name: count, dtype: int64

# %% [markdown]
# # Campaign Crop Distribution Analysis
#
# ## Overview
#
# The `campaign_crop` feature represents the agricultural crops targeted in digital marketing campaigns.
#
# Analyzing crop distribution helps understand:
# - campaign focus areas,
# - crop-specific targeting strategies,
# - and dataset balance.
#
# ---
#
# # Crop Frequency Distribution
#
# | Crop | Count |
# |---|---|
# | wheat | 26 |
# | mustard | 26 |
# | chickpea | 26 |
# | potato | 26 |
#
# ---
#
# # Interpretation
#
# ## Perfectly Balanced Crop Distribution
#
# - Each crop appears exactly 26 times in the dataset.
# - The dataset demonstrates complete balance across all crop categories.
#
# ### Business Insight
#
# This suggests:
# - equal campaign attention across crops,
# - balanced marketing strategies,
# - and uniform campaign allocation.
#
# ---
#
# # Crop-Level Observations
#
# ## Wheat
#
# - Represents one of the major agricultural campaign categories.
# - Likely associated with seasonal cereal crop marketing.
#
# ---
#
# ## Mustard
#
# - Indicates focus on oilseed crop campaigns.
# - May support region-specific agricultural targeting.
#
# ---
#
# ## Chickpea
#
# - Represents pulse crop marketing initiatives.
# - Useful for diversified agricultural engagement strategies.
#
# ---
#
# ## Potato
#
# - Reflects campaigns targeting commercial vegetable farming.
# - May relate to high-demand or high-value agricultural products.
#
# ---
#
# # AI/ML Relevance
#
# Balanced categorical distributions are highly beneficial because they:
# - reduce class imbalance problems,
# - improve model fairness,
# - and strengthen prediction reliability.
#
# The `campaign_crop` feature can significantly improve:
# - campaign recommendation systems,
# - crop-specific analytics,
# - and targeted marketing models.
#
# ---
#
# # Business Importance
#
# Crop-wise campaign analysis can help:
# - optimize agricultural marketing,
# - personalize recommendations,
# - and evaluate product demand trends by crop category.
#
# ---
#
# # Final Interpretation
#
# The `campaign_crop` feature demonstrates a perfectly balanced distribution across all crop categories. This creates a strong foundation for:
# - fair analytical comparisons,
# - balanced AI/ML modeling,
# - and crop-specific marketing intelligence.

# %%
df['week_start_date'].min()
# Out:
# '2025-10-06'

# %%
df['week_start_date'].max()
# Out:
# '2026-03-30'

# %% [markdown]
# # Week Start Date Range Analysis
#
# ## Overview
#
# The `week_start_date` feature represents the weekly tracking period for digital campaign performance.
#
# Analyzing the date range helps understand:
# - campaign activity duration,
# - seasonal coverage,
# - operational continuity,
# - and temporal scope.
#
# ---
#
# # Date Range Summary
#
# | Metric | Value |
# |---|---|
# | Earliest Date | 2025-10-06 |
# | Latest Date | 2026-03-30 |
#
# ---
#
# # Interpretation
#
# ## Campaign Timeline
#
# - The dataset spans nearly 6 months of weekly campaign activity.
# - Campaign tracking extends from October 2025 to March 2026.
#
# ### Business Insight
#
# This duration allows analysis of:
# - long-term campaign performance,
# - engagement trends,
# - and seasonal marketing behavior.
#
# ---
#
# # Seasonal Coverage
#
# The timeline includes:
# - post-monsoon agricultural activity,
# - winter crop campaigns,
# - and early 2026 seasonal operations.
#
# ### Strategic Importance
#
# This period may capture campaigns related to:
# - Rabi crop cultivation,
# - seasonal product promotion,
# - and farmer engagement cycles.
#
# ---
#
# # Weekly Granularity
#
# The dataset records campaign performance on a weekly basis.
#
# ### Analytical Benefits
#
# Weekly granularity supports:
# - trend monitoring,
# - performance comparison,
# - and short-term forecasting.
#
# ---
#
# # AI/ML Relevance
#
# The `week_start_date` feature can support:
# - time-series forecasting,
# - seasonal trend analysis,
# - campaign scheduling optimization,
# - and engagement prediction.
#
# Additional time-based features can be engineered, such as:
# - month,
# - quarter,
# - season,
# - and campaign week number.
#
# ---
#
# # Data Quality Observation
#
# The date values appear:
# - structured,
# - chronologically consistent,
# - and operationally realistic.
#
# No abnormal timestamps are observed.
#
# ---
#
# # Final Interpretation
#
# The dataset captures weekly campaign activity across a well-defined 6-month period, providing strong temporal coverage for:
# - marketing analytics,
# - seasonal trend evaluation,
# - and AI-driven campaign optimization.

# %%
df['campaign_crop'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='campaign_crop'>

# %% [markdown]
# # Campaign Crop Visualization Analysis
#
# ## Overview
#
# The bar chart visualizes the distribution of campaigns across different crop categories. It helps identify:
# - campaign allocation balance,
# - crop targeting strategy,
# - and category representation.
#
# ---
#
# # Key Observations
#
# | Crop | Approximate Count |
# |---|---|
# | wheat | 26 |
# | mustard | 26 |
# | chickpea | 26 |
# | potato | 26 |
#
# ---
#
# # Interpretation
#
# ## Uniform Crop Distribution
#
# - All crop categories have equal representation in the dataset.
# - Each crop appears exactly 26 times.
#
# ### Business Insight
#
# This indicates:
# - balanced campaign planning,
# - equal marketing focus,
# - and uniform crop targeting.
#
# ---
#
# # Crop-Level Insights
#
# ## Wheat
#
# - Represents cereal crop-focused campaigns.
# - Likely associated with seasonal agricultural promotion.
#
# ---
#
# ## Mustard
#
# - Indicates oilseed crop marketing initiatives.
# - May target region-specific grower segments.
#
# ---
#
# ## Chickpea
#
# - Represents pulse crop campaigns.
# - Supports diversified agricultural outreach.
#
# ---
#
# ## Potato
#
# - Reflects vegetable crop-focused marketing activity.
# - May relate to commercial farming engagement.
#
# ---
#
# # Visualization Insights
#
# The chart clearly shows:
# - identical bar heights,
# - balanced category distribution,
# - and absence of crop dominance.
#
# This balanced structure improves:
# - analytical fairness,
# - comparative analysis,
# - and modeling consistency.
#
# ---
#
# # AI/ML Relevance
#
# Balanced categorical data is highly beneficial because it:
# - reduces class imbalance,
# - improves model stability,
# - and enhances prediction fairness.
#
# The `campaign_crop` feature can support:
# - crop-specific recommendations,
# - campaign optimization,
# - and targeted engagement systems.
#
# ---
#
# # Final Interpretation
#
# The visualization demonstrates a perfectly balanced crop distribution across all campaign categories. This creates a strong foundation for:
# - unbiased analysis,
# - fair AI/ML modeling,
# - and effective agricultural marketing intelligence.

# %% [markdown]
# # reps_territory.csv Analysis

# %%
df = pd.read_csv("../datasets/reps_territory.csv")

# %%
df.head()
# Out:
#      rep_id territory_id       territory_name          state   district  \
# 0  REP_0001     TER_0001      patna_north_001          Bihar      Patna
# 1  REP_0002     TER_0002      hisar_south_002        Haryana      Hisar
# 2  REP_0003     TER_0003    varanasi_east_003  Uttar Pradesh   Varanasi
# 3  REP_0004     TER_0004   bharatpur_west_004      Rajasthan  Bharatpur
# 4  REP_0005     TER_0005  jalgaon_central_005    Maharashtra    Jalgaon
#
#                                          tehsil_list
# 0  ["Patna_T001", "Patna_T002", "Patna_T003", "Pa...
# 1  ["Hisar_T001", "Hisar_T002", "Hisar_T003", "Hi...
# 2  ["Varanasi_T001", "Varanasi_T002", "Varanasi_T...
# 3  ["Bharatpur_T001", "Bharatpur_T002", "Bharatpu...
# 4  ["Jalgaon_T001", "Jalgaon_T002", "Jalgaon_T003...

# %% [markdown]
# # Representatives Territory Dataset Analysis
#
# ## Overview
#
# The `reps_territory.csv` dataset contains information related to:
# - sales representatives,
# - assigned territories,
# - geographic regions,
# - and tehsil coverage areas.
#
# The dataset helps map operational structure across multiple geographic levels.
#
# ---
#
# # Dataset Features
#
# | Feature | Description |
# |---|---|
# | rep_id | Unique representative identifier |
# | territory_id | Unique territory identifier |
# | territory_name | Name of the assigned territory |
# | state | State associated with the territory |
# | district | District associated with the territory |
# | tehsil_list | List of tehsils covered within the territory |
#
# ---
#
# # Initial Observations
#
# ## Representative-Level Mapping
#
# ### `rep_id`
#
# - Each record corresponds to a specific sales representative.
# - Enables individual-level operational tracking.
#
# ### Business Importance
#
# Useful for:
# - workforce management,
# - performance monitoring,
# - and territory assignment analysis.
#
# ---
#
# ## Territory Information
#
# ### `territory_id`
#
# - Represents unique operational territories.
# - Supports territory-level segmentation and analysis.
#
# ### `territory_name`
#
# - Provides descriptive territory labels.
# - Includes geographic and directional naming patterns.
#
# ### Interpretation
#
# Territory names appear structured using:
# - district/city name,
# - regional direction,
# - and territory numbering.
#
# Example:
# - `patna_north_001`
# - `hisar_south_002`
#
# ---
#
# # Geographic Features
#
# ## `state`
#
# - Represents macro-level regional information.
# - Supports state-wise operational analysis.
#
# ---
#
# ## `district`
#
# - Provides district-level territory mapping.
# - Useful for localized business intelligence.
#
# ---
#
# ## `tehsil_list`
#
# - Contains multiple tehsils assigned to each territory.
# - Indicates hierarchical geographic coverage.
#
# ### Business Relevance
#
# This feature helps understand:
# - territory reach,
# - operational span,
# - and micro-regional coverage.
#
# ---
#
# # Operational Insights
#
# The dataset demonstrates a clear geographic hierarchy:
#
# `State → District → Territory → Tehsil`
#
# This structure supports:
# - operational planning,
# - territory optimization,
# - and regional performance analysis.
#
# ---
#
# # AI/ML Relevance
#
# The dataset can support:
# - territory clustering,
# - geographic recommendation systems,
# - workforce optimization,
# - and territory performance prediction.
#
# Potential engineered features include:
# - number of tehsils per territory,
# - territory density,
# - and regional coverage metrics.
#
# ---
#
# # Final Interpretation
#
# The `reps_territory.csv` dataset provides structured operational and geographic intelligence across representatives and territories. The hierarchical regional structure creates strong potential for:
# - business analytics,
# - operational optimization,
# - and AI-driven territory management systems.

# %%
df.shape
# Out:
# (500, 6)

# %% [markdown]
# # Dataset Shape Analysis
#
# ## Overview
#
# The shape of a dataset represents:
# - the total number of rows (records),
# - and the number of columns (features).
#
# This helps understand:
# - dataset size,
# - feature availability,
# - and analytical scope.
#
# ---
#
# # Dataset Shape
#
# | Metric | Value |
# |---|---|
# | Number of Rows | 500 |
# | Number of Columns | 6 |
#
# ---
#
# # Interpretation
#
# ## Total Records = 500
#
# - The dataset contains 500 representative-territory records.
# - Each row represents a unique territory assignment associated with a sales representative.
#
# ### Business Insight
#
# This provides sufficient coverage for:
# - territory analysis,
# - operational planning,
# - and workforce management.
#
# ---
#
# ## Total Features = 6
#
# The dataset includes:
# - representative identifiers,
# - territory information,
# - geographic hierarchy,
# - and tehsil coverage details.
#
# ### Analytical Importance
#
# These features support:
# - geographic segmentation,
# - territory mapping,
# - and operational intelligence.
#
# ---
#
# # Data Structure Observation
#
# The dataset appears:
# - well-structured,
# - organized,
# - and operationally meaningful.
#
# The combination of identifiers and geographic features creates strong analytical value.
#
# ---
#
# # AI/ML Relevance
#
# The dataset can support:
# - territory clustering,
# - workload analysis,
# - regional optimization,
# - and predictive operational modeling.
#
# The dataset size is suitable for:
# - exploratory analysis,
# - dashboard reporting,
# - and geographic intelligence systems.
#
# ---
#
# # Final Interpretation
#
# The dataset contains 500 structured operational records and 6 meaningful features, providing a strong foundation for:
# - territory management,
# - representative analysis,
# - and AI-driven regional optimization.

# %%
df.shape
# Out:
# (500, 6)

# %% [markdown]
# # Dataset Shape Analysis
#
# ## Overview
#
# The dataset shape provides information about:
# - the total number of records,
# - the number of available features,
# - and the overall analytical scope.
#
# Understanding dataset dimensions helps evaluate:
# - data coverage,
# - complexity,
# - and suitability for analysis.
#
# ---
#
# # Dataset Shape
#
# | Metric | Value |
# |---|---|
# | Number of Rows | 500 |
# | Number of Columns | 6 |
#
# ---
#
# # Interpretation
#
# ## Total Records = 500
#
# - The dataset contains 500 representative-territory entries.
# - Each row represents a territory mapped to a specific sales representative.
#
# ### Business Insight
#
# This provides meaningful operational coverage for:
# - territory assignment analysis,
# - workforce monitoring,
# - and regional management.
#
# ---
#
# ## Total Features = 6
#
# The dataset includes:
# - representative identifiers,
# - territory identifiers,
# - geographic hierarchy,
# - and tehsil coverage information.
#
# ### Analytical Importance
#
# These features support:
# - geographic intelligence,
# - operational analytics,
# - and territory optimization.
#
# ---
#
# # Data Structure Observation
#
# The dataset appears:
# - compact,
# - structured,
# - and operationally organized.
#
# The hierarchical geographic information improves:
# - regional segmentation,
# - territory tracking,
# - and localized analysis.
#
# ---
#
# # AI/ML Relevance
#
# The dataset is suitable for:
# - clustering,
# - territory recommendation systems,
# - representative performance analysis,
# - and regional optimization models.
#
# Additional engineered features such as:
# - territory size,
# - tehsil count,
# - and regional density
#
# can further improve analytical value.
#
# ---
#
# # Final Interpretation
#
# The dataset contains 500 operational records and 6 meaningful features, providing a strong foundation for:
# - territory management,
# - geographic analysis,
# - and AI-driven operational decision systems.

# %%
df.columns
# Out:
# Index(['rep_id', 'territory_id', 'territory_name', 'state', 'district',
#        'tehsil_list'],
#       dtype='str')

# %% [markdown]
# # Feature Analysis
#
# ## Overview
#
# The dataset contains 6 features related to:
# - sales representatives,
# - territory assignments,
# - and geographic coverage.
#
# These features provide valuable operational and regional intelligence for:
# - territory management,
# - workforce analysis,
# - and geographic optimization.
#
# ---
#
# # Dataset Features
#
# | Feature | Description |
# |---|---|
# | rep_id | Unique representative identifier |
# | territory_id | Unique territory identifier |
# | territory_name | Name of the assigned territory |
# | state | State associated with the territory |
# | district | District associated with the territory |
# | tehsil_list | List of tehsils covered within the territory |
#
# ---
#
# # Feature-Level Interpretation
#
# ## `rep_id`
#
# - Represents unique sales representatives.
# - Useful for representative-level tracking and analysis.
#
# ### Business Importance
#
# Supports:
# - workforce management,
# - performance monitoring,
# - and operational planning.
#
# ---
#
# ## `territory_id`
#
# - Represents unique territory assignments.
# - Enables territory-level segmentation.
#
# ### Analytical Importance
#
# Useful for:
# - operational analysis,
# - territory mapping,
# - and performance comparison.
#
# ---
#
# ## `territory_name`
#
# - Contains descriptive territory labels.
# - Appears to combine geographic location and directional information.
#
# ### Business Insight
#
# Helps identify:
# - territory regions,
# - operational zones,
# - and geographic clusters.
#
# ---
#
# ## `state`
#
# - Represents macro-level geographic information.
# - Useful for regional analysis and state-level reporting.
#
# ### AI/ML Relevance
#
# Can support:
# - regional segmentation,
# - geographic clustering,
# - and territory optimization.
#
# ---
#
# ## `district`
#
# - Provides district-level geographic granularity.
# - Enables localized operational analysis.
#
# ### Business Importance
#
# Useful for:
# - identifying regional hotspots,
# - analyzing territory density,
# - and improving local operations.
#
# ---
#
# ## `tehsil_list`
#
# - Contains multiple tehsils covered within each territory.
# - Represents detailed geographic coverage information.
#
# ### Strategic Importance
#
# Supports:
# - micro-regional analysis,
# - coverage optimization,
# - and territory workload assessment.
#
# ---
#
# # Geographic Hierarchy Observation
#
# The dataset follows a structured geographic hierarchy:
#
# `State → District → Territory → Tehsil`
#
# This structure improves:
# - operational visibility,
# - geographic intelligence,
# - and regional planning capabilities.
#
# ---
#
# # AI/ML Relevance
#
# The dataset features can support:
# - territory clustering,
# - operational forecasting,
# - representative allocation,
# - and geographic recommendation systems.
#
# Potential engineered features include:
# - tehsil count per territory,
# - territory density,
# - and regional workload metrics.
#
# ---
#
# # Final Interpretation
#
# The dataset features are highly structured and operationally valuable. Together, they provide strong support for:
# - geographic analysis,
# - territory optimization,
# - workforce intelligence,
# - and AI-driven operational decision systems.

# %%
df.isnull().sum()
# Out:
# rep_id            0
# territory_id      0
# territory_name    0
# state             0
# district          0
# tehsil_list       0
# dtype: int64

# %% [markdown]
# # Missing Value Analysis
#
# ## Overview
#
# Missing value analysis helps evaluate:
# - dataset completeness,
# - data reliability,
# - and preprocessing requirements.
#
# Datasets with no missing values are generally more reliable for:
# - statistical analysis,
# - business intelligence,
# - and machine learning applications.
#
# ---
#
# # Missing Value Summary
#
# | Feature | Missing Values |
# |---|---|
# | rep_id | 0 |
# | territory_id | 0 |
# | territory_name | 0 |
# | state | 0 |
# | district | 0 |
# | tehsil_list | 0 |
#
# ---
#
# # Interpretation
#
# ## No Missing Values Detected
#
# All features in the dataset are completely populated with:
# - zero null values,
# - strong structural consistency,
# - and complete geographic coverage.
#
# This indicates excellent data quality.
#
# ---
#
# # Feature-Level Observations
#
# ## `rep_id`
#
# - Every record contains a valid representative identifier.
# - Ensures reliable representative-level tracking.
#
# ---
#
# ## `territory_id`
#
# - Territory information is fully available.
# - Supports accurate territory mapping and operational analysis.
#
# ---
#
# ## `territory_name`
#
# - All territory names are properly recorded.
# - Improves readability and geographic interpretation.
#
# ---
#
# ## Geographic Features
#
# ### `state` and `district`
#
# - Geographic hierarchy is fully populated.
# - Enables uninterrupted regional analysis and segmentation.
#
# ---
#
# ## `tehsil_list`
#
# - Every territory includes assigned tehsil information.
# - Ensures complete micro-regional coverage data.
#
# ### Business Importance
#
# This improves:
# - territory planning,
# - operational visibility,
# - and geographic intelligence.
#
# ---
#
# # Business Impact
#
# Complete data availability reduces:
# - preprocessing effort,
# - data-cleaning complexity,
# - and analytical uncertainty.
#
# This improves:
# - reporting accuracy,
# - operational reliability,
# - and decision-making quality.
#
# ---
#
# # AI/ML Relevance
#
# Since no missing values exist:
# - imputation is unnecessary,
# - preprocessing becomes simpler,
# - and model reliability improves.
#
# The dataset is highly suitable for:
# - clustering,
# - geographic modeling,
# - and operational optimization systems.
#
# ---
#
# # Final Interpretation
#
# The dataset demonstrates excellent completeness with no missing values across all features. This creates a strong foundation for:
# - operational analytics,
# - geographic intelligence,
# - and AI-driven territory management systems.

# %%
df.dtypes
# Out:
# rep_id            str
# territory_id      str
# territory_name    str
# state             str
# district          str
# tehsil_list       str
# dtype: object

# %% [markdown]
# # Data Type Analysis
#
# ## Overview
#
# Data type analysis helps verify whether dataset features are stored in appropriate formats for:
# - analysis,
# - preprocessing,
# - visualization,
# - and machine learning.
#
# Correct data types improve:
# - data consistency,
# - interpretability,
# - and computational efficiency.
#
# ---
#
# # Feature Data Types
#
# | Feature | Data Type |
# |---|---|
# | rep_id | object (string) |
# | territory_id | object (string) |
# | territory_name | object (string) |
# | state | object (string) |
# | district | object (string) |
# | tehsil_list | object (string) |
#
# ---
#
# # Interpretation
#
# ## Categorical and Identifier Features
#
# ### `rep_id`
#
# - Stored correctly as string data.
# - Represents unique sales representatives.
#
# ### Business Importance
#
# Useful for:
# - workforce tracking,
# - representative analysis,
# - and operational monitoring.
#
# ---
#
# ### `territory_id`
#
# - Properly stored as categorical text data.
# - Represents unique operational territories.
#
# ### Analytical Importance
#
# Supports:
# - territory segmentation,
# - performance analysis,
# - and regional mapping.
#
# ---
#
# ### `territory_name`
#
# - Stored as string data.
# - Contains descriptive geographic territory labels.
#
# ### Business Insight
#
# Useful for:
# - territory identification,
# - operational readability,
# - and regional categorization.
#
# ---
#
# # Geographic Features
#
# ## `state`
#
# - Represents macro-level geographic information.
# - Correctly stored as categorical text data.
#
# ---
#
# ## `district`
#
# - Provides district-level regional granularity.
# - Suitable for localized operational analysis.
#
# ---
#
# # Complex Feature Observation
#
# ## `tehsil_list`
#
# - Stored as string data containing multiple tehsil values.
# - Appears to represent list-like geographic information.
#
# ### Important Observation
#
# Although stored as string format, this feature behaves like a collection of multiple categorical values.
#
# ### Recommended Improvement
#
# Convert the feature into actual list format for advanced analysis.
#
# ### Suggested Conversion
#
# ```python
# import ast
#
# df['tehsil_list'] = df['tehsil_list'].apply(ast.literal_eval)
# ```
#
# ### Business Importance
#
# Proper conversion enables:
# - tehsil-level analysis,
# - territory coverage evaluation,
# - and workload estimation.
#
# ---
#
# # AI/ML Relevance
#
# All features are categorical or geographic in nature and can support:
# - territory clustering,
# - geographic segmentation,
# - operational forecasting,
# - and recommendation systems.
#
# Encoding techniques such as:
# - label encoding,
# - frequency encoding,
# - or embeddings
#
# may be required for modeling.
#
# ---
#
# # Final Interpretation
#
# The dataset data types are largely well-structured and operationally appropriate. The primary enhancement opportunity lies in converting `tehsil_list` from string format into an actual list structure for deeper geographic and analytical processing.

# %%
df.describe()
# Out:
#           rep_id territory_id   territory_name          state district  \
# count        500          500              500            500      500
# unique       500          500              500             10       33
# top     REP_0001     TER_0001  patna_north_001  Uttar Pradesh    Patna
# freq           1            1                1             76       16
#
#                                               tehsil_list
# count                                                 500
# unique                                                500
# top     ["Patna_T001", "Patna_T002", "Patna_T003", "Pa...
# freq                                                    1

# %% [markdown]
# # Categorical Feature Statistical Analysis
#
# ## Overview
#
# The statistical summary provides insights into:
# - feature uniqueness,
# - geographic diversity,
# - operational distribution,
# - and categorical structure.
#
# These observations are valuable for:
# - territory analysis,
# - workforce management,
# - and AI/ML preprocessing.
#
# ---
#
# # Statistical Summary
#
# | Feature | Count | Unique | Top Value | Frequency |
# |---|---|---|---|---|
# | rep_id | 500 | 500 | REP_0001 | 1 |
# | territory_id | 500 | 500 | TER_0001 | 1 |
# | territory_name | 500 | 500 | patna_north_001 | 1 |
# | state | 500 | 10 | Uttar Pradesh | 76 |
# | district | 500 | 33 | Patna | 16 |
# | tehsil_list | 500 | 500 | ["Patna_T001", ...] | 1 |
#
# ---
#
# # Interpretation
#
# # 1. Representative ID Analysis
#
# ## Unique Representatives = 500
#
# - Every `rep_id` is unique.
# - Each record corresponds to a separate representative.
#
# ### Business Insight
#
# This indicates:
# - strong entity-level separation,
# - clean operational mapping,
# - and individualized territory assignments.
#
# ---
#
# # 2. Territory ID Analysis
#
# ## Unique Territories = 500
#
# - Every territory is uniquely identified.
# - No territory duplication exists in the dataset.
#
# ### Business Importance
#
# This supports:
# - accurate territory management,
# - operational tracking,
# - and regional allocation analysis.
#
# ---
#
# # 3. Territory Name Analysis
#
# ## Unique Territory Names = 500
#
# - Each territory name is unique.
# - Territory labels appear highly structured and descriptive.
#
# ### Interpretation
#
# Territory names likely combine:
# - geographic location,
# - directional information,
# - and numeric identifiers.
#
# Example:
# - `patna_north_001`
#
# ---
#
# # 4. State Analysis
#
# ## Unique States = 10
#
# - The dataset spans 10 states.
# - Uttar Pradesh has the highest representation with 76 records.
#
# ### Business Insight
#
# This suggests:
# - stronger operational coverage in Uttar Pradesh,
# - or higher territory allocation within the region.
#
# ---
#
# # 5. District Analysis
#
# ## Unique Districts = 33
#
# - The dataset contains 33 districts.
# - Patna appears most frequently with 16 records.
#
# ### Interpretation
#
# District representation appears geographically diverse with moderate concentration in specific operational zones.
#
# ---
#
# # 6. Tehsil List Analysis
#
# ## Unique Tehsil Lists = 500
#
# - Every territory has a unique tehsil coverage structure.
# - No duplicate territory coverage combinations exist.
#
# ### Business Importance
#
# This indicates:
# - customized territory mapping,
# - detailed geographic allocation,
# - and strong regional granularity.
#
# ---
#
# # Geographic Hierarchy Observation
#
# The dataset follows a structured operational hierarchy:
#
# `State → District → Territory → Tehsil`
#
# This hierarchy supports:
# - geographic intelligence,
# - operational planning,
# - and territory optimization.
#
# ---
#
# # AI/ML Relevance
#
# The categorical structure is highly suitable for:
# - clustering,
# - geographic segmentation,
# - territory recommendation systems,
# - and operational analytics.
#
# High-cardinality features such as:
# - `rep_id`,
# - `territory_id`,
# - and `territory_name`
#
# may require advanced encoding techniques.
#
# ---
#
# # Final Interpretation
#
# The dataset demonstrates:
# - strong geographic diversity,
# - unique territory allocation,
# - and highly granular operational coverage.
#
# The structured categorical features provide an excellent foundation for:
# - territory analytics,
# - workforce intelligence,
# - and AI-driven operational optimization systems.

# %%
df['state'].value_counts()
# Out:
# state
# Uttar Pradesh     76
# Haryana           61
# Rajasthan         61
# Madhya Pradesh    60
# Punjab            60
# Maharashtra       46
# Gujarat           45
# Bihar             31
# West Bengal       30
# Karnataka         30
# Name: count, dtype: int64

# %% [markdown]
# # State-Wise Territory Distribution Analysis
#
# ## Overview
#
# The `state` feature represents the geographic distribution of representative territories across different states.
#
# Analyzing state-wise frequency helps understand:
# - operational coverage,
# - territory concentration,
# - regional allocation,
# - and geographic diversity.
#
# ---
#
# # State Frequency Distribution
#
# | State | Count |
# |---|---|
# | Uttar Pradesh | 76 |
# | Haryana | 61 |
# | Rajasthan | 61 |
# | Madhya Pradesh | 60 |
# | Punjab | 60 |
# | Maharashtra | 46 |
# | Gujarat | 45 |
# | Bihar | 31 |
# | West Bengal | 30 |
# | Karnataka | 30 |
#
# ---
#
# # Interpretation
#
# ## Uttar Pradesh Has the Highest Territory Representation
#
# - Uttar Pradesh contains the largest number of territories.
# - This indicates stronger operational presence in the region.
#
# ### Business Insight
#
# Possible reasons include:
# - larger agricultural markets,
# - higher grower density,
# - or increased sales activity.
#
# ---
#
# ## Haryana, Rajasthan, Madhya Pradesh, and Punjab Show Strong Coverage
#
# - These states also contain a high number of territories.
# - The dataset appears concentrated in agriculturally active northern and central regions.
#
# ### Operational Importance
#
# These regions may require:
# - larger field teams,
# - increased operational support,
# - and more intensive campaign activities.
#
# ---
#
# ## Moderate Representation States
#
# ### Maharashtra and Gujarat
#
# - These states show moderate territory allocation.
# - They may represent developing or selectively targeted operational markets.
#
# ---
#
# ## Lower Representation States
#
# ### Bihar, West Bengal, and Karnataka
#
# - These states contain comparatively fewer territories.
# - Possible explanations include:
#   - smaller operational footprint,
#   - lower market penetration,
#   - or limited territory allocation.
#
# ---
#
# # Geographic Diversity Insights
#
# The dataset includes territories from:
# - northern India,
# - western India,
# - central India,
# - eastern India,
# - and southern India.
#
# This improves:
# - regional coverage,
# - geographic intelligence,
# - and operational diversity.
#
# ---
#
# # AI/ML Relevance
#
# The `state` feature is highly useful for:
# - territory clustering,
# - geographic segmentation,
# - regional forecasting,
# - and operational optimization.
#
# However, uneven territory distribution may introduce:
# - regional imbalance,
# - coverage bias,
# - and skewed operational analysis.
#
# ---
#
# # Business Importance
#
# State-wise territory analysis can help:
# - optimize representative allocation,
# - improve operational planning,
# - identify expansion opportunities,
# - and strengthen regional strategy.
#
# ---
#
# # Final Interpretation
#
# The state distribution demonstrates strong operational coverage across major agricultural regions with higher concentration in Uttar Pradesh and northern states. The feature provides valuable regional intelligence for:
# - territory management,
# - operational analytics,
# - and AI-driven geographic optimization.

# %%
df['state'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='state'>

# %% [markdown]
# # State Distribution Visualization Analysis
#
# ## Overview
#
# The bar chart visualizes the distribution of representative territories across different states. It provides a clear comparison of operational coverage and highlights regions with higher territory concentration.
#
# ---
#
# # Key Observations
#
# | State | Approximate Count |
# |---|---|
# | Uttar Pradesh | ~76 |
# | Haryana | ~61 |
# | Rajasthan | ~61 |
# | Madhya Pradesh | ~60 |
# | Punjab | ~60 |
# | Maharashtra | ~46 |
# | Gujarat | ~45 |
# | Bihar | ~31 |
# | West Bengal | ~30 |
# | Karnataka | ~30 |
#
# ---
#
# # Interpretation
#
# ## Uttar Pradesh Has the Highest Representation
#
# - Uttar Pradesh shows the tallest bar in the chart.
# - This indicates the strongest territory presence in the dataset.
#
# ### Business Insight
#
# This may reflect:
# - higher agricultural activity,
# - stronger operational penetration,
# - or larger representative allocation.
#
# ---
#
# ## Strong Presence from Northern and Central States
#
# ### Haryana, Rajasthan, Madhya Pradesh, and Punjab
#
# - These states also show high territory counts.
# - The dataset is heavily concentrated in agriculturally active regions.
#
# ### Operational Importance
#
# These states may require:
# - larger field operations,
# - increased campaign activities,
# - and higher resource allocation.
#
# ---
#
# ## Moderate Representation States
#
# ### Maharashtra and Gujarat
#
# - These states have moderate territory coverage.
# - They may represent growing or strategically targeted operational markets.
#
# ---
#
# ## Lower Representation States
#
# ### Bihar, West Bengal, and Karnataka
#
# - These states show comparatively fewer territories.
# - Possible reasons include:
#   - smaller operational networks,
#   - lower market penetration,
#   - or limited territory expansion.
#
# ---
#
# # Visualization Insights
#
# The chart clearly highlights:
# - regional operational imbalance,
# - dominant territory regions,
# - and geographic diversity.
#
# The gradual decline in bar heights indicates varying territory allocation across states.
#
# ---
#
# # AI/ML Relevance
#
# The `state` feature can significantly support:
# - geographic clustering,
# - territory optimization,
# - operational forecasting,
# - and regional recommendation systems.
#
# However, uneven state representation may introduce:
# - regional bias,
# - operational imbalance,
# - and skewed model behavior.
#
# ---
#
# # Final Interpretation
#
# The visualization demonstrates strong territory concentration in major agricultural states while maintaining broad geographic coverage across India. The `state` feature provides valuable operational intelligence for:
# - territory management,
# - workforce optimization,
# - and AI-driven regional planning systems.

# %% [markdown]
# # retailer_inventory_weekly.csv Analysis

# %%
df = pd.read_csv("../datasets/retailer_inventory_weekly.csv")

# %%
df.head()
# Out:
#   retailer_id         sku_id      sku_name  sku_qty week_end_date
# 0   RTL_00001  SY_TILT_250EC   Tilt 250 EC       94    2025-10-05
# 1   RTL_00001   SY_SCO_250EC  Score 250 EC      122    2025-10-05
# 2   RTL_00001    SY_AXI_50EC   Axial 50 EC      193    2025-10-05
# 3   RTL_00001  SY_TILT_250EC   Tilt 250 EC       94    2025-10-12
# 4   RTL_00001   SY_SCO_250EC  Score 250 EC       41    2025-10-12

# %% [markdown]
# # Retailer Inventory Weekly Dataset Analysis
#
# ## Overview
#
# The `retailer_inventory_weekly.csv` dataset contains weekly inventory information related to:
# - retailers,
# - agricultural products (SKUs),
# - inventory quantities,
# - and weekly stock tracking.
#
# The dataset is useful for:
# - inventory monitoring,
# - sales planning,
# - supply-chain analysis,
# - and demand forecasting.
#
# ---
#
# # Dataset Features
#
# | Feature | Description |
# |---|---|
# | retailer_id | Unique retailer identifier |
# | sku_id | Unique product SKU identifier |
# | sku_name | Name of the agricultural product |
# | sku_qty | Quantity of product available |
# | week_end_date | Weekly inventory tracking date |
#
# ---
#
# # Initial Observations
#
# ## Retailer-Level Inventory Tracking
#
# ### `retailer_id`
#
# - Represents individual retailers.
# - Enables retailer-wise inventory analysis.
#
# ### Business Importance
#
# Useful for:
# - stock monitoring,
# - retailer performance analysis,
# - and inventory allocation planning.
#
# ---
#
# ## Product Information
#
# ### `sku_id`
#
# - Represents unique product identifiers.
# - Helps distinguish different agricultural products.
#
# ### `sku_name`
#
# - Contains descriptive product names.
# - Improves product-level interpretability.
#
# ### Example Products
#
# - Tilt 250 EC
# - Score 250 EC
# - Axial 50 EC
#
# ### Business Insight
#
# The products appear related to:
# - crop protection,
# - agrochemicals,
# - or pesticide formulations.
#
# ---
#
# ## Inventory Quantity
#
# ### `sku_qty`
#
# - Represents weekly product quantity available at the retailer level.
# - Useful for stock and demand analysis.
#
# ### Operational Importance
#
# Can help identify:
# - fast-moving products,
# - stock shortages,
# - and inventory trends.
#
# ---
#
# ## Temporal Feature
#
# ### `week_end_date`
#
# - Represents weekly inventory reporting periods.
# - Enables time-based inventory tracking.
#
# ### Analytical Importance
#
# Supports:
# - trend analysis,
# - seasonal demand evaluation,
# - and forecasting.
#
# ---
#
# # Dataset Structure Observation
#
# The dataset appears organized at the:
#
# `Retailer → Product → Weekly Inventory`
#
# level.
#
# This structure supports:
# - granular inventory intelligence,
# - operational monitoring,
# - and product movement analysis.
#
# ---
#
# # AI/ML Relevance
#
# The dataset can support:
# - inventory forecasting,
# - demand prediction,
# - stock optimization,
# - and retailer recommendation systems.
#
# Potential engineered features include:
# - average stock levels,
# - weekly inventory trends,
# - stock volatility,
# - and product movement frequency.
#
# ---
#
# # Final Interpretation
#
# The `retailer_inventory_weekly.csv` dataset provides structured weekly inventory intelligence across retailers and agricultural products. The combination of retailer, product, quantity, and temporal data creates strong potential for:
# - supply-chain analytics,
# - inventory optimization,
# - and AI-driven demand forecasting systems.

# %%
df.shape
# Out:
# (310544, 5)

# %% [markdown]
# # Dataset Shape Analysis
#
# ## Overview
#
# The shape of a dataset represents:
# - the total number of records,
# - and the number of available features.
#
# This helps evaluate:
# - dataset scale,
# - analytical depth,
# - and modeling potential.
#
# ---
#
# # Dataset Shape
#
# | Metric | Value |
# |---|---|
# | Number of Rows | 310,544 |
# | Number of Columns | 5 |
#
# ---
#
# # Interpretation
#
# ## Total Records = 310,544
#
# - The dataset contains over 310,000 inventory records.
# - Each row represents weekly inventory information for a specific retailer-product combination.
#
# ### Business Insight
#
# This indicates:
# - large-scale operational coverage,
# - extensive inventory tracking,
# - and strong transactional granularity.
#
# ---
#
# ## Total Features = 5
#
# The dataset includes:
# - retailer identifiers,
# - product information,
# - inventory quantities,
# - and weekly tracking dates.
#
# ### Analytical Importance
#
# These features support:
# - inventory monitoring,
# - product-level analysis,
# - and demand forecasting.
#
# ---
#
# # Data Scale Observation
#
# The dataset is relatively large and suitable for:
# - advanced analytics,
# - large-scale reporting,
# - and machine learning applications.
#
# The high row count improves:
# - trend reliability,
# - forecasting capability,
# - and statistical robustness.
#
# ---
#
# # AI/ML Relevance
#
# The dataset size is highly beneficial for:
# - demand prediction,
# - inventory forecasting,
# - anomaly detection,
# - and stock optimization models.
#
# The large number of observations can improve:
# - model generalization,
# - prediction accuracy,
# - and trend learning.
#
# ---
#
# # Final Interpretation
#
# The dataset contains 310,544 operational inventory records and 5 meaningful features, providing a strong foundation for:
# - supply-chain analytics,
# - inventory intelligence,
# - and AI-driven forecasting systems.

# %%
df.columns
# Out:
# Index(['retailer_id', 'sku_id', 'sku_name', 'sku_qty', 'week_end_date'], dtype='str')

# %% [markdown]
# # Feature Analysis
#
# ## Overview
#
# The dataset contains 5 features related to:
# - retailers,
# - agricultural products,
# - inventory quantities,
# - and weekly stock tracking.
#
# These features provide valuable insights for:
# - inventory management,
# - demand forecasting,
# - and supply-chain analytics.
#
# ---
#
# # Dataset Features
#
# | Feature | Description |
# |---|---|
# | retailer_id | Unique retailer identifier |
# | sku_id | Unique product SKU identifier |
# | sku_name | Name of the agricultural product |
# | sku_qty | Quantity of product available |
# | week_end_date | Weekly inventory tracking date |
#
# ---
#
# # Feature-Level Interpretation
#
# ## `retailer_id`
#
# - Represents unique retailers in the inventory system.
# - Useful for retailer-level stock analysis.
#
# ### Business Importance
#
# Supports:
# - retailer performance monitoring,
# - inventory allocation,
# - and stock distribution analysis.
#
# ---
#
# ## `sku_id`
#
# - Represents unique product identifiers.
# - Helps distinguish products accurately across records.
#
# ### Analytical Importance
#
# Useful for:
# - product tracking,
# - inventory mapping,
# - and SKU-level analysis.
#
# ---
#
# ## `sku_name`
#
# - Contains descriptive product names.
# - Improves interpretability of product-related analysis.
#
# ### Business Insight
#
# Supports:
# - product performance evaluation,
# - stock movement analysis,
# - and demand monitoring.
#
# ---
#
# ## `sku_qty`
#
# - Represents inventory quantity available for a product.
# - Acts as the primary numerical inventory metric.
#
# ### Operational Importance
#
# Useful for:
# - stock monitoring,
# - demand forecasting,
# - and inventory optimization.
#
# ---
#
# ## `week_end_date`
#
# - Represents weekly inventory reporting dates.
# - Enables temporal tracking of stock levels.
#
# ### AI/ML Relevance
#
# Supports:
# - time-series analysis,
# - inventory forecasting,
# - and seasonal trend evaluation.
#
# ---
#
# # Dataset Structure Observation
#
# The dataset follows a structured inventory hierarchy:
#
# `Retailer → Product → Weekly Quantity`
#
# This structure supports:
# - granular inventory intelligence,
# - operational reporting,
# - and supply-chain monitoring.
#
# ---
#
# # AI/ML Relevance
#
# The features are highly suitable for:
# - inventory prediction,
# - anomaly detection,
# - stock optimization,
# - and retailer-product recommendation systems.
#
# Potential engineered features include:
# - average weekly stock,
# - stock turnover trends,
# - inventory volatility,
# - and seasonal demand patterns.
#
# ---
#
# # Final Interpretation
#
# The dataset features are well-structured and operationally valuable. Together, they provide a strong foundation for:
# - inventory analytics,
# - supply-chain intelligence,
# - and AI-driven forecasting systems.

# %%
df.isnull().sum()
# Out:
# retailer_id      0
# sku_id           0
# sku_name         0
# sku_qty          0
# week_end_date    0
# dtype: int64

# %% [markdown]
# # Missing Value Analysis
#
# ## Overview
#
# Missing value analysis helps evaluate:
# - data completeness,
# - dataset reliability,
# - and preprocessing requirements.
#
# Datasets without missing values are generally more suitable for:
# - statistical analysis,
# - forecasting,
# - and machine learning applications.
#
# ---
#
# # Missing Value Summary
#
# | Feature | Missing Values |
# |---|---|
# | retailer_id | 0 |
# | sku_id | 0 |
# | sku_name | 0 |
# | sku_qty | 0 |
# | week_end_date | 0 |
#
# ---
#
# # Interpretation
#
# ## No Missing Values Detected
#
# All features in the dataset are completely populated with:
# - zero null values,
# - strong structural consistency,
# - and reliable inventory information.
#
# This indicates excellent data quality.
#
# ---
#
# # Feature-Level Observations
#
# ## `retailer_id`
#
# - Every inventory record is linked to a retailer.
# - Ensures accurate retailer-level stock analysis.
#
# ---
#
# ## `sku_id`
#
# - Product identifiers are fully available.
# - Supports reliable SKU-level tracking and inventory management.
#
# ---
#
# ## `sku_name`
#
# - Product names are consistently recorded.
# - Improves interpretability and reporting quality.
#
# ---
#
# ## `sku_qty`
#
# - Inventory quantity values are complete across all records.
# - Enables uninterrupted stock analysis and forecasting.
#
# ---
#
# ## `week_end_date`
#
# - Weekly tracking dates are fully populated.
# - Supports accurate time-series and trend analysis.
#
# ---
#
# # Business Importance
#
# Complete inventory data improves:
# - operational visibility,
# - stock monitoring accuracy,
# - and supply-chain decision-making.
#
# The absence of missing values also reduces:
# - preprocessing effort,
# - imputation requirements,
# - and analytical uncertainty.
#
# ---
#
# # AI/ML Relevance
#
# Since no missing values exist:
# - preprocessing becomes simpler,
# - model reliability improves,
# - and forecasting quality becomes stronger.
#
# This benefits:
# - inventory prediction,
# - demand forecasting,
# - anomaly detection,
# - and stock optimization systems.
#
# ---
#
# # Final Interpretation
#
# The dataset demonstrates excellent completeness with no missing values across all inventory features. This creates a strong foundation for:
# - inventory analytics,
# - operational intelligence,
# - and AI-driven supply-chain optimization systems.

# %%
df.dtypes
# Out:
# retailer_id        str
# sku_id             str
# sku_name           str
# sku_qty          int64
# week_end_date      str
# dtype: object

# %% [markdown]
# # Data Type Analysis
#
# ## Overview
#
# Data type analysis helps verify whether dataset features are stored in appropriate formats for:
# - analysis,
# - preprocessing,
# - visualization,
# - and machine learning.
#
# Correct data types improve:
# - computational efficiency,
# - analytical accuracy,
# - and data consistency.
#
# ---
#
# # Feature Data Types
#
# | Feature | Data Type |
# |---|---|
# | retailer_id | object (string) |
# | sku_id | object (string) |
# | sku_name | object (string) |
# | sku_qty | int64 |
# | week_end_date | object (string) |
#
# ---
#
# # Interpretation
#
# ## Categorical Features
#
# ### `retailer_id`
#
# - Stored correctly as string data.
# - Represents unique retailer identifiers.
#
# ### Business Importance
#
# Useful for:
# - retailer-level tracking,
# - inventory allocation,
# - and operational analysis.
#
# ---
#
# ### `sku_id`
#
# - Represents unique product SKU identifiers.
# - Properly stored as categorical text data.
#
# ### Analytical Importance
#
# Supports:
# - product mapping,
# - SKU-level analysis,
# - and inventory tracking.
#
# ---
#
# ### `sku_name`
#
# - Contains descriptive product names.
# - Improves interpretability of inventory analysis.
#
# ### Business Insight
#
# Useful for:
# - product performance evaluation,
# - stock movement analysis,
# - and reporting.
#
# ---
#
# # Numerical Feature
#
# ## `sku_qty`
#
# - Stored as integer (`int64`) values.
# - Represents inventory quantity levels.
#
# ### Operational Importance
#
# Useful for:
# - inventory forecasting,
# - stock optimization,
# - and demand analysis.
#
# ### AI/ML Relevance
#
# Can support:
# - time-series forecasting,
# - anomaly detection,
# - and inventory prediction models.
#
# ---
#
# # Temporal Feature Observation
#
# ## `week_end_date`
#
# - Currently stored as string (`object`) type.
# - Represents weekly inventory reporting dates.
#
# ### Recommended Improvement
#
# Convert this feature into datetime format for:
# - trend analysis,
# - seasonal evaluation,
# - forecasting,
# - and time-series modeling.
#
# ### Suggested Conversion
#
# ```python
# df['week_end_date'] = pd.to_datetime(df['week_end_date'])
# ```
#
# ---
#
# # Overall Dataset Structure
#
# The dataset contains a balanced combination of:
# - categorical identifiers,
# - product information,
# - numerical inventory metrics,
# - and temporal tracking features.
#
# This structure is highly suitable for:
# - supply-chain analytics,
# - inventory intelligence,
# - and AI/ML forecasting systems.
#
# ---
#
# # Final Interpretation
#
# The dataset data types are mostly well-structured and analytically appropriate. The primary enhancement opportunity is converting `week_end_date` into datetime format to enable advanced temporal analysis and inventory forecasting.

# %%
df.describe()
# Out:
#              sku_qty
# count  310544.000000
# mean       87.110760
# std        64.171073
# min         0.000000
# 25%        32.000000
# 50%        77.000000
# 75%       134.000000
# max       451.000000

# %% [markdown]
# # Numerical Feature Statistical Analysis
#
# ## Overview
#
# The dataset contains one primary numerical inventory feature:
#
# - `sku_qty`
#
# This feature represents product stock quantity at the retailer level and is highly valuable for:
# - inventory analysis,
# - demand forecasting,
# - stock optimization,
# - and supply-chain intelligence.
#
# ---
#
# # SKU Quantity Statistical Summary
#
# | Metric | Value |
# |---|---|
# | Count | 310,544 |
# | Mean | 87.11 |
# | Standard Deviation | 64.17 |
# | Minimum | 0 |
# | 25th Percentile | 32 |
# | Median (50%) | 77 |
# | 75th Percentile | 134 |
# | Maximum | 451 |
#
# ---
#
# # Interpretation
#
# ## Total Records = 310,544
#
# - A very large number of inventory observations are available.
# - This improves:
#   - statistical reliability,
#   - forecasting capability,
#   - and trend analysis quality.
#
# ---
#
# ## Mean Inventory Quantity ≈ 87
#
# - On average, retailers hold approximately 87 units per SKU.
#
# ### Business Insight
#
# This suggests:
# - moderate inventory levels,
# - active product movement,
# - and operational stock management.
#
# ---
#
# ## Median Inventory Quantity = 77
#
# - The median is slightly lower than the mean.
#
# ### Interpretation
#
# This indicates:
# - mild right skewness,
# - where some high inventory values increase the overall average.
#
# ---
#
# ## Inventory Range
#
# | Metric | Value |
# |---|---|
# | Minimum | 0 |
# | Maximum | 451 |
#
# ### Interpretation
#
# The dataset includes:
# - out-of-stock situations,
# - low inventory conditions,
# - and high-stock inventory cases.
#
# ### Business Importance
#
# This variation is valuable for:
# - stock monitoring,
# - replenishment planning,
# - and supply-chain optimization.
#
# ---
#
# ## Standard Deviation ≈ 64.17
#
# - Inventory quantities show high variability across records.
#
# ### Interpretation
#
# This indicates:
# - diverse stock levels,
# - varying product demand,
# - and inconsistent inventory movement patterns.
#
# ---
#
# # Quartile Analysis
#
# ## 25% of inventory values are below 32
#
# - Represents low-stock inventory situations.
#
# ---
#
# ## 50% of inventory values are below 77
#
# - Indicates that most inventory levels remain moderate.
#
# ---
#
# ## 75% of inventory values are below 134
#
# - Suggests high inventory values are less common.
#
# ---
#
# # Outlier Observation
#
# ## Maximum Inventory = 451
#
# - Significantly larger than the median and upper quartile.
#
# ### Possible Reasons
#
# - bulk stocking,
# - high-demand products,
# - seasonal inventory buildup,
# - or operational overstocking.
#
# ### AI/ML Consideration
#
# Outlier handling techniques such as:
# - IQR analysis,
# - winsorization,
# - or normalization
#
# may improve modeling performance.
#
# ---
#
# # AI/ML Relevance
#
# The `sku_qty` feature is highly valuable for:
# - demand forecasting,
# - inventory prediction,
# - anomaly detection,
# - and stock optimization systems.
#
# Potential engineered features include:
# - moving averages,
# - stock volatility,
# - inventory turnover,
# - and seasonal demand indicators.
#
# ---
#
# # Final Interpretation
#
# The `sku_qty` feature demonstrates strong operational and analytical value with significant inventory variation across retailers and products. The feature provides an excellent foundation for:
# - inventory intelligence,
# - forecasting systems,
# - and AI-driven supply-chain optimization.

# %%
df['sku_name'].value_counts()
# Out:
# sku_name
# Score 250 EC         26650
# Alto 5 SC            26546
# Vibrance Integral    26468
# Amistar 250 SC       26130
# Movondo              26130
# Axial 50 EC          26078
# Topik 15 WP          26078
# Cruiser 350 FS       25636
# Kavach 75 WP         25428
# Vertimec 1.8 EC      25402
# Tilt 250 EC          25220
# Actara 25 WG         24778
# Name: count, dtype: int64

# %% [markdown]
# # SKU Name Distribution Analysis
#
# ## Overview
#
# The `sku_name` feature represents agricultural products available in retailer inventory records.
#
# Analyzing SKU frequency helps understand:
# - product distribution,
# - inventory coverage,
# - product popularity,
# - and operational focus.
#
# ---
#
# # SKU Frequency Distribution
#
# | SKU Name | Count |
# |---|---|
# | Score 250 EC | 26,650 |
# | Alto 5 SC | 26,546 |
# | Vibrance Integral | 26,468 |
# | Amistar 250 SC | 26,130 |
# | Movondo | 26,130 |
# | Axial 50 EC | 26,078 |
# | Topik 15 WP | 26,078 |
# | Cruiser 350 FS | 25,636 |
# | Kavach 75 WP | 25,428 |
# | Vertimec 1.8 EC | 25,402 |
# | Tilt 250 EC | 25,220 |
# | Actara 25 WG | 24,778 |
#
# ---
#
# # Interpretation
#
# ## Balanced Product Distribution
#
# - Product counts are relatively evenly distributed across all SKUs.
# - No single product overwhelmingly dominates the dataset.
#
# ### Business Insight
#
# This suggests:
# - balanced inventory management,
# - diversified product allocation,
# - and broad product coverage.
#
# ---
#
# # High Representation Products
#
# ## Score 250 EC
#
# - Has the highest frequency in the dataset.
# - Indicates strong inventory presence across retailers.
#
# ### Business Importance
#
# May represent:
# - high-demand products,
# - frequently stocked inventory,
# - or strategically important SKUs.
#
# ---
#
# # Moderate Variation Across Products
#
# - Frequency differences between SKUs are relatively small.
# - Most products appear between 24,000 and 27,000 times.
#
# ### Interpretation
#
# This indicates:
# - consistent inventory tracking,
# - stable product distribution,
# - and balanced operational coverage.
#
# ---
#
# # Product Portfolio Insights
#
# The product list includes:
# - fungicides,
# - insecticides,
# - seed treatment products,
# - and crop protection solutions.
#
# ### Strategic Importance
#
# This diversity supports:
# - multi-crop agricultural operations,
# - broad market engagement,
# - and varied retailer demand patterns.
#
# ---
#
# # AI/ML Relevance
#
# The `sku_name` feature is highly useful for:
# - product recommendation systems,
# - inventory forecasting,
# - demand prediction,
# - and retailer-product analytics.
#
# Balanced SKU representation improves:
# - model fairness,
# - learning stability,
# - and prediction quality.
#
# ---
#
# # Business Importance
#
# SKU-level analysis can help:
# - identify fast-moving products,
# - optimize stock allocation,
# - improve supply-chain planning,
# - and support product performance evaluation.
#
# ---
#
# # Final Interpretation
#
# The SKU distribution demonstrates strong product diversity and balanced inventory representation across agricultural products. The `sku_name` feature provides valuable operational intelligence for:
# - inventory analytics,
# - demand forecasting,
# - and AI-driven supply-chain optimization systems.

# %%
df['week_end_date'].min()
# Out:
# '2025-10-05'

# %%
df['week_end_date'].max()
# Out:
# '2026-03-29'

# %% [markdown]
# # Week End Date Range Analysis
#
# ## Overview
#
# The `week_end_date` feature represents the weekly inventory reporting timeline for retailer stock data.
#
# Analyzing the date range helps understand:
# - operational coverage duration,
# - inventory tracking continuity,
# - seasonal coverage,
# - and temporal scope.
#
# ---
#
# # Date Range Summary
#
# | Metric | Value |
# |---|---|
# | Earliest Date | 2025-10-05 |
# | Latest Date | 2026-03-29 |
#
# ---
#
# # Interpretation
#
# ## Inventory Tracking Timeline
#
# - The dataset spans nearly 6 months of weekly inventory records.
# - Inventory activity is tracked from October 2025 to March 2026.
#
# ### Business Insight
#
# This provides sufficient temporal coverage for:
# - inventory trend analysis,
# - stock movement monitoring,
# - and seasonal demand evaluation.
#
# ---
#
# # Seasonal Coverage
#
# The timeline includes:
# - post-monsoon agricultural operations,
# - winter crop activity,
# - and early 2026 inventory cycles.
#
# ### Strategic Importance
#
# This period may capture:
# - seasonal stocking behavior,
# - crop protection demand patterns,
# - and agricultural product consumption trends.
#
# ---
#
# # Weekly Granularity
#
# The dataset records inventory at a weekly level.
#
# ### Analytical Benefits
#
# Weekly tracking supports:
# - time-series analysis,
# - short-term forecasting,
# - stock monitoring,
# - and operational planning.
#
# ---
#
# # AI/ML Relevance
#
# The `week_end_date` feature can support:
# - demand forecasting,
# - inventory prediction,
# - seasonal trend analysis,
# - and supply-chain optimization.
#
# Additional engineered features may include:
# - month,
# - quarter,
# - season,
# - and inventory cycle indicators.
#
# ---
#
# # Data Quality Observation
#
# The date range appears:
# - continuous,
# - operationally realistic,
# - and chronologically structured.
#
# No abnormal or inconsistent dates are observed.
#
# ---
#
# # Final Interpretation
#
# The dataset captures weekly inventory activity across a well-defined 6-month period, providing strong temporal coverage for:
# - inventory analytics,
# - demand forecasting,
# - and AI-driven supply-chain optimization systems.

# %%
df['sku_name'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='sku_name'>

# %% [markdown]
# # SKU Distribution Visualization Analysis
#
# ## Overview
#
# The bar chart visualizes the frequency distribution of different agricultural products (`sku_name`) in the inventory dataset.
#
# The visualization helps understand:
# - product representation,
# - inventory distribution balance,
# - and operational product coverage.
#
# ---
#
# # Key Observations
#
# | SKU Name | Approximate Count |
# |---|---|
# | Score 250 EC | ~26,650 |
# | Alto 5 SC | ~26,546 |
# | Vibrance Integral | ~26,468 |
# | Amistar 250 SC | ~26,130 |
# | Movondo | ~26,130 |
# | Axial 50 EC | ~26,078 |
# | Topik 15 WP | ~26,078 |
# | Cruiser 350 FS | ~25,636 |
# | Kavach 75 WP | ~25,428 |
# | Vertimec 1.8 EC | ~25,402 |
# | Tilt 250 EC | ~25,220 |
# | Actara 25 WG | ~24,778 |
#
# ---
#
# # Interpretation
#
# ## Balanced SKU Representation
#
# - The chart shows highly balanced inventory representation across all products.
# - Bar heights are relatively similar with only minor variations.
#
# ### Business Insight
#
# This indicates:
# - diversified inventory allocation,
# - stable product distribution,
# - and balanced operational stocking.
#
# ---
#
# # Highest Frequency Product
#
# ## Score 250 EC
#
# - Appears as the most frequently occurring SKU.
# - Indicates strong inventory presence across retailers.
#
# ### Operational Importance
#
# This may suggest:
# - high product demand,
# - strong market performance,
# - or strategic stocking priority.
#
# ---
#
# # Lower Frequency Product
#
# ## Actara 25 WG
#
# - Shows the lowest frequency among listed SKUs.
# - However, the difference is relatively small compared to other products.
#
# ### Interpretation
#
# This suggests:
# - overall inventory consistency,
# - and absence of extreme product imbalance.
#
# ---
#
# # Visualization Insights
#
# The chart demonstrates:
# - uniform inventory distribution,
# - broad product coverage,
# - and operational consistency.
#
# No SKU appears significantly underrepresented or excessively dominant.
#
# ---
#
# # Product Portfolio Observation
#
# The products shown appear related to:
# - fungicides,
# - insecticides,
# - crop protection chemicals,
# - and seed treatment solutions.
#
# ### Strategic Importance
#
# A diversified product portfolio supports:
# - multi-crop operations,
# - broader market reach,
# - and flexible inventory management.
#
# ---
#
# # AI/ML Relevance
#
# Balanced SKU distributions are highly beneficial for:
# - demand forecasting,
# - inventory prediction,
# - recommendation systems,
# - and operational analytics.
#
# The balanced representation reduces:
# - product bias,
# - training imbalance,
# - and prediction instability.
#
# ---
#
# # Final Interpretation
#
# The visualization demonstrates strong balance and diversity across agricultural products in the inventory system. The `sku_name` feature provides valuable operational intelligence for:
# - inventory analytics,
# - product performance monitoring,
# - and AI-driven supply-chain optimization systems.

# %% [markdown]
# # retailer_pos.csv Analysis

# %%
df = pd.read_csv("../datasets/retailer_pos.csv")

# %%
df.head()
# Out:
#   retailer_id    transaction_id        sku_id      sku_name  sku_qty  \
# 0   RTL_00001  POS_f457022d4d51  SY_SCO_250EC  Score 250 EC       81
# 1   RTL_00001  POS_f2f5eaaaf5e4  SY_SCO_250EC  Score 250 EC        3
# 2   RTL_00001  POS_94af270ca790   SY_AXI_50EC   Axial 50 EC        1
# 3   RTL_00001  POS_a6e6345ef25c   SY_AXI_50EC   Axial 50 EC        1
# 4   RTL_00001  POS_3dfd7d3a4837   SY_AXI_50EC   Axial 50 EC        1
#
#    sku_price transaction_date
# 0    1539.21       2025-10-10
# 1    1644.39       2025-10-14
# 2     393.85       2025-10-18
# 3    1257.72       2025-10-18
# 4    1028.55       2025-10-16

# %% [markdown]
# # Retailer POS Dataset Analysis
#
# ## Overview
#
# The `retailer_pos.csv` dataset contains Point-of-Sale (POS) transaction records related to:
# - retailers,
# - agricultural products,
# - sales quantities,
# - pricing,
# - and transaction timelines.
#
# The dataset is highly valuable for:
# - sales analytics,
# - demand forecasting,
# - retailer behavior analysis,
# - and revenue intelligence.
#
# ---
#
# # Dataset Features
#
# | Feature | Description |
# |---|---|
# | retailer_id | Unique retailer identifier |
# | transaction_id | Unique POS transaction identifier |
# | sku_id | Unique product SKU identifier |
# | sku_name | Name of the agricultural product |
# | sku_qty | Quantity sold in the transaction |
# | sku_price | Product transaction price |
# | transaction_date | Date of transaction |
#
# ---
#
# # Initial Observations
#
# ## Retailer-Level Sales Tracking
#
# ### `retailer_id`
#
# - Represents retailers involved in transactions.
# - Enables retailer-wise sales analysis.
#
# ### Business Importance
#
# Useful for:
# - retailer performance monitoring,
# - sales segmentation,
# - and demand analysis.
#
# ---
#
# ## Transaction Information
#
# ### `transaction_id`
#
# - Represents unique POS transactions.
# - Ensures transaction-level granularity.
#
# ### Analytical Importance
#
# Supports:
# - transaction tracking,
# - sales auditing,
# - and operational transparency.
#
# ---
#
# # Product Information
#
# ## `sku_id`
#
# - Represents unique product identifiers.
# - Enables accurate product mapping across transactions.
#
# ---
#
# ## `sku_name`
#
# - Contains descriptive agricultural product names.
#
# ### Example Products
#
# - Score 250 EC
# - Axial 50 EC
#
# ### Business Insight
#
# Products appear related to:
# - agrochemicals,
# - crop protection products,
# - and agricultural solutions.
#
# ---
#
# # Sales Quantity Analysis
#
# ## `sku_qty`
#
# - Represents quantity sold per transaction.
# - Useful for demand and consumption analysis.
#
# ### Operational Importance
#
# Supports:
# - sales forecasting,
# - inventory planning,
# - and product demand monitoring.
#
# ---
#
# # Pricing Feature
#
# ## `sku_price`
#
# - Represents transaction-level product pricing.
#
# ### Business Relevance
#
# Useful for:
# - revenue analysis,
# - pricing strategy evaluation,
# - and profitability assessment.
#
# ---
#
# # Temporal Feature
#
# ## `transaction_date`
#
# - Represents transaction occurrence dates.
# - Enables time-based sales analysis.
#
# ### Analytical Importance
#
# Supports:
# - trend analysis,
# - seasonality detection,
# - and forecasting.
#
# ---
#
# # Dataset Structure Observation
#
# The dataset follows a transactional hierarchy:
#
# `Retailer → Transaction → Product → Sales`
#
# This structure supports:
# - granular sales intelligence,
# - operational reporting,
# - and customer demand analysis.
#
# ---
#
# # AI/ML Relevance
#
# The dataset can support:
# - sales forecasting,
# - recommendation systems,
# - demand prediction,
# - anomaly detection,
# - and dynamic pricing analysis.
#
# Potential engineered features include:
# - total transaction value,
# - average purchase quantity,
# - retailer sales frequency,
# - and product demand trends.
#
# ---
#
# # Final Interpretation
#
# The `retailer_pos.csv` dataset provides highly granular transactional intelligence across retailers and agricultural products. The combination of sales quantity, pricing, product, and temporal information creates strong potential for:
# - sales analytics,
# - demand forecasting,
# - and AI-driven retail intelligence systems.

# %%
df.shape
# Out:
# (235042, 7)

# %% [markdown]
# # Dataset Shape Analysis
#
# ## Overview
#
# The shape of a dataset represents:
# - the total number of records,
# - and the number of available features.
#
# This helps evaluate:
# - dataset scale,
# - analytical depth,
# - and modeling capability.
#
# ---
#
# # Dataset Shape
#
# | Metric | Value |
# |---|---|
# | Number of Rows | 235,042 |
# | Number of Columns | 7 |
#
# ---
#
# # Interpretation
#
# ## Total Records = 235,042
#
# - The dataset contains over 235,000 POS transaction records.
# - Each row represents an individual retailer-product transaction.
#
# ### Business Insight
#
# This indicates:
# - high transactional activity,
# - large-scale sales operations,
# - and strong retail-level granularity.
#
# ---
#
# ## Total Features = 7
#
# The dataset includes:
# - retailer identifiers,
# - transaction details,
# - product information,
# - sales quantities,
# - pricing,
# - and transaction dates.
#
# ### Analytical Importance
#
# These features support:
# - sales analytics,
# - demand forecasting,
# - revenue analysis,
# - and retailer intelligence.
#
# ---
#
# # Data Scale Observation
#
# The dataset is relatively large and highly suitable for:
# - advanced analytics,
# - business intelligence,
# - and machine learning applications.
#
# The large number of records improves:
# - statistical reliability,
# - forecasting accuracy,
# - and pattern detection.
#
# ---
#
# # Operational Insight
#
# The transactional structure enables:
# - retailer-level sales tracking,
# - SKU-level demand monitoring,
# - and time-based performance analysis.
#
# This level of granularity is highly valuable for operational decision-making.
#
# ---
#
# # AI/ML Relevance
#
# The dataset size is highly beneficial for:
# - demand forecasting,
# - recommendation systems,
# - pricing analytics,
# - and anomaly detection models.
#
# The large record volume improves:
# - model generalization,
# - predictive stability,
# - and learning performance.
#
# ---
#
# # Final Interpretation
#
# The dataset contains 235,042 detailed POS transaction records and 7 meaningful features, providing a strong foundation for:
# - sales intelligence,
# - retail analytics,
# - and AI-driven forecasting systems.

# %%
df.columns
# Out:
# Index(['retailer_id', 'transaction_id', 'sku_id', 'sku_name', 'sku_qty',
#        'sku_price', 'transaction_date'],
#       dtype='str')

# %% [markdown]
# # Feature Analysis
#
# ## Overview
#
# The dataset contains 7 features related to:
# - retailers,
# - POS transactions,
# - agricultural products,
# - sales quantities,
# - pricing,
# - and transaction timelines.
#
# These features provide strong analytical value for:
# - sales intelligence,
# - demand forecasting,
# - and retail analytics.
#
# ---
#
# # Dataset Features
#
# | Feature | Description |
# |---|---|
# | retailer_id | Unique retailer identifier |
# | transaction_id | Unique transaction identifier |
# | sku_id | Unique product SKU identifier |
# | sku_name | Name of the agricultural product |
# | sku_qty | Quantity sold in the transaction |
# | sku_price | Product transaction price |
# | transaction_date | Date of transaction |
#
# ---
#
# # Feature-Level Interpretation
#
# ## `retailer_id`
#
# - Represents individual retailers participating in transactions.
# - Useful for retailer-level sales analysis.
#
# ### Business Importance
#
# Supports:
# - retailer performance tracking,
# - sales segmentation,
# - and operational monitoring.
#
# ---
#
# ## `transaction_id`
#
# - Represents unique POS transaction records.
# - Ensures transaction-level granularity and traceability.
#
# ### Analytical Importance
#
# Useful for:
# - transaction auditing,
# - operational analysis,
# - and sales tracking.
#
# ---
#
# ## `sku_id`
#
# - Represents unique product identifiers.
# - Enables accurate SKU-level mapping and analysis.
#
# ### Business Relevance
#
# Supports:
# - product tracking,
# - inventory-sales integration,
# - and demand analysis.
#
# ---
#
# ## `sku_name`
#
# - Contains descriptive product names.
# - Improves interpretability of sales analysis.
#
# ### Operational Importance
#
# Useful for:
# - product performance evaluation,
# - category analysis,
# - and reporting.
#
# ---
#
# ## `sku_qty`
#
# - Represents quantity sold per transaction.
# - Acts as an important numerical sales metric.
#
# ### Business Insight
#
# Useful for:
# - demand forecasting,
# - sales trend analysis,
# - and inventory planning.
#
# ---
#
# ## `sku_price`
#
# - Represents transaction-level product pricing.
# - Provides financial and revenue-related insights.
#
# ### Analytical Importance
#
# Supports:
# - revenue analysis,
# - pricing strategy evaluation,
# - and profitability assessment.
#
# ---
#
# ## `transaction_date`
#
# - Represents transaction occurrence dates.
# - Enables time-based sales analysis.
#
# ### AI/ML Relevance
#
# Supports:
# - trend analysis,
# - seasonality detection,
# - forecasting,
# - and time-series modeling.
#
# ---
#
# # Dataset Structure Observation
#
# The dataset follows a structured transactional hierarchy:
#
# `Retailer → Transaction → Product → Sales`
#
# This structure supports:
# - detailed sales intelligence,
# - operational reporting,
# - and product demand analysis.
#
# ---
#
# # AI/ML Relevance
#
# The dataset features are highly suitable for:
# - sales forecasting,
# - recommendation systems,
# - pricing analytics,
# - and customer behavior modeling.
#
# Potential engineered features include:
# - total transaction value,
# - average retailer spending,
# - sales frequency,
# - and product demand trends.
#
# ---
#
# # Final Interpretation
#
# The dataset features are well-structured and highly valuable for operational and analytical applications. Together, they provide a strong foundation for:
# - retail intelligence,
# - sales analytics,
# - and AI-driven forecasting systems.

# %%
df.isnull().sum()
# Out:
# retailer_id         0
# transaction_id      0
# sku_id              0
# sku_name            0
# sku_qty             0
# sku_price           0
# transaction_date    0
# dtype: int64

# %% [markdown]
# # Missing Value Analysis
#
# ## Overview
#
# Missing value analysis helps evaluate:
# - dataset completeness,
# - data reliability,
# - and preprocessing requirements.
#
# Datasets without missing values are highly suitable for:
# - statistical analysis,
# - forecasting,
# - and machine learning applications.
#
# ---
#
# # Missing Value Summary
#
# | Feature | Missing Values |
# |---|---|
# | retailer_id | 0 |
# | transaction_id | 0 |
# | sku_id | 0 |
# | sku_name | 0 |
# | sku_qty | 0 |
# | sku_price | 0 |
# | transaction_date | 0 |
#
# ---
#
# # Interpretation
#
# ## No Missing Values Detected
#
# All features in the dataset are fully populated with:
# - zero null values,
# - strong structural consistency,
# - and reliable transactional information.
#
# This indicates excellent data quality.
#
# ---
#
# # Feature-Level Observations
#
# ## `retailer_id`
#
# - Every transaction is linked to a retailer.
# - Enables accurate retailer-level sales analysis.
#
# ---
#
# ## `transaction_id`
#
# - All transactions contain unique identifiers.
# - Supports transaction traceability and operational transparency.
#
# ---
#
# ## `sku_id`
#
# - Product identifiers are fully available.
# - Ensures reliable SKU-level sales tracking.
#
# ---
#
# ## `sku_name`
#
# - Product names are consistently recorded.
# - Improves interpretability and reporting quality.
#
# ---
#
# ## `sku_qty`
#
# - Sales quantity values are complete across all transactions.
# - Supports uninterrupted demand and sales analysis.
#
# ---
#
# ## `sku_price`
#
# - Pricing information is fully available.
# - Enables accurate revenue and profitability analysis.
#
# ---
#
# ## `transaction_date`
#
# - Transaction dates are completely populated.
# - Supports reliable time-series and trend analysis.
#
# ---
#
# # Business Importance
#
# Complete transactional data improves:
# - sales visibility,
# - forecasting accuracy,
# - and operational decision-making.
#
# The absence of missing values also reduces:
# - preprocessing effort,
# - imputation complexity,
# - and analytical uncertainty.
#
# ---
#
# # AI/ML Relevance
#
# Since no missing values exist:
# - preprocessing becomes simpler,
# - model reliability improves,
# - and predictive performance strengthens.
#
# This benefits:
# - demand forecasting,
# - recommendation systems,
# - pricing analytics,
# - and anomaly detection models.
#
# ---
#
# # Final Interpretation
#
# The dataset demonstrates excellent completeness with no missing values across all transactional features. This creates a strong foundation for:
# - retail analytics,
# - sales intelligence,
# - and AI-driven forecasting systems.

# %%
df.dtypes
# Out:
# retailer_id             str
# transaction_id          str
# sku_id                  str
# sku_name                str
# sku_qty               int64
# sku_price           float64
# transaction_date        str
# dtype: object

# %% [markdown]
# # Data Type Analysis
#
# ## Overview
#
# Data type analysis helps verify whether dataset features are stored in appropriate formats for:
# - analysis,
# - preprocessing,
# - visualization,
# - and machine learning.
#
# Correct data types improve:
# - computational efficiency,
# - analytical accuracy,
# - and data consistency.
#
# ---
#
# # Feature Data Types
#
# | Feature | Data Type |
# |---|---|
# | retailer_id | object (string) |
# | transaction_id | object (string) |
# | sku_id | object (string) |
# | sku_name | object (string) |
# | sku_qty | int64 |
# | sku_price | float64 |
# | transaction_date | object (string) |
#
# ---
#
# # Interpretation
#
# ## Categorical Features
#
# ### `retailer_id`
#
# - Stored correctly as string data.
# - Represents unique retailers in the sales system.
#
# ### Business Importance
#
# Useful for:
# - retailer-level analysis,
# - customer segmentation,
# - and sales monitoring.
#
# ---
#
# ### `transaction_id`
#
# - Represents unique POS transaction identifiers.
# - Properly stored as categorical text data.
#
# ### Analytical Importance
#
# Supports:
# - transaction tracking,
# - auditing,
# - and operational transparency.
#
# ---
#
# ### `sku_id`
#
# - Represents unique product identifiers.
# - Useful for SKU-level analysis and tracking.
#
# ---
#
# ### `sku_name`
#
# - Contains descriptive product names.
# - Improves interpretability of transactional analysis.
#
# ### Business Insight
#
# Supports:
# - product performance evaluation,
# - sales analytics,
# - and reporting.
#
# ---
#
# # Numerical Features
#
# ## `sku_qty`
#
# - Stored as integer (`int64`) values.
# - Represents quantity sold per transaction.
#
# ### Operational Importance
#
# Useful for:
# - demand forecasting,
# - sales trend analysis,
# - and inventory planning.
#
# ---
#
# ## `sku_price`
#
# - Stored as floating-point (`float64`) values.
# - Represents transaction-level product pricing.
#
# ### Business Importance
#
# Supports:
# - revenue analysis,
# - pricing optimization,
# - and profitability evaluation.
#
# ### AI/ML Relevance
#
# Useful for:
# - pricing prediction,
# - revenue forecasting,
# - and anomaly detection.
#
# ---
#
# # Temporal Feature Observation
#
# ## `transaction_date`
#
# - Currently stored as string (`object`) type.
# - Represents transaction occurrence dates.
#
# ### Recommended Improvement
#
# Convert this feature into datetime format for:
# - trend analysis,
# - seasonality detection,
# - forecasting,
# - and time-series modeling.
#
# ### Suggested Conversion
#
# ```python
# df['transaction_date'] = pd.to_datetime(df['transaction_date'])
# ```
#
# ---
#
# # Overall Dataset Structure
#
# The dataset contains a strong combination of:
# - categorical identifiers,
# - numerical sales metrics,
# - pricing information,
# - and temporal features.
#
# This structure is highly suitable for:
# - retail analytics,
# - sales intelligence,
# - and AI/ML forecasting systems.
#
# ---
#
# # Final Interpretation
#
# The dataset data types are mostly well-structured and analytically appropriate. The primary enhancement opportunity is converting `transaction_date` into datetime format to enable advanced temporal and forecasting analysis.

# %%
df.describe()
# Out:
#              sku_qty      sku_price
# count  235042.000000  235042.000000
# mean        9.247883    1290.615681
# std        19.375990     525.325244
# min         1.000000     380.040000
# 25%         2.000000     835.482500
# 50%         4.000000    1291.480000
# 75%         8.000000    1745.820000
# max       287.000000    2200.000000

# %% [markdown]
# # Numerical Feature Statistical Analysis
#
# ## Overview
#
# The dataset contains two major numerical transactional features:
#
# - `sku_qty`
# - `sku_price`
#
# These features help analyze:
# - product demand,
# - transaction behavior,
# - pricing patterns,
# - and revenue potential.
#
# ---
#
# # 1. SKU Quantity Analysis
#
# ## Statistical Summary for `sku_qty`
#
# | Metric | Value |
# |---|---|
# | Count | 235,042 |
# | Mean | 9.25 |
# | Standard Deviation | 19.38 |
# | Minimum | 1 |
# | 25th Percentile | 2 |
# | Median (50%) | 4 |
# | 75th Percentile | 8 |
# | Maximum | 287 |
#
# ---
#
# ## Interpretation
#
# ## Average Quantity Sold ≈ 9 Units
#
# - On average, transactions involve approximately 9 product units.
# - Most purchases appear relatively small in size.
#
# ### Business Insight
#
# This may indicate:
# - retail-level purchasing behavior,
# - frequent low-volume transactions,
# - or distributed demand patterns.
#
# ---
#
# ## Median Quantity = 4
#
# - The median is significantly lower than the mean.
#
# ### Interpretation
#
# This suggests:
# - right-skewed distribution,
# - where a few very large transactions increase the average.
#
# ---
#
# ## Quantity Variability
#
# ### Standard Deviation ≈ 19.38
#
# - Transaction quantities vary considerably across records.
#
# ### Business Importance
#
# This reflects:
# - varying retailer demand,
# - bulk purchase events,
# - and diverse purchasing behavior.
#
# ---
#
# ## Outlier Observation
#
# ### Maximum Quantity = 287
#
# - Significantly larger than the upper quartile value.
#
# ### Possible Reasons
#
# - bulk purchases,
# - seasonal stocking,
# - or large retailer transactions.
#
# ### AI/ML Consideration
#
# Outlier handling techniques such as:
# - IQR analysis,
# - winsorization,
# - or log transformation
#
# may improve model stability.
#
# ---
#
# # 2. SKU Price Analysis
#
# ## Statistical Summary for `sku_price`
#
# | Metric | Value |
# |---|---|
# | Count | 235,042 |
# | Mean | 1290.62 |
# | Standard Deviation | 525.33 |
# | Minimum | 380.04 |
# | 25th Percentile | 835.48 |
# | Median (50%) | 1291.48 |
# | 75th Percentile | 1745.82 |
# | Maximum | 2200 |
#
# ---
#
# ## Interpretation
#
# ## Average Product Price ≈ 1291
#
# - The average transaction price is approximately 1291 currency units.
#
# ### Business Insight
#
# This suggests:
# - medium-to-premium agricultural product pricing,
# - potentially specialized crop protection products,
# - or branded agrochemical solutions.
#
# ---
#
# ## Median Price ≈ Mean Price
#
# - The median and mean values are very close.
#
# ### Interpretation
#
# This indicates:
# - relatively balanced pricing distribution,
# - and limited pricing skewness.
#
# ---
#
# ## Price Variability
#
# ### Standard Deviation ≈ 525
#
# - Product prices show moderate variation.
#
# ### Business Importance
#
# This may reflect:
# - different product categories,
# - varying product formulations,
# - and premium vs standard products.
#
# ---
#
# ## Price Range
#
# | Metric | Value |
# |---|---|
# | Minimum | 380.04 |
# | Maximum | 2200 |
#
# ### Interpretation
#
# The dataset includes:
# - lower-cost products,
# - mid-range products,
# - and premium-priced agricultural solutions.
#
# ---
#
# # Combined Numerical Insights
#
# The numerical features indicate:
# - varying purchase behavior,
# - diverse pricing structures,
# - and broad transactional diversity.
#
# The combination of quantity and price creates strong potential for:
# - revenue estimation,
# - demand forecasting,
# - and profitability analysis.
#
# ---
#
# # AI/ML Relevance
#
# The numerical features are highly valuable for:
# - sales forecasting,
# - revenue prediction,
# - demand modeling,
# - and anomaly detection.
#
# Potential engineered features include:
# - transaction value,
# - average order size,
# - purchase frequency,
# - and revenue contribution metrics.
#
# ---
#
# # Final Interpretation
#
# The numerical transactional features demonstrate strong operational and analytical value. The dataset captures meaningful variation in:
# - purchase quantities,
# - pricing patterns,
# - and retailer transaction behavior.
#
# These features provide an excellent foundation for:
# - retail analytics,
# - sales intelligence,
# - and AI-driven forecasting systems.

# %%
df['sku_name'].value_counts()
# Out:
# sku_name
# Vibrance Integral    20123
# Alto 5 SC            20116
# Axial 50 EC          19843
# Score 250 EC         19838
# Topik 15 WP          19829
# Amistar 250 SC       19709
# Movondo              19489
# Cruiser 350 FS       19463
# Vertimec 1.8 EC      19401
# Kavach 75 WP         19182
# Tilt 250 EC          19162
# Actara 25 WG         18887
# Name: count, dtype: int64

# %% [markdown]
# # SKU Name Distribution Analysis
#
# ## Overview
#
# The `sku_name` feature represents agricultural products sold through retailer POS transactions.
#
# Analyzing SKU frequency helps understand:
# - product demand,
# - sales distribution,
# - product popularity,
# - and operational focus.
#
# ---
#
# # SKU Frequency Distribution
#
# | SKU Name | Count |
# |---|---|
# | Vibrance Integral | 20,123 |
# | Alto 5 SC | 20,116 |
# | Axial 50 EC | 19,843 |
# | Score 250 EC | 19,838 |
# | Topik 15 WP | 19,829 |
# | Amistar 250 SC | 19,709 |
# | Movondo | 19,489 |
# | Cruiser 350 FS | 19,463 |
# | Vertimec 1.8 EC | 19,401 |
# | Kavach 75 WP | 19,182 |
# | Tilt 250 EC | 19,162 |
# | Actara 25 WG | 18,887 |
#
# ---
#
# # Interpretation
#
# ## Balanced Product Sales Distribution
#
# - Product frequencies are relatively evenly distributed across all SKUs.
# - No single product overwhelmingly dominates transaction activity.
#
# ### Business Insight
#
# This suggests:
# - diversified product demand,
# - balanced sales activity,
# - and broad product adoption across retailers.
#
# ---
#
# # Highest Frequency Products
#
# ## Vibrance Integral and Alto 5 SC
#
# - These products show the highest transaction frequencies.
# - Indicates strong retailer demand and high sales activity.
#
# ### Operational Importance
#
# Possible reasons include:
# - strong market adoption,
# - frequent usage,
# - or strategic product importance.
#
# ---
#
# # Lower Frequency Products
#
# ## Actara 25 WG and Tilt 250 EC
#
# - These products show comparatively lower transaction counts.
# - However, differences remain relatively small.
#
# ### Interpretation
#
# This indicates:
# - consistent sales distribution,
# - and absence of major product imbalance.
#
# ---
#
# # Product Portfolio Insights
#
# The dataset includes multiple agricultural product categories such as:
# - fungicides,
# - insecticides,
# - herbicides,
# - and seed treatment solutions.
#
# ### Business Importance
#
# A diversified product portfolio supports:
# - broader market reach,
# - multi-crop agricultural operations,
# - and varied retailer demand patterns.
#
# ---
#
# # Sales Behavior Observation
#
# The close frequency distribution across products suggests:
# - stable retailer purchasing behavior,
# - balanced operational stocking,
# - and widespread product participation.
#
# ---
#
# # AI/ML Relevance
#
# The `sku_name` feature is highly useful for:
# - demand forecasting,
# - recommendation systems,
# - sales prediction,
# - and retailer-product analytics.
#
# Balanced SKU representation improves:
# - model stability,
# - fairness,
# - and prediction reliability.
#
# ---
#
# # Business Importance
#
# SKU-level sales analysis can help:
# - identify high-performing products,
# - optimize inventory allocation,
# - improve supply-chain planning,
# - and support sales strategy decisions.
#
# ---
#
# # Final Interpretation
#
# The SKU sales distribution demonstrates strong product diversity and balanced transactional representation across agricultural products. The `sku_name` feature provides valuable intelligence for:
# - retail analytics,
# - demand forecasting,
# - and AI-driven sales optimization systems.

# %%
df['transaction_date'].min()
# Out:
# '2025-10-06'

# %%
df['transaction_date'].max()
# Out:
# '2026-03-29'

# %% [markdown]
# # Transaction Date Range Analysis
#
# ## Overview
#
# The `transaction_date` feature represents the timeline of POS sales transactions across retailers and products.
#
# Analyzing the transaction date range helps understand:
# - operational coverage duration,
# - sales activity periods,
# - seasonal behavior,
# - and temporal scope.
#
# ---
#
# # Date Range Summary
#
# | Metric | Value |
# |---|---|
# | Earliest Transaction Date | 2025-10-06 |
# | Latest Transaction Date | 2026-03-29 |
#
# ---
#
# # Interpretation
#
# ## Sales Activity Timeline
#
# - The dataset spans nearly 6 months of transaction activity.
# - Transactions are recorded from October 2025 to March 2026.
#
# ### Business Insight
#
# This provides sufficient temporal coverage for:
# - sales trend analysis,
# - demand forecasting,
# - and seasonal performance evaluation.
#
# ---
#
# # Seasonal Coverage
#
# The transaction period includes:
# - post-monsoon agricultural operations,
# - winter crop cycles,
# - and early 2026 sales activity.
#
# ### Strategic Importance
#
# This timeline may capture:
# - seasonal agrochemical demand,
# - crop protection purchasing behavior,
# - and inventory replenishment cycles.
#
# ---
#
# # Daily Transaction Granularity
#
# Transactions are recorded at the daily level.
#
# ### Analytical Benefits
#
# Daily granularity supports:
# - detailed trend analysis,
# - sales pattern detection,
# - retailer activity monitoring,
# - and short-term forecasting.
#
# ---
#
# # AI/ML Relevance
#
# The `transaction_date` feature is highly valuable for:
# - time-series forecasting,
# - seasonality analysis,
# - sales prediction,
# - and demand modeling.
#
# Potential engineered features include:
# - month,
# - quarter,
# - weekday,
# - season,
# - and sales cycle indicators.
#
# ---
#
# # Data Quality Observation
#
# The date range appears:
# - continuous,
# - operationally realistic,
# - and chronologically structured.
#
# No abnormal or inconsistent dates are observed.
#
# ---
#
# # Final Interpretation
#
# The dataset captures daily POS transaction activity across a well-defined 6-month operational period, providing strong temporal coverage for:
# - retail analytics,
# - sales forecasting,
# - and AI-driven demand prediction systems.

# %%
df['sku_name'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='sku_name'>

# %% [markdown]
# # SKU Sales Distribution Visualization Analysis
#
# ## Overview
#
# The bar chart visualizes the sales frequency distribution of agricultural products (`sku_name`) in the POS transaction dataset.
#
# The visualization helps identify:
# - product popularity,
# - sales balance,
# - operational demand patterns,
# - and product-level transaction activity.
#
# ---
#
# # Key Observations
#
# | SKU Name | Approximate Count |
# |---|---|
# | Vibrance Integral | ~20,123 |
# | Alto 5 SC | ~20,116 |
# | Axial 50 EC | ~19,843 |
# | Score 250 EC | ~19,838 |
# | Topik 15 WP | ~19,829 |
# | Amistar 250 SC | ~19,709 |
# | Movondo | ~19,489 |
# | Cruiser 350 FS | ~19,463 |
# | Vertimec 1.8 EC | ~19,401 |
# | Kavach 75 WP | ~19,182 |
# | Tilt 250 EC | ~19,162 |
# | Actara 25 WG | ~18,887 |
#
# ---
#
# # Interpretation
#
# ## Balanced Product Sales Distribution
#
# - The chart shows relatively uniform sales distribution across all products.
# - No SKU overwhelmingly dominates transaction frequency.
#
# ### Business Insight
#
# This suggests:
# - balanced retailer demand,
# - diversified product adoption,
# - and stable sales participation across SKUs.
#
# ---
#
# # Highest Transaction Products
#
# ## Vibrance Integral and Alto 5 SC
#
# - These products show the highest transaction frequencies.
# - Indicates strong sales performance and broad retailer usage.
#
# ### Operational Importance
#
# Possible reasons include:
# - strong market demand,
# - product effectiveness,
# - or strategic product positioning.
#
# ---
#
# # Lower Transaction Products
#
# ## Actara 25 WG
#
# - Shows the lowest transaction frequency in the chart.
# - However, the difference remains relatively small compared to other products.
#
# ### Interpretation
#
# This indicates:
# - healthy product distribution,
# - and absence of severe product imbalance.
#
# ---
#
# # Visualization Insights
#
# The bar heights are closely aligned, demonstrating:
# - operational consistency,
# - balanced inventory movement,
# - and stable product engagement.
#
# The dataset does not appear heavily skewed toward any single SKU.
#
# ---
#
# # Product Portfolio Observation
#
# The products appear related to:
# - fungicides,
# - herbicides,
# - insecticides,
# - and crop protection solutions.
#
# ### Strategic Importance
#
# A diversified agricultural portfolio supports:
# - multi-crop operations,
# - wider market reach,
# - and stronger retailer engagement.
#
# ---
#
# # AI/ML Relevance
#
# Balanced SKU sales distributions are highly beneficial for:
# - demand forecasting,
# - recommendation systems,
# - sales prediction,
# - and retailer analytics.
#
# The balanced structure reduces:
# - model bias,
# - prediction instability,
# - and class imbalance issues.
#
# ---
#
# # Final Interpretation
#
# The visualization demonstrates strong balance and diversity in product transaction activity across agricultural SKUs. The `sku_name` feature provides valuable insights for:
# - retail intelligence,
# - sales forecasting,
# - and AI-driven product optimization systems.

# %% [markdown]
# # retailer_visit_log.csv Analysis

# %%
df = pd.read_csv("../datasets/retailer_visit_log.csv")

# %%
df.head()
# Out:
#      rep_id  visit_date territory_id  visit_tehsil          visit_type  \
# 0  REP_0203  2026-03-09     TER_0203  Jalgaon_T062    retailer meeting
# 1  REP_0203  2026-03-12     TER_0203  Jalgaon_T064    retailer meeting
# 2  REP_0203  2026-03-12     TER_0203  Jalgaon_T063  campaign_conducted
# 3  REP_0203  2026-03-12     TER_0203  Jalgaon_T064    retailer meeting
# 4  REP_0203  2026-03-12     TER_0203  Jalgaon_T063  campaign_conducted
#
#   product_recommended
# 0     Vertimec 1.8 EC
# 1         Tilt 250 EC
# 2      Cruiser 350 FS
# 3      Cruiser 350 FS
# 4         Tilt 250 EC

# %% [markdown]
# # Representative Visit Dataset Analysis
#
# ## Overview
#
# The dataset contains representative field-visit records related to:
# - sales representatives,
# - territories,
# - tehsil-level operations,
# - visit activities,
# - and product recommendations.
#
# The dataset is highly useful for:
# - field-force analytics,
# - territory monitoring,
# - operational intelligence,
# - and recommendation analysis.
#
# ---
#
# # Dataset Features
#
# | Feature | Description |
# |---|---|
# | rep_id | Unique sales representative identifier |
# | visit_date | Date of representative visit |
# | territory_id | Territory assigned to the representative |
# | visit_tehsil | Tehsil where the visit occurred |
# | visit_type | Type of field activity conducted |
# | product_recommended | Product recommended during the visit |
#
# ---
#
# # Initial Observations
#
# ## Representative-Level Activity Tracking
#
# ### `rep_id`
#
# - Represents individual field representatives.
# - Enables rep-wise operational analysis.
#
# ### Business Importance
#
# Useful for:
# - workforce monitoring,
# - performance evaluation,
# - and territory activity analysis.
#
# ---
#
# # Territory and Geographic Information
#
# ## `territory_id`
#
# - Represents assigned operational territories.
# - Supports territory-level performance analysis.
#
# ---
#
# ## `visit_tehsil`
#
# - Captures tehsil-level visit locations.
# - Provides granular geographic operational intelligence.
#
# ### Business Insight
#
# Useful for:
# - regional activity mapping,
# - market penetration analysis,
# - and field coverage monitoring.
#
# ---
#
# # Visit Activity Information
#
# ## `visit_type`
#
# - Represents the type of field interaction conducted.
#
# ### Example Activities
#
# - retailer meeting
# - campaign_conducted
#
# ### Operational Importance
#
# Supports:
# - activity tracking,
# - engagement analysis,
# - and campaign monitoring.
#
# ---
#
# # Product Recommendation Analysis
#
# ## `product_recommended`
#
# - Represents products promoted during field visits.
#
# ### Business Importance
#
# Useful for:
# - recommendation analysis,
# - product promotion tracking,
# - and sales influence evaluation.
#
# ---
#
# # Temporal Feature
#
# ## `visit_date`
#
# - Represents the date of field activity.
# - Enables time-based operational analysis.
#
# ### Analytical Importance
#
# Supports:
# - activity trend analysis,
# - rep engagement tracking,
# - and campaign timeline evaluation.
#
# ---
#
# # Dataset Structure Observation
#
# The dataset follows a structured field-operations hierarchy:
#
# `Representative → Territory → Tehsil → Visit Activity → Product Recommendation`
#
# This structure supports:
# - operational intelligence,
# - workforce analytics,
# - and campaign performance monitoring.
#
# ---
#
# # AI/ML Relevance
#
# The dataset can support:
# - representative performance prediction,
# - territory optimization,
# - recommendation systems,
# - and activity forecasting.
#
# Potential engineered features include:
# - visit frequency,
# - recommendation trends,
# - territory coverage scores,
# - and rep productivity metrics.
#
# ---
#
# # Final Interpretation
#
# The dataset provides detailed field-operations intelligence across representatives, territories, and product recommendations. The combination of geographic, temporal, and operational features creates strong potential for:
# - workforce analytics,
# - territory intelligence,
# - and AI-driven operational optimization systems.

# %%
df.shape
# Out:
# (30000, 6)

# %% [markdown]
# # Dataset Shape Analysis
#
# ## Overview
#
# The shape of a dataset represents:
# - the total number of records,
# - and the number of available features.
#
# This helps evaluate:
# - dataset scale,
# - operational coverage,
# - and analytical capability.
#
# ---
#
# # Dataset Shape
#
# | Metric | Value |
# |---|---|
# | Number of Rows | 30,000 |
# | Number of Columns | 6 |
#
# ---
#
# # Interpretation
#
# ## Total Records = 30,000
#
# - The dataset contains 30,000 representative field-visit records.
# - Each row represents a specific operational activity conducted by a representative.
#
# ### Business Insight
#
# This indicates:
# - large-scale field activity tracking,
# - extensive operational coverage,
# - and strong activity-level granularity.
#
# ---
#
# ## Total Features = 6
#
# The dataset includes:
# - representative information,
# - territory details,
# - visit locations,
# - activity types,
# - product recommendations,
# - and visit dates.
#
# ### Analytical Importance
#
# These features support:
# - field-force analytics,
# - operational intelligence,
# - territory monitoring,
# - and campaign analysis.
#
# ---
#
# # Operational Scale Observation
#
# The dataset size is suitable for:
# - activity analysis,
# - performance monitoring,
# - and machine learning applications.
#
# The number of records improves:
# - trend reliability,
# - operational visibility,
# - and behavioral analysis quality.
#
# ---
#
# # Geographic and Operational Coverage
#
# The dataset captures:
# - representative activities,
# - territory-level operations,
# - and tehsil-level engagement.
#
# This enables:
# - granular field-force monitoring,
# - territory optimization,
# - and regional intelligence generation.
#
# ---
#
# # AI/ML Relevance
#
# The dataset size is beneficial for:
# - recommendation analysis,
# - representative performance prediction,
# - territory optimization,
# - and activity forecasting models.
#
# The record volume supports:
# - pattern learning,
# - model generalization,
# - and operational trend analysis.
#
# ---
#
# # Final Interpretation
#
# The dataset contains 30,000 field-operation records and 6 meaningful features, providing a strong foundation for:
# - workforce analytics,
# - territory intelligence,
# - and AI-driven operational optimization systems.

# %%
df.columns
# Out:
# Index(['rep_id', 'visit_date', 'territory_id', 'visit_tehsil', 'visit_type',
#        'product_recommended'],
#       dtype='str')

# %% [markdown]
# # Feature Analysis
#
# ## Overview
#
# The dataset contains 6 features related to:
# - sales representatives,
# - territory operations,
# - field visits,
# - activity types,
# - and product recommendations.
#
# These features provide strong analytical value for:
# - workforce analytics,
# - territory intelligence,
# - and operational monitoring.
#
# ---
#
# # Dataset Features
#
# | Feature | Description |
# |---|---|
# | rep_id | Unique sales representative identifier |
# | visit_date | Date of representative visit |
# | territory_id | Assigned territory identifier |
# | visit_tehsil | Tehsil where the visit occurred |
# | visit_type | Type of field activity conducted |
# | product_recommended | Product recommended during the visit |
#
# ---
#
# # Feature-Level Interpretation
#
# ## `rep_id`
#
# - Represents individual field representatives.
# - Useful for representative-level activity tracking.
#
# ### Business Importance
#
# Supports:
# - workforce monitoring,
# - productivity analysis,
# - and performance evaluation.
#
# ---
#
# ## `visit_date`
#
# - Represents the date of field activity.
# - Enables time-based operational analysis.
#
# ### Analytical Importance
#
# Useful for:
# - trend analysis,
# - campaign monitoring,
# - and activity forecasting.
#
# ---
#
# ## `territory_id`
#
# - Represents assigned operational territories.
# - Supports territory-level performance evaluation.
#
# ### Business Relevance
#
# Useful for:
# - territory optimization,
# - operational planning,
# - and regional analytics.
#
# ---
#
# ## `visit_tehsil`
#
# - Captures tehsil-level visit locations.
# - Provides detailed geographic operational intelligence.
#
# ### Operational Importance
#
# Supports:
# - regional coverage analysis,
# - field penetration monitoring,
# - and geographic segmentation.
#
# ---
#
# ## `visit_type`
#
# - Represents the type of field activity conducted.
#
# ### Example Activities
#
# - retailer meeting
# - campaign_conducted
#
# ### Business Insight
#
# Useful for:
# - engagement analysis,
# - campaign tracking,
# - and operational activity monitoring.
#
# ---
#
# ## `product_recommended`
#
# - Represents products promoted during visits.
# - Provides recommendation-level operational insights.
#
# ### Analytical Importance
#
# Supports:
# - product promotion analysis,
# - recommendation trend evaluation,
# - and demand influence studies.
#
# ---
#
# # Dataset Structure Observation
#
# The dataset follows a structured operational hierarchy:
#
# `Representative → Territory → Visit Location → Activity → Product Recommendation`
#
# This structure supports:
# - workforce intelligence,
# - operational analytics,
# - and territory management.
#
# ---
#
# # AI/ML Relevance
#
# The features are highly suitable for:
# - representative performance prediction,
# - recommendation systems,
# - territory optimization,
# - and activity forecasting.
#
# Potential engineered features include:
# - visit frequency,
# - rep productivity scores,
# - territory engagement metrics,
# - and recommendation success indicators.
#
# ---
#
# # Final Interpretation
#
# The dataset features are well-structured and operationally valuable. Together, they provide a strong foundation for:
# - field-force analytics,
# - territory intelligence,
# - and AI-driven operational optimization systems.

# %%
df.isnull().sum()
# Out:
# rep_id                 0
# visit_date             0
# territory_id           0
# visit_tehsil           0
# visit_type             0
# product_recommended    0
# dtype: int64

# %% [markdown]
# # Missing Value Analysis
#
# ## Overview
#
# Missing value analysis helps evaluate:
# - dataset completeness,
# - data reliability,
# - and preprocessing requirements.
#
# Datasets without missing values are highly beneficial for:
# - operational analytics,
# - forecasting,
# - and machine learning applications.
#
# ---
#
# # Missing Value Summary
#
# | Feature | Missing Values |
# |---|---|
# | rep_id | 0 |
# | visit_date | 0 |
# | territory_id | 0 |
# | visit_tehsil | 0 |
# | visit_type | 0 |
# | product_recommended | 0 |
#
# ---
#
# # Interpretation
#
# ## No Missing Values Detected
#
# All features in the dataset are fully populated with:
# - zero null values,
# - strong operational consistency,
# - and reliable field-activity information.
#
# This indicates excellent data quality.
#
# ---
#
# # Feature-Level Observations
#
# ## `rep_id`
#
# - Every visit record is linked to a representative.
# - Supports accurate workforce-level analysis.
#
# ---
#
# ## `visit_date`
#
# - All operational activities contain valid visit dates.
# - Enables reliable temporal and trend analysis.
#
# ---
#
# ## `territory_id`
#
# - Territory assignments are completely available.
# - Supports uninterrupted territory-level analytics.
#
# ---
#
# ## `visit_tehsil`
#
# - Geographic visit locations are fully recorded.
# - Improves regional operational intelligence.
#
# ---
#
# ## `visit_type`
#
# - Activity categories are consistently captured.
# - Supports engagement and campaign analysis.
#
# ---
#
# ## `product_recommended`
#
# - Product recommendation information is fully available.
# - Enables recommendation trend evaluation and product promotion analysis.
#
# ---
#
# # Business Importance
#
# Complete operational data improves:
# - field-force visibility,
# - activity monitoring accuracy,
# - and territory intelligence.
#
# The absence of missing values also reduces:
# - preprocessing complexity,
# - data-cleaning effort,
# - and analytical uncertainty.
#
# ---
#
# # AI/ML Relevance
#
# Since no missing values exist:
# - preprocessing becomes simpler,
# - model reliability improves,
# - and prediction quality strengthens.
#
# This benefits:
# - representative performance modeling,
# - recommendation systems,
# - territory optimization,
# - and operational forecasting.
#
# ---
#
# # Final Interpretation
#
# The dataset demonstrates excellent completeness with no missing values across all operational features. This creates a strong foundation for:
# - workforce analytics,
# - territory intelligence,
# - and AI-driven operational optimization systems.

# %%
df.dtypes
# Out:
# rep_id                 str
# visit_date             str
# territory_id           str
# visit_tehsil           str
# visit_type             str
# product_recommended    str
# dtype: object

# %% [markdown]
# # Data Type Analysis
#
# ## Overview
#
# Data type analysis helps verify whether dataset features are stored in appropriate formats for:
# - analysis,
# - preprocessing,
# - visualization,
# - and machine learning.
#
# Correct data types improve:
# - analytical accuracy,
# - computational efficiency,
# - and data consistency.
#
# ---
#
# # Feature Data Types
#
# | Feature | Data Type |
# |---|---|
# | rep_id | object (string) |
# | visit_date | object (string) |
# | territory_id | object (string) |
# | visit_tehsil | object (string) |
# | visit_type | object (string) |
# | product_recommended | object (string) |
#
# ---
#
# # Interpretation
#
# ## Categorical Features
#
# ### `rep_id`
#
# - Stored correctly as string data.
# - Represents unique sales representatives.
#
# ### Business Importance
#
# Useful for:
# - workforce tracking,
# - productivity analysis,
# - and representative performance monitoring.
#
# ---
#
# ### `territory_id`
#
# - Represents assigned operational territories.
# - Properly stored as categorical text data.
#
# ### Analytical Importance
#
# Supports:
# - territory segmentation,
# - regional analysis,
# - and operational planning.
#
# ---
#
# ### `visit_tehsil`
#
# - Contains tehsil-level geographic information.
# - Useful for granular operational analysis.
#
# ### Business Insight
#
# Supports:
# - regional coverage monitoring,
# - market penetration analysis,
# - and field activity tracking.
#
# ---
#
# ### `visit_type`
#
# - Represents types of operational activities conducted.
# - Stored correctly as categorical data.
#
# ### Operational Importance
#
# Useful for:
# - engagement analysis,
# - campaign tracking,
# - and workforce activity evaluation.
#
# ---
#
# ### `product_recommended`
#
# - Represents products promoted during visits.
# - Useful for recommendation and demand analysis.
#
# ### Business Relevance
#
# Supports:
# - product promotion monitoring,
# - recommendation analytics,
# - and sales influence analysis.
#
# ---
#
# # Temporal Feature Observation
#
# ## `visit_date`
#
# - Currently stored as string (`object`) type.
# - Represents dates of representative field visits.
#
# ### Recommended Improvement
#
# Convert this feature into datetime format for:
# - trend analysis,
# - operational forecasting,
# - seasonality detection,
# - and time-series analysis.
#
# ### Suggested Conversion
#
# ```python
# df['visit_date'] = pd.to_datetime(df['visit_date'])
# ```
#
# ---
#
# # Overall Dataset Structure
#
# The dataset primarily contains:
# - categorical operational features,
# - geographic information,
# - activity classifications,
# - and recommendation data.
#
# This structure is highly suitable for:
# - workforce analytics,
# - territory intelligence,
# - and AI-driven operational systems.
#
# ---
#
# # AI/ML Relevance
#
# The dataset features can support:
# - representative performance prediction,
# - territory optimization,
# - recommendation systems,
# - and activity forecasting.
#
# Categorical encoding techniques such as:
# - label encoding,
# - frequency encoding,
# - or embeddings
#
# may be required for machine learning models.
#
# ---
#
# # Final Interpretation
#
# The dataset data types are appropriately structured for operational analytics. The primary enhancement opportunity is converting `visit_date` into datetime format to enable advanced temporal and forecasting analysis.

# %%
df.describe()
# Out:
#           rep_id  visit_date territory_id   visit_tehsil        visit_type  \
# count      30000       30000        30000          30000             30000
# unique       500         182          500           4935                 3
# top     REP_0164  2025-10-02     TER_0164  Amritsar_T068  retailer meeting
# freq         130         211          130             22             12233
#
#        product_recommended
# count                30000
# unique                  12
# top         Amistar 250 SC
# freq                  3790

# %% [markdown]
# # Categorical Feature Statistical Analysis
#
# ## Overview
#
# The statistical summary provides insights into:
# - representative activity distribution,
# - geographic diversity,
# - operational coverage,
# - and recommendation behavior.
#
# These observations are highly useful for:
# - workforce analytics,
# - territory intelligence,
# - and operational optimization.
#
# ---
#
# # Statistical Summary
#
# | Feature | Count | Unique | Top Value | Frequency |
# |---|---|---|---|---|
# | rep_id | 30,000 | 500 | REP_0164 | 130 |
# | visit_date | 30,000 | 182 | 2025-10-02 | 211 |
# | territory_id | 30,000 | 500 | TER_0164 | 130 |
# | visit_tehsil | 30,000 | 4,935 | Amritsar_T068 | 22 |
# | visit_type | 30,000 | 3 | retailer meeting | 12,233 |
# | product_recommended | 30,000 | 12 | Amistar 250 SC | 3,790 |
#
# ---
#
# # Interpretation
#
# # 1. Representative Activity Analysis
#
# ## Unique Representatives = 500
#
# - The dataset contains activity records for 500 representatives.
# - Operational activity appears distributed across the workforce.
#
# ### Highest Activity Representative
#
# - `REP_0164` appears most frequently with 130 records.
#
# ### Business Insight
#
# This may indicate:
# - higher field engagement,
# - larger territory responsibility,
# - or increased operational activity.
#
# ---
#
# # 2. Visit Date Analysis
#
# ## Unique Dates = 182
#
# - The dataset spans 182 operational days.
# - Indicates consistent field activity over approximately 6 months.
#
# ### Most Active Date
#
# - `2025-10-02` contains the highest number of visits.
#
# ### Interpretation
#
# This may reflect:
# - campaign periods,
# - operational peaks,
# - or scheduled activity drives.
#
# ---
#
# # 3. Territory Analysis
#
# ## Unique Territories = 500
#
# - Every territory appears uniquely represented.
# - Territory activity is distributed across the operational network.
#
# ### Operational Importance
#
# Supports:
# - balanced territory allocation,
# - geographic coverage,
# - and regional workforce management.
#
# ---
#
# # 4. Tehsil-Level Coverage Analysis
#
# ## Unique Visit Tehsils = 4,935
#
# - The dataset contains highly granular geographic coverage.
# - Indicates broad field penetration across operational regions.
#
# ### Business Importance
#
# This improves:
# - regional intelligence,
# - market coverage analysis,
# - and territory optimization.
#
# ---
#
# # 5. Visit Type Analysis
#
# ## Unique Visit Types = 3
#
# The dataset includes three operational activity categories.
#
# ### Most Frequent Activity
#
# - `retailer meeting` is the dominant activity type with 12,233 records.
#
# ### Interpretation
#
# This suggests:
# - strong retailer engagement focus,
# - relationship-driven field operations,
# - and active sales interaction.
#
# ---
#
# # 6. Product Recommendation Analysis
#
# ## Unique Recommended Products = 12
#
# - Representatives promote a diverse range of agricultural products.
#
# ### Most Recommended Product
#
# - `Amistar 250 SC` appears most frequently with 3,790 recommendations.
#
# ### Business Insight
#
# This may indicate:
# - strong product demand,
# - strategic promotion focus,
# - or high campaign priority.
#
# ---
#
# # Geographic and Operational Diversity
#
# The dataset demonstrates:
# - broad territory coverage,
# - granular tehsil-level operations,
# - and diverse product recommendation activity.
#
# This creates strong operational intelligence potential.
#
# ---
#
# # AI/ML Relevance
#
# The categorical structure is highly suitable for:
# - representative performance modeling,
# - recommendation systems,
# - territory optimization,
# - and operational forecasting.
#
# High-cardinality features such as:
# - `visit_tehsil`,
# - `rep_id`,
# - and `territory_id`
#
# may require advanced encoding techniques.
#
# ---
#
# # Final Interpretation
#
# The dataset demonstrates strong operational diversity across representatives, territories, activities, and product recommendations. The structured categorical features provide an excellent foundation for:
# - workforce analytics,
# - territory intelligence,
# - and AI-driven operational optimization systems.

# %%
df['product_recommended'].value_counts()
# Out:
# product_recommended
# Amistar 250 SC       3790
# Kavach 75 WP         3339
# Cruiser 350 FS       3148
# Actara 25 WG         3008
# Alto 5 SC            2804
# Axial 50 EC          2650
# Tilt 250 EC          2628
# Score 250 EC         2031
# Vibrance Integral    1925
# Vertimec 1.8 EC      1587
# Movondo              1572
# Topik 15 WP          1518
# Name: count, dtype: int64

# %% [markdown]
# # Product Recommendation Distribution Analysis
#
# ## Overview
#
# The `product_recommended` feature represents agricultural products promoted by representatives during field visits.
#
# Analyzing recommendation frequency helps understand:
# - product promotion focus,
# - field-force priorities,
# - recommendation trends,
# - and operational strategy.
#
# ---
#
# # Product Recommendation Frequency
#
# | Product Recommended | Count |
# |---|---|
# | Amistar 250 SC | 3,790 |
# | Kavach 75 WP | 3,339 |
# | Cruiser 350 FS | 3,148 |
# | Actara 25 WG | 3,008 |
# | Alto 5 SC | 2,804 |
# | Axial 50 EC | 2,650 |
# | Tilt 250 EC | 2,628 |
# | Score 250 EC | 2,031 |
# | Vibrance Integral | 1,925 |
# | Vertimec 1.8 EC | 1,587 |
# | Movondo | 1,572 |
# | Topik 15 WP | 1,518 |
#
# ---
#
# # Interpretation
#
# ## Most Recommended Product
#
# ### Amistar 250 SC
#
# - Appears as the most frequently recommended product.
# - Indicates strong promotional focus by representatives.
#
# ### Business Insight
#
# Possible reasons include:
# - high market demand,
# - strategic campaign emphasis,
# - or strong product performance.
#
# ---
#
# # Strongly Promoted Products
#
# ## Kavach 75 WP and Cruiser 350 FS
#
# - These products also show high recommendation frequencies.
# - Suggest active field-force promotion and operational importance.
#
# ### Operational Importance
#
# These products may represent:
# - priority sales targets,
# - seasonal crop solutions,
# - or high-value agricultural products.
#
# ---
#
# # Moderate Recommendation Products
#
# ## Alto 5 SC, Axial 50 EC, and Tilt 250 EC
#
# - These products maintain balanced recommendation activity.
# - Suggest stable but moderate promotional focus.
#
# ---
#
# # Lower Recommended Products
#
# ## Movondo and Topik 15 WP
#
# - Show the lowest recommendation frequencies in the dataset.
#
# ### Interpretation
#
# Possible explanations include:
# - niche product usage,
# - lower campaign focus,
# - or crop-specific demand.
#
# ---
#
# # Recommendation Distribution Observation
#
# The recommendation distribution is moderately uneven:
# - a few products dominate recommendations,
# - while others receive comparatively lower promotion.
#
# ### Business Implication
#
# This may reflect:
# - strategic marketing priorities,
# - crop seasonality,
# - or product demand differences.
#
# ---
#
# # AI/ML Relevance
#
# The `product_recommended` feature is highly useful for:
# - recommendation systems,
# - product affinity analysis,
# - sales influence modeling,
# - and campaign optimization.
#
# Recommendation frequency patterns can support:
# - product prioritization,
# - field-force optimization,
# - and targeted marketing strategies.
#
# ---
#
# # Business Importance
#
# Product recommendation analysis can help:
# - measure campaign effectiveness,
# - optimize field-force strategies,
# - improve product targeting,
# - and identify under-promoted products.
#
# ---
#
# # Final Interpretation
#
# The product recommendation distribution demonstrates clear promotional priorities across agricultural products, with stronger emphasis on select high-focus SKUs. The feature provides valuable operational intelligence for:
# - field-force analytics,
# - product strategy optimization,
# - and AI-driven recommendation systems.

# %%
df['visit_date'].min()
# Out:
# '2025-09-29'

# %%
df['visit_date'].max()
# Out:
# '2026-03-29'

# %% [markdown]
# # Visit Date Range Analysis
#
# ## Overview
#
# The `visit_date` feature represents the timeline of representative field activities conducted across territories and tehsils.
#
# Analyzing the visit date range helps understand:
# - operational coverage duration,
# - field-force activity timelines,
# - campaign periods,
# - and temporal consistency.
#
# ---
#
# # Date Range Summary
#
# | Metric | Value |
# |---|---|
# | Earliest Visit Date | 2025-09-29 |
# | Latest Visit Date | 2026-03-29 |
#
# ---
#
# # Interpretation
#
# ## Operational Timeline Coverage
#
# - The dataset spans approximately 6 months of field activity.
# - Representative visits are recorded from September 2025 to March 2026.
#
# ### Business Insight
#
# This provides sufficient temporal coverage for:
# - operational monitoring,
# - activity trend analysis,
# - and campaign performance evaluation.
#
# ---
#
# # Seasonal Coverage
#
# The timeline includes:
# - post-monsoon agricultural operations,
# - winter crop cycles,
# - and early 2026 field activities.
#
# ### Strategic Importance
#
# This period may capture:
# - seasonal product promotion,
# - campaign execution cycles,
# - and territory engagement patterns.
#
# ---
#
# # Daily Operational Granularity
#
# Visit records are maintained at the daily level.
#
# ### Analytical Benefits
#
# Daily granularity supports:
# - workforce activity tracking,
# - operational trend analysis,
# - territory monitoring,
# - and short-term forecasting.
#
# ---
#
# # Operational Consistency Observation
#
# The date range appears:
# - continuous,
# - operationally realistic,
# - and chronologically structured.
#
# This suggests stable field-force engagement throughout the observation period.
#
# ---
#
# # AI/ML Relevance
#
# The `visit_date` feature is highly useful for:
# - operational forecasting,
# - seasonality analysis,
# - activity prediction,
# - and campaign optimization.
#
# Potential engineered features include:
# - month,
# - week,
# - quarter,
# - season,
# - and activity-cycle indicators.
#
# ---
#
# # Business Importance
#
# Temporal activity analysis can help:
# - optimize representative scheduling,
# - evaluate campaign timing,
# - improve territory planning,
# - and monitor operational intensity.
#
# ---
#
# # Final Interpretation
#
# The dataset captures representative field activities across a well-structured 6-month operational period, providing strong temporal coverage for:
# - workforce analytics,
# - campaign intelligence,
# - and AI-driven operational optimization systems.

# %%
df['product_recommended'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='product_recommended'>

# %% [markdown]
# # Product Recommendation Visualization Analysis
#
# ## Overview
#
# The bar chart visualizes the distribution of product recommendations made by representatives during field visits.
#
# The visualization helps identify:
# - highly promoted products,
# - recommendation priorities,
# - field-force focus areas,
# - and product-level promotional trends.
#
# ---
#
# # Key Observations
#
# | Product Recommended | Approximate Count |
# |---|---|
# | Amistar 250 SC | ~3,790 |
# | Kavach 75 WP | ~3,339 |
# | Cruiser 350 FS | ~3,148 |
# | Actara 25 WG | ~3,008 |
# | Alto 5 SC | ~2,804 |
# | Axial 50 EC | ~2,650 |
# | Tilt 250 EC | ~2,628 |
# | Score 250 EC | ~2,031 |
# | Vibrance Integral | ~1,925 |
# | Vertimec 1.8 EC | ~1,587 |
# | Movondo | ~1,572 |
# | Topik 15 WP | ~1,518 |
#
# ---
#
# # Interpretation
#
# ## Dominant Recommended Product
#
# ### Amistar 250 SC
#
# - The chart clearly shows `Amistar 250 SC` as the most recommended product.
# - Indicates strong field-force emphasis and high operational priority.
#
# ### Business Insight
#
# Possible reasons include:
# - strong market demand,
# - strategic campaign focus,
# - or high product effectiveness.
#
# ---
#
# # Strongly Promoted Products
#
# ## Kavach 75 WP and Cruiser 350 FS
#
# - These products also show high recommendation frequencies.
# - Suggest active promotional efforts across territories.
#
# ### Operational Importance
#
# These products may represent:
# - seasonal crop solutions,
# - high-revenue products,
# - or campaign-driven recommendations.
#
# ---
#
# # Moderate Recommendation Products
#
# ## Alto 5 SC, Axial 50 EC, and Tilt 250 EC
#
# - Maintain balanced recommendation activity.
# - Reflect stable field-level promotion.
#
# ---
#
# # Lowest Recommended Products
#
# ## Topik 15 WP and Movondo
#
# - These products appear least recommended in the visualization.
#
# ### Interpretation
#
# Possible explanations include:
# - niche usage patterns,
# - crop-specific applications,
# - or lower campaign priority.
#
# ---
#
# # Visualization Insights
#
# The bar heights show noticeable variation across products, indicating:
# - unequal promotional focus,
# - product prioritization strategies,
# - and differentiated field-force attention.
#
# The distribution is moderately skewed toward a few high-priority products.
#
# ---
#
# # Business Importance
#
# Recommendation analysis can help organizations:
# - optimize field-force strategies,
# - identify high-priority products,
# - improve campaign planning,
# - and strengthen product positioning.
#
# ---
#
# # AI/ML Relevance
#
# The recommendation distribution is valuable for:
# - recommendation systems,
# - product affinity analysis,
# - demand forecasting,
# - and campaign optimization models.
#
# The feature can help build:
# - intelligent recommendation engines,
# - product targeting systems,
# - and territory-level promotion strategies.
#
# ---
#
# # Final Interpretation
#
# The visualization demonstrates clear promotional priorities among agricultural products, with stronger representative focus on select high-demand SKUs. The recommendation distribution provides valuable insights for:
# - field-force analytics,
# - campaign intelligence,
# - and AI-driven product recommendation systems.

# %% [markdown]
# # whatsapp_campaign.csv Analysis

# %%
df = pd.read_csv("../datasets/whatsapp_campaign.csv")

# %%
df.head()
# Out:
#                  id campaign_product campaign_crop  grower_id  \
# 0  WAM_RABI25_00001      Tilt 250 EC         wheat  GRW_00001
# 1  WAM_RABI25_00002      Tilt 250 EC         wheat  GRW_00002
# 2  WAM_RABI25_00003      Tilt 250 EC         wheat  GRW_00003
# 3  WAM_RABI25_00004      Tilt 250 EC         wheat  GRW_00004
# 4  WAM_RABI25_00005      Tilt 250 EC         wheat  GRW_00005
#
#   message_sent_date  delivered_status  opened_status  clicked_status
# 0        2026-03-20              True          False           False
# 1        2026-03-31              True          False           False
# 2        2026-03-03              True          False           False
# 3        2025-10-28              True          False           False
# 4        2025-12-08              True          False           False

# %% [markdown]
# # WhatsApp Campaign Dataset Analysis
#
# ## Overview
#
# The dataset contains WhatsApp campaign interaction records related to:
# - campaign products,
# - crop targeting,
# - grower engagement,
# - message delivery,
# - and campaign response behavior.
#
# The dataset is highly useful for:
# - digital marketing analytics,
# - grower engagement analysis,
# - campaign performance evaluation,
# - and AI-driven targeting systems.
#
# ---
#
# # Dataset Features
#
# | Feature | Description |
# |---|---|
# | id | Unique WhatsApp campaign interaction identifier |
# | campaign_product | Product promoted in the campaign |
# | campaign_crop | Crop targeted by the campaign |
# | grower_id | Unique grower identifier |
# | message_sent_date | Date the WhatsApp message was sent |
# | delivered_status | Whether the message was successfully delivered |
# | opened_status | Whether the grower opened the message |
# | clicked_status | Whether the grower clicked the campaign content |
#
# ---
#
# # Initial Observations
#
# ## Campaign Product Information
#
# ### `campaign_product`
#
# - Represents products promoted through WhatsApp campaigns.
# - Useful for product-level campaign analysis.
#
# ### Business Importance
#
# Supports:
# - product promotion evaluation,
# - campaign effectiveness analysis,
# - and digital engagement monitoring.
#
# ---
#
# # Crop Targeting Information
#
# ## `campaign_crop`
#
# - Represents crops targeted by marketing campaigns.
#
# ### Analytical Importance
#
# Useful for:
# - crop-specific marketing strategies,
# - seasonal targeting,
# - and demand analysis.
#
# ---
#
# # Grower-Level Tracking
#
# ## `grower_id`
#
# - Represents individual growers receiving campaign messages.
# - Enables grower-level engagement analysis.
#
# ### Business Insight
#
# Supports:
# - customer segmentation,
# - personalization,
# - and targeted marketing strategies.
#
# ---
#
# # Campaign Interaction Metrics
#
# ## `delivered_status`
#
# - Indicates whether the message reached the grower.
#
# ### Operational Importance
#
# Useful for:
# - delivery success analysis,
# - communication reliability monitoring,
# - and outreach evaluation.
#
# ---
#
# ## `opened_status`
#
# - Indicates whether the grower opened the WhatsApp message.
#
# ### Engagement Importance
#
# Supports:
# - engagement-rate calculation,
# - content effectiveness analysis,
# - and campaign performance evaluation.
#
# ---
#
# ## `clicked_status`
#
# - Indicates whether the grower clicked campaign content.
#
# ### Business Relevance
#
# Useful for:
# - conversion analysis,
# - lead generation evaluation,
# - and grower intent measurement.
#
# ---
#
# # Temporal Feature
#
# ## `message_sent_date`
#
# - Represents the campaign communication date.
# - Enables time-based campaign analysis.
#
# ### Analytical Benefits
#
# Supports:
# - campaign trend analysis,
# - engagement timing optimization,
# - and seasonal communication strategies.
#
# ---
#
# # Dataset Structure Observation
#
# The dataset follows a structured digital engagement hierarchy:
#
# `Campaign → Product → Crop → Grower → Delivery → Engagement`
#
# This structure supports:
# - campaign intelligence,
# - digital funnel analytics,
# - and grower engagement monitoring.
#
# ---
#
# # AI/ML Relevance
#
# The dataset is highly suitable for:
# - engagement prediction,
# - click-through forecasting,
# - grower response modeling,
# - and campaign optimization.
#
# Potential engineered features include:
# - open rates,
# - click-through rates,
# - grower engagement scores,
# - and campaign effectiveness metrics.
#
# ---
#
# # Final Interpretation
#
# The dataset provides detailed WhatsApp campaign interaction intelligence across growers, products, and engagement behaviors. The combination of campaign, temporal, and interaction features creates strong potential for:
# - digital marketing analytics,
# - engagement optimization,
# - and AI-driven campaign intelligence systems.

# %%
df.shape
# Out:
# (4479, 8)

# %% [markdown]
# # Dataset Shape Analysis
#
# ## Overview
#
# The shape of a dataset represents:
# - the total number of records,
# - and the number of available features.
#
# This helps evaluate:
# - dataset scale,
# - campaign coverage,
# - and analytical capability.
#
# ---
#
# # Dataset Shape
#
# | Metric | Value |
# |---|---|
# | Number of Rows | 4,479 |
# | Number of Columns | 8 |
#
# ---
#
# # Interpretation
#
# ## Total Records = 4,479
#
# - The dataset contains 4,479 WhatsApp campaign interaction records.
# - Each row represents a grower-level campaign communication event.
#
# ### Business Insight
#
# This indicates:
# - active digital outreach operations,
# - measurable grower engagement tracking,
# - and campaign-level interaction monitoring.
#
# ---
#
# ## Total Features = 8
#
# The dataset includes:
# - campaign information,
# - product promotion details,
# - crop targeting,
# - grower identifiers,
# - temporal information,
# - and engagement metrics.
#
# ### Analytical Importance
#
# These features support:
# - campaign analytics,
# - engagement monitoring,
# - grower behavior analysis,
# - and marketing optimization.
#
# ---
#
# # Operational Scale Observation
#
# The dataset size is suitable for:
# - campaign performance analysis,
# - engagement trend evaluation,
# - and machine learning applications.
#
# The number of records improves:
# - behavioral analysis quality,
# - engagement visibility,
# - and prediction reliability.
#
# ---
#
# # Digital Engagement Coverage
#
# The dataset captures:
# - grower-level communication activity,
# - message delivery outcomes,
# - open behavior,
# - and click interactions.
#
# This enables:
# - digital funnel analysis,
# - campaign optimization,
# - and targeted engagement strategies.
#
# ---
#
# # AI/ML Relevance
#
# The dataset size is beneficial for:
# - engagement prediction,
# - click-through forecasting,
# - campaign optimization,
# - and grower segmentation models.
#
# The interaction records support:
# - behavioral learning,
# - response modeling,
# - and digital marketing intelligence.
#
# ---
#
# # Final Interpretation
#
# The dataset contains 4,479 WhatsApp campaign interaction records and 8 meaningful features, providing a strong foundation for:
# - digital marketing analytics,
# - grower engagement intelligence,
# - and AI-driven campaign optimization systems.

# %%
df.columns
# Out:
# Index(['id', 'campaign_product', 'campaign_crop', 'grower_id',
#        'message_sent_date', 'delivered_status', 'opened_status',
#        'clicked_status'],
#       dtype='str')

# %% [markdown]
# # Feature Analysis
#
# ## Overview
#
# The dataset contains 8 features related to:
# - WhatsApp campaign operations,
# - product promotion,
# - crop targeting,
# - grower engagement,
# - and digital interaction behavior.
#
# These features provide strong analytical value for:
# - digital marketing analytics,
# - engagement intelligence,
# - and campaign optimization.
#
# ---
#
# # Dataset Features
#
# | Feature | Description |
# |---|---|
# | id | Unique WhatsApp campaign interaction identifier |
# | campaign_product | Product promoted in the campaign |
# | campaign_crop | Crop targeted by the campaign |
# | grower_id | Unique grower identifier |
# | message_sent_date | Date the campaign message was sent |
# | delivered_status | Whether the message was delivered |
# | opened_status | Whether the message was opened |
# | clicked_status | Whether the campaign content was clicked |
#
# ---
#
# # Feature-Level Interpretation
#
# ## `id`
#
# - Represents unique campaign interaction records.
# - Ensures traceability of individual campaign events.
#
# ### Operational Importance
#
# Useful for:
# - interaction tracking,
# - campaign auditing,
# - and data integrity validation.
#
# ---
#
# ## `campaign_product`
#
# - Represents products promoted through WhatsApp campaigns.
# - Useful for product-level marketing analysis.
#
# ### Business Insight
#
# Supports:
# - product promotion tracking,
# - campaign effectiveness analysis,
# - and demand evaluation.
#
# ---
#
# ## `campaign_crop`
#
# - Represents crops targeted during campaigns.
# - Enables crop-specific marketing strategies.
#
# ### Analytical Importance
#
# Useful for:
# - seasonal targeting,
# - crop segmentation,
# - and campaign optimization.
#
# ---
#
# ## `grower_id`
#
# - Represents individual growers receiving campaign messages.
# - Supports grower-level engagement analysis.
#
# ### Business Relevance
#
# Useful for:
# - personalization,
# - segmentation,
# - and customer engagement modeling.
#
# ---
#
# ## `message_sent_date`
#
# - Represents the date of campaign communication.
# - Enables temporal campaign analysis.
#
# ### Analytical Benefits
#
# Supports:
# - engagement trend analysis,
# - campaign scheduling optimization,
# - and seasonal communication evaluation.
#
# ---
#
# ## `delivered_status`
#
# - Indicates successful message delivery.
# - Represents campaign reach effectiveness.
#
# ### Operational Importance
#
# Useful for:
# - delivery success monitoring,
# - communication reliability analysis,
# - and outreach evaluation.
#
# ---
#
# ## `opened_status`
#
# - Indicates whether growers opened campaign messages.
# - Represents initial engagement behavior.
#
# ### Engagement Importance
#
# Supports:
# - open-rate analysis,
# - content effectiveness measurement,
# - and campaign engagement evaluation.
#
# ---
#
# ## `clicked_status`
#
# - Indicates whether growers clicked campaign content.
# - Represents deeper engagement and intent.
#
# ### Business Importance
#
# Useful for:
# - click-through analysis,
# - conversion evaluation,
# - and lead-generation assessment.
#
# ---
#
# # Dataset Structure Observation
#
# The dataset follows a structured digital engagement flow:
#
# `Campaign → Product → Grower → Delivery → Open → Click`
#
# This structure supports:
# - funnel analytics,
# - engagement tracking,
# - and campaign intelligence generation.
#
# ---
#
# # AI/ML Relevance
#
# The features are highly suitable for:
# - engagement prediction,
# - click-through forecasting,
# - grower response modeling,
# - and marketing optimization.
#
# Potential engineered features include:
# - engagement scores,
# - conversion rates,
# - grower activity patterns,
# - and campaign effectiveness metrics.
#
# ---
#
# # Final Interpretation
#
# The dataset features are well-structured and operationally valuable for digital marketing analytics. Together, they provide a strong foundation for:
# - campaign intelligence,
# - grower engagement analysis,
# - and AI-driven marketing optimization systems.

# %%
df.isnull().sum()
# Out:
# id                   0
# campaign_product     0
# campaign_crop        0
# grower_id            0
# message_sent_date    0
# delivered_status     0
# opened_status        0
# clicked_status       0
# dtype: int64

# %% [markdown]
# # Missing Value Analysis
#
# ## Overview
#
# Missing value analysis helps evaluate:
# - dataset completeness,
# - data reliability,
# - and preprocessing requirements.
#
# Datasets without missing values are highly beneficial for:
# - campaign analytics,
# - engagement modeling,
# - and machine learning applications.
#
# ---
#
# # Missing Value Summary
#
# | Feature | Missing Values |
# |---|---|
# | id | 0 |
# | campaign_product | 0 |
# | campaign_crop | 0 |
# | grower_id | 0 |
# | message_sent_date | 0 |
# | delivered_status | 0 |
# | opened_status | 0 |
# | clicked_status | 0 |
#
# ---
#
# # Interpretation
#
# ## No Missing Values Detected
#
# All features in the dataset are fully populated with:
# - zero null values,
# - strong structural consistency,
# - and reliable campaign interaction information.
#
# This indicates excellent data quality.
#
# ---
#
# # Feature-Level Observations
#
# ## `id`
#
# - Every campaign interaction contains a unique identifier.
# - Supports reliable interaction tracking and auditing.
#
# ---
#
# ## `campaign_product`
#
# - Product promotion information is completely available.
# - Enables uninterrupted product-level campaign analysis.
#
# ---
#
# ## `campaign_crop`
#
# - Crop targeting data is fully recorded.
# - Supports accurate crop-specific marketing evaluation.
#
# ---
#
# ## `grower_id`
#
# - Every interaction is linked to a grower.
# - Improves grower-level engagement analysis and personalization.
#
# ---
#
# ## `message_sent_date`
#
# - All campaign records contain valid communication dates.
# - Enables reliable temporal and trend analysis.
#
# ---
#
# ## `delivered_status`
#
# - Delivery outcomes are fully captured.
# - Supports accurate communication success analysis.
#
# ---
#
# ## `opened_status`
#
# - Message open behavior is consistently available.
# - Enables engagement-rate evaluation and funnel analysis.
#
# ---
#
# ## `clicked_status`
#
# - Click interaction data is completely recorded.
# - Supports conversion and intent analysis.
#
# ---
#
# # Business Importance
#
# Complete digital engagement data improves:
# - campaign visibility,
# - engagement analysis accuracy,
# - and marketing intelligence.
#
# The absence of missing values also reduces:
# - preprocessing effort,
# - imputation complexity,
# - and analytical uncertainty.
#
# ---
#
# # AI/ML Relevance
#
# Since no missing values exist:
# - preprocessing becomes simpler,
# - model reliability improves,
# - and predictive performance strengthens.
#
# This benefits:
# - engagement prediction,
# - click-through forecasting,
# - campaign optimization,
# - and grower segmentation models.
#
# ---
#
# # Final Interpretation
#
# The dataset demonstrates excellent completeness with no missing values across all campaign interaction features. This creates a strong foundation for:
# - digital marketing analytics,
# - engagement intelligence,
# - and AI-driven campaign optimization systems.

# %%
df.dtypes
# Out:
# id                    str
# campaign_product      str
# campaign_crop         str
# grower_id             str
# message_sent_date     str
# delivered_status     bool
# opened_status        bool
# clicked_status       bool
# dtype: object

# %% [markdown]
# # Data Type Analysis
#
# ## Overview
#
# Data type analysis helps verify whether dataset features are stored in appropriate formats for:
# - analysis,
# - preprocessing,
# - visualization,
# - and machine learning.
#
# Correct data types improve:
# - computational efficiency,
# - analytical accuracy,
# - and data consistency.
#
# ---
#
# # Feature Data Types
#
# | Feature | Data Type |
# |---|---|
# | id | object (string) |
# | campaign_product | object (string) |
# | campaign_crop | object (string) |
# | grower_id | object (string) |
# | message_sent_date | object (string) |
# | delivered_status | bool |
# | opened_status | bool |
# | clicked_status | bool |
#
# ---
#
# # Interpretation
#
# # Categorical Features
#
# ## `id`
#
# - Stored correctly as string data.
# - Represents unique campaign interaction identifiers.
#
# ### Operational Importance
#
# Useful for:
# - campaign tracking,
# - interaction auditing,
# - and record validation.
#
# ---
#
# ## `campaign_product`
#
# - Represents products promoted during campaigns.
# - Properly stored as categorical text data.
#
# ### Business Importance
#
# Supports:
# - product-level campaign analysis,
# - promotion tracking,
# - and engagement evaluation.
#
# ---
#
# ## `campaign_crop`
#
# - Represents crops targeted by campaigns.
# - Useful for crop-specific marketing analysis.
#
# ### Analytical Relevance
#
# Supports:
# - seasonal targeting,
# - crop segmentation,
# - and campaign optimization.
#
# ---
#
# ## `grower_id`
#
# - Represents unique growers receiving campaign messages.
# - Enables grower-level engagement analysis.
#
# ### Business Insight
#
# Useful for:
# - personalization,
# - customer segmentation,
# - and behavioral modeling.
#
# ---
#
# # Temporal Feature Observation
#
# ## `message_sent_date`
#
# - Currently stored as string (`object`) type.
# - Represents the campaign communication date.
#
# ### Recommended Improvement
#
# Convert this feature into datetime format for:
# - trend analysis,
# - campaign timing optimization,
# - seasonality detection,
# - and time-series modeling.
#
# ### Suggested Conversion
#
# ```python
# df['message_sent_date'] = pd.to_datetime(df['message_sent_date'])
# ```
#
# ---
#
# # Boolean Engagement Features
#
# ## `delivered_status`
#
# - Stored as Boolean (`bool`) values.
# - Represents whether messages were successfully delivered.
#
# ### Operational Importance
#
# Useful for:
# - delivery-rate analysis,
# - communication monitoring,
# - and outreach evaluation.
#
# ---
#
# ## `opened_status`
#
# - Stored as Boolean (`bool`) values.
# - Represents whether growers opened campaign messages.
#
# ### Engagement Importance
#
# Supports:
# - open-rate analysis,
# - engagement measurement,
# - and campaign effectiveness evaluation.
#
# ---
#
# ## `clicked_status`
#
# - Stored as Boolean (`bool`) values.
# - Represents whether growers clicked campaign content.
#
# ### Business Relevance
#
# Useful for:
# - click-through analysis,
# - conversion measurement,
# - and intent prediction.
#
# ---
#
# # Dataset Structure Observation
#
# The dataset combines:
# - categorical campaign information,
# - temporal communication data,
# - and binary engagement indicators.
#
# This structure is highly suitable for:
# - digital funnel analytics,
# - campaign intelligence,
# - and AI-driven engagement systems.
#
# ---
#
# # AI/ML Relevance
#
# The feature types are highly valuable for:
# - engagement prediction,
# - click-through forecasting,
# - grower response modeling,
# - and marketing optimization.
#
# Boolean engagement features can directly support:
# - classification models,
# - funnel analysis,
# - and behavioral prediction systems.
#
# ---
#
# # Final Interpretation
#
# The dataset data types are well-structured and operationally appropriate. The primary enhancement opportunity is converting `message_sent_date` into datetime format to enable advanced temporal and campaign trend analysis.

# %%
df.describe()
# Out:
#                       id campaign_product campaign_crop  grower_id  \
# count               4479             4479          4479       4479
# unique              4479                4             9       4479
# top     WAM_RABI25_00001      Tilt 250 EC         wheat  GRW_00001
# freq                   1             2376          2376          1
#
#        message_sent_date delivered_status opened_status clicked_status
# count               4479             4479          4479           4479
# unique               182                2             2              2
# top           2025-10-06             True         False          False
# freq                 108             4406          3442           4253

# %% [markdown]
# # Categorical and Engagement Statistical Analysis
#
# ## Overview
#
# The statistical summary provides insights into:
# - campaign distribution,
# - crop targeting,
# - grower coverage,
# - communication frequency,
# - and digital engagement behavior.
#
# These observations are highly useful for:
# - marketing analytics,
# - campaign optimization,
# - and engagement intelligence.
#
# ---
#
# # Statistical Summary
#
# | Feature | Count | Unique | Top Value | Frequency |
# |---|---|---|---|---|
# | id | 4,479 | 4,479 | WAM_RABI25_00001 | 1 |
# | campaign_product | 4,479 | 4 | Tilt 250 EC | 2,376 |
# | campaign_crop | 4,479 | 9 | wheat | 2,376 |
# | grower_id | 4,479 | 4,479 | GRW_00001 | 1 |
# | message_sent_date | 4,479 | 182 | 2025-10-06 | 108 |
# | delivered_status | 4,479 | 2 | True | 4,406 |
# | opened_status | 4,479 | 2 | False | 3,442 |
# | clicked_status | 4,479 | 2 | False | 4,253 |
#
# ---
#
# # Interpretation
#
# # 1. Campaign Product Analysis
#
# ## Unique Campaign Products = 4
#
# - The dataset includes 4 promoted agricultural products.
# - Campaign focus appears concentrated on a limited product portfolio.
#
# ### Most Promoted Product
#
# - `Tilt 250 EC` appears most frequently with 2,376 campaign interactions.
#
# ### Business Insight
#
# This suggests:
# - strong marketing emphasis,
# - strategic product prioritization,
# - or seasonal product relevance.
#
# ---
#
# # 2. Campaign Crop Analysis
#
# ## Unique Crops Targeted = 9
#
# - Campaigns target multiple crop categories.
# - Indicates diversified agricultural outreach.
#
# ### Most Targeted Crop
#
# - `wheat` appears most frequently with 2,376 records.
#
# ### Interpretation
#
# This may reflect:
# - seasonal crop importance,
# - market demand concentration,
# - or campaign timing alignment.
#
# ---
#
# # 3. Grower Coverage Analysis
#
# ## Unique Growers = 4,479
#
# - Every grower appears uniquely represented.
# - Indicates broad grower-level outreach without duplication.
#
# ### Business Importance
#
# Supports:
# - personalized campaign analysis,
# - individual engagement tracking,
# - and targeted marketing strategies.
#
# ---
#
# # 4. Message Timeline Analysis
#
# ## Unique Campaign Dates = 182
#
# - Campaign activity spans 182 unique days.
# - Indicates sustained digital engagement over approximately 6 months.
#
# ### Most Active Date
#
# - `2025-10-06` contains the highest number of campaign messages.
#
# ### Operational Insight
#
# This may represent:
# - campaign launch periods,
# - promotional peaks,
# - or scheduled outreach events.
#
# ---
#
# # 5. Delivery Status Analysis
#
# ## Delivered Messages
#
# - `True` appears 4,406 times.
#
# ### Interpretation
#
# The campaign demonstrates:
# - very high message delivery success,
# - strong communication reliability,
# - and effective outreach infrastructure.
#
# ---
#
# # 6. Opened Status Analysis
#
# ## Most Common Open Status = False
#
# - `False` appears 3,442 times.
#
# ### Interpretation
#
# Although messages are largely delivered successfully:
# - a significant portion remains unopened,
# - indicating engagement challenges.
#
# ### Business Implication
#
# This suggests opportunities for improving:
# - message timing,
# - content personalization,
# - and campaign relevance.
#
# ---
#
# # 7. Clicked Status Analysis
#
# ## Most Common Click Status = False
#
# - `False` appears 4,253 times.
#
# ### Interpretation
#
# Click-through engagement is relatively low compared to message delivery.
#
# ### Possible Reasons
#
# - low conversion intent,
# - limited content attractiveness,
# - or weak call-to-action effectiveness.
#
# ---
#
# # Digital Funnel Observation
#
# The dataset reflects a clear engagement funnel:
#
# `Delivered → Opened → Clicked`
#
# The funnel indicates:
# - strong delivery performance,
# - moderate opening engagement,
# - and comparatively low click conversion.
#
# ---
#
# # AI/ML Relevance
#
# The dataset is highly suitable for:
# - engagement prediction,
# - click-through forecasting,
# - grower response modeling,
# - and campaign optimization.
#
# Boolean engagement features can support:
# - classification models,
# - behavioral prediction,
# - and intelligent targeting systems.
#
# ---
#
# # Final Interpretation
#
# The dataset demonstrates strong campaign delivery performance with moderate engagement and lower click conversion rates. These features provide valuable intelligence for:
# - digital marketing analytics,
# - engagement optimization,
# - and AI-driven campaign performance systems.

# %%
df['message_sent_date'].min()
# Out:
# '2025-10-06'

# %%
df['message_sent_date'].max()
# Out:
# '2026-04-05'

# %% [markdown]
# # Message Sent Date Range Analysis
#
# ## Overview
#
# The `message_sent_date` feature represents the timeline of WhatsApp campaign communications sent to growers.
#
# Analyzing the date range helps understand:
# - campaign duration,
# - communication consistency,
# - seasonal outreach,
# - and digital engagement timelines.
#
# ---
#
# # Date Range Summary
#
# | Metric | Value |
# |---|---|
# | Earliest Message Date | 2025-10-06 |
# | Latest Message Date | 2026-04-05 |
#
# ---
#
# # Interpretation
#
# ## Campaign Timeline Coverage
#
# - The dataset spans approximately 6 months of digital campaign activity.
# - Campaign communications extend from October 2025 to April 2026.
#
# ### Business Insight
#
# This provides sufficient temporal coverage for:
# - engagement trend analysis,
# - campaign performance monitoring,
# - and seasonal marketing evaluation.
#
# ---
#
# # Seasonal Campaign Coverage
#
# The timeline includes:
# - Rabi crop promotion periods,
# - winter agricultural campaigns,
# - and early 2026 marketing operations.
#
# ### Strategic Importance
#
# This period may capture:
# - crop-season targeting,
# - seasonal product promotion,
# - and grower engagement cycles.
#
# ---
#
# # Communication Consistency
#
# The wide date range suggests:
# - sustained digital outreach,
# - continuous campaign execution,
# - and active grower engagement efforts.
#
# ### Operational Observation
#
# Consistent campaign activity improves:
# - brand visibility,
# - grower interaction frequency,
# - and campaign effectiveness potential.
#
# ---
#
# # Temporal Granularity
#
# Campaign records are maintained at the daily level.
#
# ### Analytical Benefits
#
# This enables:
# - day-wise engagement analysis,
# - campaign timing optimization,
# - response trend tracking,
# - and time-series modeling.
#
# ---
#
# # AI/ML Relevance
#
# The `message_sent_date` feature is highly valuable for:
# - engagement prediction,
# - campaign scheduling optimization,
# - seasonality analysis,
# - and communication forecasting.
#
# Potential engineered features include:
# - month,
# - week,
# - campaign season,
# - and engagement-cycle indicators.
#
# ---
#
# # Business Importance
#
# Temporal campaign analysis can help:
# - optimize communication timing,
# - improve grower engagement,
# - identify high-response periods,
# - and strengthen campaign planning.
#
# ---
#
# # Final Interpretation
#
# The dataset captures WhatsApp campaign activity across a well-structured 6-month communication period, providing strong temporal coverage for:
# - digital marketing analytics,
# - engagement intelligence,
# - and AI-driven campaign optimization systems.

# %%
df['campaign_crop'].value_counts()
# Out:
# campaign_crop
# wheat        2376
# chickpea      666
# mustard       528
# barley        273
# potato        204
# lentil        175
# safflower     140
# cumin          63
# maize          54
# Name: count, dtype: int64

# %%
df['campaign_product'].value_counts()
# Out:
# campaign_product
# Tilt 250 EC       2376
# Amistar 250 SC    1231
# Score 250 EC       668
# Kavach 75 WP       204
# Name: count, dtype: int64

# %% [markdown]
# # Campaign Crop and Product Distribution Analysis
#
# ## Overview
#
# The analysis of `campaign_crop` and `campaign_product` helps understand:
# - marketing focus areas,
# - campaign prioritization,
# - crop-specific targeting strategies,
# - and promoted product distribution.
#
# These insights are valuable for:
# - digital marketing analytics,
# - campaign optimization,
# - and strategic product promotion.
#
# ---
#
# # 1. Campaign Crop Distribution
#
# ## Crop Frequency Summary
#
# | Campaign Crop | Count |
# |---|---|
# | wheat | 2,376 |
# | chickpea | 666 |
# | mustard | 528 |
# | barley | 273 |
# | potato | 204 |
# | lentil | 175 |
# | safflower | 140 |
# | cumin | 63 |
# | maize | 54 |
#
# ---
#
# # Interpretation
#
# ## Dominant Target Crop
#
# ### Wheat
#
# - `wheat` is the most targeted crop with 2,376 campaign records.
# - It represents more than half of all campaign interactions.
#
# ### Business Insight
#
# This suggests:
# - strong seasonal importance,
# - high market demand,
# - or strategic campaign prioritization for wheat cultivation.
#
# ---
#
# # Secondary Target Crops
#
# ## Chickpea and Mustard
#
# - These crops also receive notable campaign attention.
# - Indicates diversified crop targeting strategy.
#
# ### Operational Importance
#
# These crops may represent:
# - regionally significant farming segments,
# - seasonal opportunities,
# - or strategic market categories.
#
# ---
#
# # Lower Frequency Crops
#
# ## Cumin and Maize
#
# - These crops receive the lowest campaign focus.
#
# ### Interpretation
#
# Possible reasons include:
# - smaller grower base,
# - niche crop cultivation,
# - or lower campaign priority.
#
# ---
#
# # Crop Distribution Observation
#
# The distribution is moderately skewed toward wheat campaigns.
#
# ### Business Implication
#
# This reflects:
# - concentrated marketing investment,
# - crop-priority segmentation,
# - and demand-driven campaign planning.
#
# ---
#
# # 2. Campaign Product Distribution
#
# ## Product Frequency Summary
#
# | Campaign Product | Count |
# |---|---|
# | Tilt 250 EC | 2,376 |
# | Amistar 250 SC | 1,231 |
# | Score 250 EC | 668 |
# | Kavach 75 WP | 204 |
#
# ---
#
# # Interpretation
#
# ## Most Promoted Product
#
# ### Tilt 250 EC
#
# - `Tilt 250 EC` dominates campaign promotions with 2,376 interactions.
#
# ### Business Insight
#
# This suggests:
# - high strategic importance,
# - strong product demand,
# - or major campaign emphasis.
#
# ---
#
# # Secondary Promoted Products
#
# ## Amistar 250 SC
#
# - Shows substantial campaign activity with 1,231 records.
#
# ### Operational Importance
#
# May indicate:
# - strong market adoption,
# - active product promotion,
# - or seasonal product relevance.
#
# ---
#
# # Lower Promoted Product
#
# ## Kavach 75 WP
#
# - Receives the lowest promotional focus.
#
# ### Interpretation
#
# Possible reasons include:
# - niche usage,
# - limited campaign allocation,
# - or crop-specific targeting.
#
# ---
#
# # Combined Marketing Insight
#
# The campaign structure demonstrates:
# - concentrated focus on wheat-related campaigns,
# - strong promotion of select high-priority products,
# - and targeted digital marketing strategies.
#
# ---
#
# # AI/ML Relevance
#
# The crop and product distribution features are highly useful for:
# - recommendation systems,
# - engagement prediction,
# - campaign optimization,
# - and grower targeting models.
#
# These features can support:
# - personalized campaign strategies,
# - intelligent product recommendation,
# - and conversion prediction systems.
#
# ---
#
# # Final Interpretation
#
# The campaign distribution analysis reveals strong marketing concentration around wheat-focused campaigns and high-priority agricultural products such as `Tilt 250 EC`. These patterns provide valuable intelligence for:
# - digital marketing optimization,
# - crop-focused campaign planning,
# - and AI-driven engagement systems.

# %%
df['campaign_crop'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='campaign_crop'>

# %%
df['campaign_product'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='campaign_product'>

# %% [markdown]
# # Campaign Crop and Product Visualization Analysis
#
# ## Overview
#
# The bar charts visualize the distribution of:
# - campaign crops,
# - and promoted campaign products.
#
# These visualizations help identify:
# - marketing priorities,
# - dominant campaign focus areas,
# - product promotion intensity,
# - and crop-targeting strategies.
#
# ---
#
# # 1. Campaign Crop Distribution Visualization
#
# ## Key Observations
#
# | Campaign Crop | Approximate Count |
# |---|---|
# | wheat | ~2,376 |
# | chickpea | ~666 |
# | mustard | ~528 |
# | barley | ~273 |
# | potato | ~204 |
# | lentil | ~175 |
# | safflower | ~140 |
# | cumin | ~63 |
# | maize | ~54 |
#
# ---
#
# # Interpretation
#
# ## Dominant Campaign Crop
#
# ### Wheat
#
# - The chart clearly shows `wheat` dominating campaign activity.
# - Wheat campaigns significantly exceed all other crop categories.
#
# ### Business Insight
#
# This suggests:
# - high seasonal importance,
# - strong grower demand,
# - or strategic marketing focus on wheat cultivation.
#
# ---
#
# # Secondary Crop Categories
#
# ## Chickpea and Mustard
#
# - These crops receive moderate campaign attention.
# - Indicate diversified crop-targeting efforts.
#
# ### Operational Importance
#
# These campaigns may target:
# - region-specific farming communities,
# - seasonal cultivation cycles,
# - or specialized product demand.
#
# ---
#
# # Low-Frequency Crops
#
# ## Cumin and Maize
#
# - These crops receive minimal campaign focus.
# - Represent niche or lower-priority campaign categories.
#
# ---
#
# # Crop Distribution Observation
#
# The crop distribution is highly skewed toward wheat campaigns.
#
# ### Business Implication
#
# This reflects:
# - concentrated marketing investment,
# - crop-priority segmentation,
# - and focused promotional strategy.
#
# ---
#
# # 2. Campaign Product Distribution Visualization
#
# ## Key Observations
#
# | Campaign Product | Approximate Count |
# |---|---|
# | Tilt 250 EC | ~2,376 |
# | Amistar 250 SC | ~1,231 |
# | Score 250 EC | ~668 |
# | Kavach 75 WP | ~204 |
#
# ---
#
# # Interpretation
#
# ## Most Promoted Product
#
# ### Tilt 250 EC
#
# - The visualization clearly identifies `Tilt 250 EC` as the dominant promoted product.
# - Campaign frequency is substantially higher than other products.
#
# ### Business Insight
#
# Possible reasons include:
# - strong product demand,
# - high campaign priority,
# - or crop-season alignment.
#
# ---
#
# # Secondary Promoted Product
#
# ## Amistar 250 SC
#
# - Shows strong promotional activity.
# - Indicates substantial operational importance.
#
# ---
#
# # Lower Promoted Products
#
# ## Score 250 EC and Kavach 75 WP
#
# - Receive comparatively lower campaign attention.
# - May represent specialized or crop-specific usage.
#
# ---
#
# # Combined Marketing Insight
#
# The visualizations reveal:
# - strong concentration around wheat campaigns,
# - heavy promotion of `Tilt 250 EC`,
# - and focused digital marketing strategies.
#
# The campaign structure appears:
# - strategically prioritized,
# - product-focused,
# - and seasonally aligned.
#
# ---
#
# # AI/ML Relevance
#
# These distributions are valuable for:
# - engagement prediction,
# - recommendation systems,
# - campaign optimization,
# - and targeting intelligence.
#
# The observed patterns can support:
# - personalized marketing,
# - crop-specific recommendation engines,
# - and campaign conversion modeling.
#
# ---
#
# # Final Interpretation
#
# The visualizations demonstrate highly concentrated campaign focus around wheat-related promotions and `Tilt 250 EC` product campaigns. These trends provide valuable intelligence for:
# - digital marketing optimization,
# - product strategy planning,
# - and AI-driven campaign targeting systems.
